# %% [markdown]
# # Datature Python SDK Guide

# %%
#!/usr/bin/env python
# -*-coding:utf-8 -*-
"""
  ████
██    ██   Datature
  ██  ██   Powering Breakthrough AI
    ██
 
@File    :   python_sdk_guide.ipynb
@Author  :   Ng Jian Ming & Wei Loon Cheng
@Version :   1.0
@Contact :   hello@datature.io
@License :   Apache License 2.0
@Desc    :   Datature Python SDK Guide.
"""

# %% [markdown]
# This notebook provides a brief overview on the different APIs provided by Datature's Python SDK. The notebook simply demonstrates the basic functionality and examples of the outputs obtained.
# <br>
# For more information and advanced usage, refer to our [developer's documentation](https://developers.datature.io/docs/python-sdk).

# %% [markdown]
# ## Table Of Contents

# %% [markdown]
# 1. [Install Libraries](#1.-Install-Libraries)<br>
# 2. [Import Libraries](#2.-Import-Libraries)<br>
# 3. [Set Configurations](#3.-Set-Configurations)<br>
# 4. [Project API](#4.-Project-API)<br>
#     4.1. [Retrieve A Project](#4.1.-Retrieve-A-Project)<br>
#     4.2. [Update A Project](#4.2.-Update-A-Project)<br>
#     4.3. [Retrieve Project's Insights](#4.3.-Retrieve-Project's-Insights)<br>
#     4.4. [Retrieve Project's Quota](#4.4.-Retrieve-Project's-Quota)<br>
#     4.5. [Retrieve Project's Users](#4.5.-Retrieve-Project's-Users)<br>
# 5. [Asset API](#Asset-API)<br>
#     5.1. [List All Assets](#5.1.-List-All-Assets)<br>
#     5.2. [Create An Upload Session](#5.2.-Create-An-Upload-Session)<br>
#     5.3. [Retrieve An Asset](#5.3.-Retrieve-An-Asset)<br>
#     5.4. [Update An Asset](#5.4.-Update-An-Asset)<br>
#     5.5. [Delete An Asset](#5.5.-Delete-An-Asset)<br>
# 6. [Annotation API](#6.-Annotation-API)<br>
#     6.1. [Create An Annotation](#6.1.-Create-An-Annotation)<br>
#     6.2. [Export Annotations](#6.2.-Export-Annotations)<br>
#     6.3. [Retrieve Exported Annotations File](#6.3.-Retrieve-Exported-Annotations-File)<br>
#     6.4. [Import Annotations](#6.4.-Import-Annotations)<br>
#     6.5. [List All Annotations In An Asset](#6.5.-List-All-Annotations-In-An-Asset)<br>
#     6.6. [Retrieve An Annotation](#6.6.-Retrieve-An-Annotation)<br>
#     6.7. [Delete An Annotation](#6.7.-Delete-An-Annotation)<br>
# 7. [Operation API](#7.-Operation-API)<br>
#     7.1. [Retrieve An Operation](#7.1.-Retrieve-An-Operation)<br>
# 8. [Tag API](#8.-Tag-API)<br>
#     8.1. [Create A Tag](#8.1.-Create-A-Tag)<br>
#     8.2. [List All Tags](#8.2.-List-All-Tags)<br>
#     8.3. [Update A Tag](#8.3.-Update-A-Tag)<br>
#     8.4. [Delete A Tag](#8.4.-Delete-A-Tag)<br>
# 9. [Workflow API](#9.-Workflow-API)<br>
#     9.1. [List All Workflows](#9.1.-List-All-Workflows)<br>
#     9.2. [Retrieve A Workflow](#9.2.-Retrieve-A-Workflow)<br>
#     9.3. [Update A Workflow](#9.3.-Update-A-Workflow)<br>
#     9.4. [Delete A Workflow](#9.4.-Delete-A-Workflow)<br>
# 10. [Training API](#10.-Training-API)<br>
#     10.1. [Create A Training Run](#10.1.-Create-A-Training-Run)<br>
#     10.2. [List All Training Runs](#10.2.-List-All-Training-Runs)<br>
#     10.3. [Retrieve A Training Log](#10.3.-Retrieve-A-Training-Log)<br>
#     10.4. [Retrieve A Training Run](#10.4.-Retrieve-A-Training-Run)<br>
#     10.5. [Kill A Training Run](#10.5.-Kill-A-Training-Run)<br>
#     10.6. [Delete A Training Run](#10.6.-Delete-A-Training-Run)<br>
# 11. [Artifact API](#11.-Artifact-API)<br>
#     11.1. [List All Artifacts](#11.1.-List-All-Artifacts)<br>
#     11.2. [Retrieve An Artifact](#11.2.-Retrieve-An-Artifact)<br>
#     11.3. [Export An Artifact Model](#11.3.-Export-An-Artifact-Model)<br>
#     11.4. [Retrieve Artifact Models](#11.4.-Retrieve-Exported-Artifact-Models)<br>
# 12. [Deploy API](#12.-Deploy-API)<br>
#     12.1. [Create A Deployment](#12.1.-Create-A-Deployment)<br>
#     12.2. [List All Deployments](#12.2.-List-All-Deployments)<br>
#     12.3. [Retrieve A Deployment](#12.3.-Retrieve-A-Deployment)<br>
#     12.4. [Modify A Deployment](#12.4.-Modify-A-Deployment)<br>
#     12.5. [Create New Version Tag Of A Deployment](#12.5.-Create-New-Version-Tag-Of-A-Deployment)<br>
#     12.6. [Delete A Deployment](#12.4.-Delete-A-Deployment)<br>

# %% [markdown]
# # 1. Install Libraries

# %% [markdown]
# Run the command below to install the `datature` library.

# %%
# Use this to install the latest version of Datature
# %pip install -U datature

# If a specific version is desired, please comment the above command and use the command below
# Replace the appropriate version value desired after '=='
# %pip install datature==1.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: datature in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (1.2.0)
# Requirement already satisfied: requests in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from datature) (2.28.2)
# Requirement already satisfied: google-crc32c in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from datature) (1.5.0)
# Requirement already satisfied: pyhumps in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from datature) (3.8.0)
# Requirement already satisfied: pyyaml in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from datature) (6.0)
# Requirement already satisfied: inquirer in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from datature) (2.10.1)
# Requirement already satisfied: halo in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from datature) (0.0.31)
# Requirement already satisfied: filetype in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from datature) (1.2.0)
# Requirement already satisfied: opencv-python in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from datature) (4.7.0.72)
# Requirement already satisfied: alive-progress in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from datature) (3.1.0)
# Requirement already satisfied: pydicom in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from datature) (2.3.1)
# Requirement already satisfied: nibabel in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from datature) (4.0.2)
# Requirement already satisfied: matplotlib in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from datature) (3.5.3)
# Requirement already satisfied: about-time==4.2.1 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from alive-progress->datature) (4.2.1)
# Requirement already satisfied: grapheme==0.6.0 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from alive-progress->datature) (0.6.0)
# Requirement already satisfied: log-symbols>=0.0.14 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from halo->datature) (0.0.14)
# Requirement already satisfied: spinners>=0.0.24 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from halo->datature) (0.0.24)
# Requirement already satisfied: termcolor>=1.1.0 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from halo->datature) (2.2.0)
# Requirement already satisfied: colorama>=0.3.9 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from halo->datature) (0.4.6)
# Requirement already satisfied: six>=1.12.0 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from halo->datature) (1.16.0)
# Requirement already satisfied: blessed>=1.19.0 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from inquirer->datature) (1.20.0)
# Requirement already satisfied: python-editor>=1.0.4 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from inquirer->datature) (1.0.4)
# Requirement already satisfied: readchar>=3.0.6 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from inquirer->datature) (4.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from matplotlib->datature) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from matplotlib->datature) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from matplotlib->datature) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from matplotlib->datature) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from matplotlib->datature) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from matplotlib->datature) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from matplotlib->datature) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from matplotlib->datature) (2.8.2)
# Requirement already satisfied: setuptools in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from nibabel->datature) (67.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from requests->datature) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from requests->datature) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from requests->datature) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from requests->datature) (2022.12.7)
# Requirement already satisfied: wcwidth>=0.1.4 in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from blessed>=1.19.0->inquirer->datature) (0.2.6)
# Requirement already satisfied: typing-extensions in /home/cwlroda/.virtualenvs/script-library/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->datature) (4.5.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. Import Libraries

# %% [markdown]
# Import the necessary libraries to be used for this notebook. This includes the `datature` library itself to showcase how to use the different APIs present in the library.

# %%
import glob
import time
from pprint import pprint

import datature

# %% [markdown]
# # 3. Set Configurations

# %% [markdown]
# Replace the project secret with your own project's secret. Do note that you will need to generate this secret key first on the Nexus platform first.
#
# **NOTE: Please remember to store your Secret Key somewhere safe. For illustration purpose, the secret key is written in the notebook.**

# %%
# Set project_secret
datature.secret_key = "YOUR_SECRET_KEY"

# %% [markdown]
# # 4. Project API

# %% [markdown]
# This section describes how to perform any operations with regards to any Project level operations.

# %% [markdown]
# ## 4.1. Retrieve A Project

# %% [markdown]
# Retrieves the overview information of the current project specified in the `project_secret` configured in the earlier section.

# %%
# Retrieve the current project's overview
project_retrieve_response = datature.Project.retrieve()

# Display response from the retrieve project operation
pprint(project_retrieve_response)
# Out:
# {'create_date': 1682063021500,
#  'groups': ['main', 'active-learning-demo'],
#  'id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'localization': 'MULTI',
#  'name': 'My Awesome Project',
#  'object': 'project',
#  'owner': 'user_637de790b14339458e9f7a73',
#  'statistic': {'annotation_total': 177,
#                'asset_annotated': 44,
#                'asset_total': 49,
#                'tags_count': [{'count': 99, 'name': 'Platelets'},
#                               {'count': 78, 'name': 'WBC'},
#                               {'count': 0, 'name': 'new tag name'},
#                               {'count': 0, 'name': 'RBC'}]},
#  'tags': ['Platelets', 'WBC', 'new tag name', 'RBC'],
#  'tier': 'developer',
#  'type': 'object-detection'}

# %% [markdown]
# ## 4.2. Update A Project

# %% [markdown]
# Performs an update on a property of the current project. Currently only allows updating the `name` property of the current project.

# %%
# Modify the project name's property
project_modify_response = datature.Project.modify({"name": "My Cool Project"})

# Display response from the modify project operation
pprint(project_modify_response)
# Out:
# {'create_date': 1682063021500,
#  'groups': ['main', 'active-learning-demo'],
#  'id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'localization': 'MULTI',
#  'name': 'My Cool Project',
#  'object': 'project',
#  'owner': 'user_637de790b14339458e9f7a73',
#  'statistic': {'annotation_total': 177,
#                'asset_annotated': 44,
#                'asset_total': 49,
#                'tags_count': [{'count': 99, 'name': 'Platelets'},
#                               {'count': 78, 'name': 'WBC'},
#                               {'count': 0, 'name': 'new tag name'},
#                               {'count': 0, 'name': 'RBC'}]},
#  'tags': ['Platelets', 'WBC', 'new tag name', 'RBC'],
#  'tier': 'developer',
#  'type': 'object-detection'}

# %% [markdown]
# ## 4.3. Retrieve Project's Insights

# %% [markdown]
# Retrieves insights of the projects which involves the details of the training runs made during the lifetime of the project itself.

# %%
# Retrieve the project's insights
project_insight_response = datature.Project.insight()

# Display response from the retrieval of project's insights operation
pprint(project_insight_response)
# Out:
# [{'batch_size': 2,
#   'checkpoint_every_n': 250,
#   'create_date': 1694166818555,
#   'data_type': 'bbox',
#   'epochs': 3000,
#   'flow_title': 'MobileNet',
#   'learning_rate': 0.08,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 0.104,
#              'localization_loss': 0.08,
#              'regularization_loss': 0.147,
#              'total_loss': 0.331},
#   'metric_target': 'Loss/total_loss',
#   'mode_name': 'retina-mobilenetv2-320x320',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'momentum',
#   'run_id': 'run_3bfbc1a4-1737-4271-84ea-216bf3ae924c',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 3.6},
#   'step': 2500},
#  {'batch_size': 4,
#   'checkpoint_every_n': 250,
#   'create_date': 1690190202619,
#   'data_type': 'bbox',
#   'epochs': 3000,
#   'flow_title': 'YOLOv8',
#   'learning_rate': 0.001,
#   'max_detection_per_class': 100,
#   'metric': {'classification_loss': 5.202, 'total_loss': 24.587},
#   'metric_target': 'DetectionBoxes_Precision/mAP@.50IOU',
#   'mode_name': 'yolov8-small-320x320',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'adam',
#   'run_id': 'run_0c57c457-64f3-42d2-9c6a-d6b1c939928b',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 19.42},
#   'step': 4},
#  {'batch_size': 2,
#   'checkpoint_every_n': 250,
#   'create_date': 1688109819811,
#   'data_type': 'bbox',
#   'epochs': 3000,
#   'flow_title': 'YOLOv8',
#   'learning_rate': 0.001,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 2.181, 'total_loss': 10.165},
#   'metric_target': 'Loss/total_loss',
#   'mode_name': 'yolov8-nano-320x320',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'adam',
#   'run_id': 'run_8d0e50be-d484-47d6-847a-e872418e61bc',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 19.42},
#   'step': 12},
#  {'batch_size': 2,
#   'checkpoint_every_n': 250,
#   'create_date': 1687166187979,
#   'data_type': 'bbox',
#   'epochs': 3000,
#   'flow_title': 'My Workflow',
#   'learning_rate': 0.04,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 0.803,
#              'localization_loss': 1.976,
#              'regularization_loss': 0,
#              'total_loss': 2.778},
#   'metric_target': 'Loss/total_loss',
#   'mode_name': 'fasterrcnn-inceptionv2-1024x1024',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'momentum_optimizer',
#   'run_id': 'run_586152af-c6d0-4bf9-b12c-7a0a76e9ed5e',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 19.42},
#   'step': 1000},
#  {'batch_size': 2,
#   'checkpoint_every_n': 250,
#   'create_date': 1686554183165,
#   'data_type': 'bbox',
#   'epochs': 3000,
#   'flow_title': 'FasterRCNN',
#   'learning_rate': 0.04,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 1.43,
#              'localization_loss': 0.991,
#              'regularization_loss': 0,
#              'total_loss': 2.421},
#   'metric_target': 'DetectionBoxes_Precision/mAP',
#   'mode_name': 'fasterrcnn-inceptionv2-640x640',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'momentum_optimizer',
#   'run_id': 'run_db7f7347-66a6-40b3-860b-1712cc830287',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 19.42},
#   'step': 3000},
#  {'batch_size': 2,
#   'checkpoint_every_n': 250,
#   'create_date': 1683277042800,
#   'data_type': 'bbox',
#   'epochs': 3000,
#   'flow_title': 'YOLOX',
#   'learning_rate': 0.001,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 0.669,
#              'localization_loss': 2.32,
#              'total_loss': 4.391},
#   'metric_target': '',
#   'mode_name': 'yolox-small-320x320',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'adam',
#   'run_id': 'run_e71ffed8-46e0-4369-b7a2-1b1370d0ae82',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 19.42},
#   'step': 12},
#  {'batch_size': 2,
#   'checkpoint_every_n': 250,
#   'create_date': 1683277013681,
#   'data_type': 'bbox',
#   'epochs': 3000,
#   'flow_title': 'YOLOv4',
#   'learning_rate': 0.001,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 0.043,
#              'localization_loss': 10.077,
#              'total_loss': 19.77},
#   'metric_target': '',
#   'mode_name': 'yolov4-darknet-320x320',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'adam',
#   'run_id': 'run_7e2f82f6-b254-4862-96a5-3c34ce6e80c6',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 19.42},
#   'step': 12},
#  {'batch_size': 2,
#   'checkpoint_every_n': 250,
#   'create_date': 1683277010021,
#   'data_type': 'bbox',
#   'epochs': 3000,
#   'flow_title': 'YOLOv4',
#   'learning_rate': 0.001,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 0.08,
#              'localization_loss': 10.178,
#              'total_loss': 19.802},
#   'metric_target': '',
#   'mode_name': 'yolov4-darknet-320x320',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'adam',
#   'run_id': 'run_1129bbb5-b59e-425a-a66a-e8103683013b',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 19.42},
#   'step': 12},
#  {'batch_size': 4,
#   'checkpoint_every_n': 250,
#   'create_date': 1683201389747,
#   'data_type': 'bbox',
#   'epochs': 3000,
#   'flow_title': 'EfficientDet',
#   'learning_rate': 0.08,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 0.47,
#              'localization_loss': 0.006,
#              'regularization_loss': 0.03,
#              'total_loss': 0.506},
#   'metric_target': '',
#   'mode_name': 'efficientdet-d1-640x640',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'momentum_optimizer',
#   'run_id': 'run_2899e28b-336f-4717-9dd9-1a55761d3ef7',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 19.42},
#   'step': 3000},
#  {'batch_size': 4,
#   'checkpoint_every_n': 250,
#   'create_date': 1683194749747,
#   'data_type': 'bbox',
#   'epochs': 3000,
#   'flow_title': 'EfficientDet',
#   'learning_rate': 0.08,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 0.349,
#              'localization_loss': 0.009,
#              'regularization_loss': 0.03,
#              'total_loss': 0.388},
#   'metric_target': 'Loss/total_loss',
#   'mode_name': 'efficientdet-d1-640x640',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'momentum_optimizer',
#   'run_id': 'run_296bc99c-2e69-49f1-80d1-10fe4e2167ca',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 19.42},
#   'step': 750},
#  {'batch_size': 2,
#   'checkpoint_every_n': 250,
#   'create_date': 1683191834530,
#   'data_type': 'bbox',
#   'epochs': 5000,
#   'flow_title': 'Copy of Blood Cell Detector',
#   'learning_rate': 0.001,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 0.051,
#              'localization_loss': 9.473,
#              'total_loss': 19.39},
#   'metric_target': 'DetectionBoxes_Precision/mAP',
#   'mode_name': 'yolov4-darknet-320x320',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'adam',
#   'run_id': 'run_190786fa-975e-4031-bc1c-733f92475eed',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 19.42},
#   'step': 20},
#  {'batch_size': 2,
#   'checkpoint_every_n': 250,
#   'create_date': 1683191821875,
#   'data_type': 'bbox',
#   'epochs': 5000,
#   'flow_title': 'YOLOX',
#   'learning_rate': 0.001,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 0.68,
#              'localization_loss': 2.267,
#              'total_loss': 4.555},
#   'metric_target': 'DetectionBoxes_Precision/mAP',
#   'mode_name': 'yolox-small-320x320',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'adam',
#   'run_id': 'run_23d1566f-d024-4450-8625-f93232cbe0f3',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 19.42},
#   'step': 20},
#  {'batch_size': 2,
#   'checkpoint_every_n': 250,
#   'create_date': 1682329224099,
#   'data_type': 'bbox',
#   'epochs': 3000,
#   'flow_title': 'MobileNet',
#   'learning_rate': 0.08,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 0.296,
#              'localization_loss': 0.166,
#              'regularization_loss': 0.147,
#              'total_loss': 0.609},
#   'metric_target': 'DetectionBoxes_Precision/mAP',
#   'mode_name': 'retina-mobilenetv2-320x320',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'momentum_optimizer',
#   'run_id': 'run_d41b904b-20a3-4605-9d55-1fbf60ca34a4',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 19.42},
#   'step': 3000},
#  {'batch_size': 4,
#   'checkpoint_every_n': 250,
#   'create_date': 1682063049129,
#   'data_type': 'bbox',
#   'epochs': 3000,
#   'flow_title': 'Blood Cell Detector',
#   'learning_rate': 0.08,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 0.537,
#              'localization_loss': 0.005,
#              'regularization_loss': 0.031,
#              'total_loss': 0.573},
#   'metric_target': 'STRAT_ALWAYS_SAVE_LATEST',
#   'mode_name': 'efficientdet-d1-640x640',
#   'momentum': 0.9,
#   'num_classes': 3,
#   'optimizer': 'momentum_optimizer',
#   'run_id': 'run_6296ef1f15462575f578ab1f',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.2,
#   'statistic': {'average_annotations': 13.2},
#   'step': 3000}]

# %% [markdown]
# ## 4.4. Retrieve Project's Quota

# %% [markdown]
# Retrieves the different quotas limit and usage in a project.

# %%
# Retrieves the quotas in the project
project_quota_response = datature.Project.quota()

# Display response from the retrival of project's quota operation
pprint(project_quota_response)
# Out:
# {'limit': {'artifact': 50,
#            'artifact_export': 50,
#            'collaborator': 10,
#            'compute': 5000,
#            'external_source': 5,
#            'image': 10000,
#            'intellibrush': 5000,
#            'octopod_cpu': 24,
#            'octopod_gpu': 6},
#  'usage': {'artifact': 33,
#            'artifact_export': 1,
#            'collaborator': 6,
#            'compute': 15,
#            'external_source': 1,
#            'image': 6624,
#            'intellibrush': 20,
#            'octopod_cpu': 8,
#            'octopod_gpu': 1}}

# %% [markdown]
# ## 4.5. Retrieve Project's Users

# %% [markdown]
# Retrieves all users in a project. This includes the metadata related to the individual users including the access type of the different users.

# %%
# Retrieves the quotas in the project
project_users_response = datature.Project.users()

# Display response from the retrival of project's quota operation
pprint(project_users_response)
# Out:
# [{'access_type': 'owner',
#   'email': 'weiloon@datature.io',
#   'id': 'user_637de790b14339458e9f7a73',
#   'nickname': 'weiloon',
#   'object': 'user',
#   'picture': 'https://s.gravatar.com/avatar/260041a626f152daac6980a88a9176b6?s=480&r=pg&d=https%3A%2F%2Fcdn.auth0.com%2Favatars%2Fwe.png'},
#  {'access_type': 'collaborator',
#   'email': 'john@datature.io',
#   'id': 'user_6450c26bff2c33b9cecee6e4',
#   'nickname': 'john',
#   'object': 'user',
#   'picture': 'https://s.gravatar.com/avatar/e538d21562e631eca4edc7b8a6a8dab6?s=480&r=pg&d=https%3A%2F%2Fcdn.auth0.com%2Favatars%2Fjo.png'},
#  {'access_type': 'collaborator',
#   'email': 'roger@datature.io',
#   'id': 'user_64af7a1abec1f0637babeb59',
#   'nickname': 'roger',
#   'object': 'user',
#   'picture': 'https://s.gravatar.com/avatar/5e8ffba247f244cd805dd6d48c20ad8d?s=480&r=pg&d=https%3A%2F%2Fcdn.auth0.com%2Favatars%2Fro.png'}]

# %% [markdown]
# # 5. Asset API

# %% [markdown]
# This section describes how to perform any operations with regards to the assets in the project. The assets refer to the images and videos in general.

# %% [markdown]
# ## 5.1. List All Assets

# %% [markdown]
# List all the assets that are present in the project. The assets listed will include the metadata pertaining to each of the asset that is present in the project itself.
#
#
# **Note that the assets are paginated, meaning calling the list will not list all objects at once. The max `limit` that can be set for asset retrieval is `100`.**

# %%
# Retrieves the first page of the assets present in the project
asset_list_response = datature.Asset.list({"limit": 5})

# Display response from the retrieval of the assets for the first page
pprint(asset_list_response)
# Out:
# {'data': [{'create_date': 1682063031519,
#            'filename': '12.jpg',
#            'id': 'asset_8f2b3898-b00a-4b2b-801c-afacf202e0a4',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 20905,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 3,
#                          'tags_count': [{'count': 2, 'name': 'Platelets'},
#                                         {'count': 1, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/12.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T064241Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063036235816&X-Goog-Signature=...'},
#           {'create_date': 1682063031519,
#            'filename': '26.jpg',
#            'id': 'asset_10d30d0b-6ca2-4d87-9d26-6148dcfe1fc2',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 22021,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 1,
#                          'tags_count': [{'count': 1, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/26.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T064241Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063036183142&X-Goog-Signature=...'},
#           {'create_date': 1682063031519,
#            'filename': '10.jpg',
#            'id': 'asset_23713306-a079-42c7-93f0-621ab5305add',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 23709,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 2,
#                          'tags_count': [{'count': 2, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/10.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T064241Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063036183451&X-Goog-Signature=...'},
#           {'create_date': 1682063031519,
#            'filename': '6.jpg',
#            'id': 'asset_6a871340-fb7a-4530-98ce-70aef30f8b54',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 21323,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 4,
#                          'tags_count': [{'count': 3, 'name': 'Platelets'},
#                                         {'count': 1, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/6.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T064241Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063035623995&X-Goog-Signature=...'},
#           {'create_date': 1682063031519,
#            'filename': '25.jpg',
#            'id': 'asset_eec2f52a-3814-479e-a2ae-2539d8793bc2',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 21128,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 3,
#                          'tags_count': [{'count': 2, 'name': 'Platelets'},
#                                         {'count': 1, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/25.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T064241Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063035605845&X-Goog-Signature=...'}],
#  'next_page': 'T2YAGDY0NDIzZWI3YWVhYTU3YjBjYTlhM2Q1NwAYNjQ0MjNlYjdhZWFhNTdiMGNhOWEzZDU3'}

# %% [markdown]
# As there are limits set for listing of assets, to list the next batch of assets, simply retrieve the value from the `'next_page'` key and reuse the above method again.

# %%
# Retrieves the next page of the assets present in the project using the earlier list response
# This is to retrieve the page id to be passed into the body parameters
asset_list_next_response = datature.Asset.list(
    {
        "limit": 5,
        "page": asset_list_response['next_page'],
    }, )

# Display response from the retrieval of the assets for the next page
pprint(asset_list_next_response)
# Out:
# {'data': [{'create_date': 1682063031519,
#            'filename': '43.jpg',
#            'id': 'asset_76b19a95-8a16-4a87-8c54-4e633120b9b3',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 21074,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 2,
#                          'tags_count': [{'count': 1, 'name': 'Platelets'},
#                                         {'count': 1, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/43.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T064241Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063036367204&X-Goog-Signature=...'},
#           {'create_date': 1682063031520,
#            'filename': '0.jpg',
#            'id': 'asset_d0f1f7f7-5afa-419a-8da1-91d1ad0c6820',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 23286,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 0, 'tags_count': []},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/0.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T100649Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1694167597780503&X-Goog-Signature=...'},
#           {'create_date': 1682063031520,
#            'filename': '8.jpg',
#            'id': 'asset_b2aa5135-cdfb-4737-9789-318d8f419e2a',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 22821,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 1,
#                          'tags_count': [{'count': 1, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/8.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T094318Z&X-Goog-Expires=86401&X-Goog-SignedHeaders=host&generation=1682063037385001&X-Goog-Signature=...'},
#           {'create_date': 1682063031520,
#            'filename': '15.jpg',
#            'id': 'asset_9f8d4206-131e-4b1d-a2c2-d21e827be868',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 20986,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 2,
#                          'tags_count': [{'count': 1, 'name': 'Platelets'},
#                                         {'count': 1, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/15.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T094318Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063037501258&X-Goog-Signature=...'},
#           {'create_date': 1682063031520,
#            'filename': '29.jpg',
#            'id': 'asset_716da93e-78a1-4374-ab40-9ccc211c930a',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 20960,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 6,
#                          'tags_count': [{'count': 4, 'name': 'Platelets'},
#                                         {'count': 2, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/29.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T094317Z&X-Goog-Expires=86401&X-Goog-SignedHeaders=host&generation=1682063037723918&X-Goog-Signature=...'}],
#  'next_page': 'T2YAGDY0NDIzZWI3YWVhYTU3YjBjYTlhM2Q2ZQAYNjQ0MjNlYjdhZWFhNTdiMGNhOWEzZDZl',
#  'prev_page': 'T2IAGDY0NDIzZWI3YWVhYTU3YjBjYTlhM2Q1NwAYNjQ0MjNlYjdhZWFhNTdiMGNhOWEzZDU3'}

# %% [markdown]
# Likewise, if there is a need to navigate back to the previous page, simply retrieve the value from the `'prev_page'` key and reuse the above method again. With reference to the example in this section, the output of this code block will be the same as the very first code block demonstrating this API.

# %%
# Retrieves the previous page of the assets present in the project using the earlier list response
# This is to retrieve the page id to be passed into the body parameters
asset_list_prev_response = datature.Asset.list(
    {
        "limit": 5,
        "page": asset_list_response['prev_page'],
    }, )

# Display response from the retrieval of the assets for the previous page
pprint(asset_list_prev_response)
# Out:
# {'data': [{'create_date': 1682063031519,
#            'filename': '12.jpg',
#            'id': 'asset_8f2b3898-b00a-4b2b-801c-afacf202e0a4',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 20905,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 3,
#                          'tags_count': [{'count': 2, 'name': 'Platelets'},
#                                         {'count': 1, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/12.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T064241Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063036235816&X-Goog-Signature=...'},
#           {'create_date': 1682063031519,
#            'filename': '26.jpg',
#            'id': 'asset_10d30d0b-6ca2-4d87-9d26-6148dcfe1fc2',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 22021,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 1,
#                          'tags_count': [{'count': 1, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/26.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T064241Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063036183142&X-Goog-Signature=...'},
#           {'create_date': 1682063031519,
#            'filename': '10.jpg',
#            'id': 'asset_23713306-a079-42c7-93f0-621ab5305add',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 23709,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 2,
#                          'tags_count': [{'count': 2, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/10.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T064241Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063036183451&X-Goog-Signature=...'},
#           {'create_date': 1682063031519,
#            'filename': '6.jpg',
#            'id': 'asset_6a871340-fb7a-4530-98ce-70aef30f8b54',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 21323,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 4,
#                          'tags_count': [{'count': 3, 'name': 'Platelets'},
#                                         {'count': 1, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/6.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T064241Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063035623995&X-Goog-Signature=...'},
#           {'create_date': 1682063031519,
#            'filename': '25.jpg',
#            'id': 'asset_eec2f52a-3814-479e-a2ae-2539d8793bc2',
#            'metadata': {'custom_metadata': {},
#                         'file_size': 21128,
#                         'groups': ['main'],
#                         'height': 480,
#                         'mime_type': 'image/jpeg',
#                         'status': 'annotated',
#                         'width': 640},
#            'object': 'asset',
#            'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#            'statistic': {'annotation_total': 3,
#                          'tags_count': [{'count': 2, 'name': 'Platelets'},
#                                         {'count': 1, 'name': 'new tag name'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/25.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T064241Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063035605845&X-Goog-Signature=...'}],
#  'next_page': 'T2YAGDY0NDIzZWI3YWVhYTU3YjBjYTlhM2Q1NwAYNjQ0MjNlYjdhZWFhNTdiMGNhOWEzZDU3'}

# %% [markdown]
# ## 5.3. Create An Upload Session

# %% [markdown]
# Create an upload session. This is required to upload assets to the platform itself. For the types of assets that can be uploaded, both **images (`.PNG`, `.JPG`, `.JPEG`)** and **videos (`.MP4`)** are allowed to be uploaded.

# %%
# Instantiate an upload session
upload_session = datature.Asset.upload_session()

# %% [markdown]
# Once the session is created, simply run a loop to add all your desired files to be uploaded and start the upload

# %%
# Retrieve all filepaths of assets to be uploaded
filepaths = glob.glob("./sdk-guides/img/*")

# For loop to add the assets to be uploaded
for filepath in filepaths:
    upload_session.add(filepath)
    
# Execute the upload once all the specified assets to be uploaded have been added
asset_upload_session_start_response = upload_session.start(background=True)

# Display response of the asset upload operation
pprint(asset_upload_session_start_response)
# Out:
# {'op_link': 'users/api|957e4e69-e753-4dde-af0c-4c838cc93cdd/projects/2c2fc3676574f13413ecdf5a1ccf1473/operations/nexus.assets.upload/581579d5-1954-4ddc-a468-cd11ed1e45a5'}

# %% [markdown]
# To check on the status of the upload, simply use the `op_link` value from the response and call the retrieve operation API. To know more on how to use it, refer to [here](#7.1.-Retrieve-An-Operation).

# %%
# Retrieve the status for the asset upload operation
retrieve_asset_upload_operation_response = datature.Operation.retrieve(
    asset_upload_session_start_response['op_link']
)
# Display response of the asset upload status retrieval operation
pprint(retrieve_asset_upload_operation_response)
# Out:
# {'id': 'op_581579d5-1954-4ddc-a468-cd11ed1e45a5',
#  'object': 'operation',
#  'op_link': 'users/api|957e4e69-e753-4dde-af0c-4c838cc93cdd/projects/2c2fc3676574f13413ecdf5a1ccf1473/operations/nexus.assets.upload/581579d5-1954-4ddc-a468-cd11ed1e45a5',
#  'status': {'message': 'Operation running',
#             'overview': 'Running',
#             'progress': {'unit': 'asset',
#                          'with_status': {'cancelled': 0,
#                                          'errored': 0,
#                                          'finished': 0,
#                                          'queued': 5,
#                                          'running': 0}},
#             'time_scheduled': 1694169574409,
#             'time_updated': 1694169575811}}

# %% [markdown]
# ## 5.3. Retrieve An Asset

# %% [markdown]
# Retrieves an asset based on the specified asset id. This returns the metadata related to the specified asset which also includes an overview of the annotations present in the asset itself.

# %%
# Retrieve an asset based on the specified asset id
asset_retrieve_response = datature.Asset.retrieve(
    asset_list_response["data"][0]["id"])

# Display response of the retrieve asset operation
pprint(asset_retrieve_response)
# Out:
# {'create_date': 1682063031519,
#  'filename': '12.jpg',
#  'id': 'asset_8f2b3898-b00a-4b2b-801c-afacf202e0a4',
#  'metadata': {'custom_metadata': {},
#               'file_size': 20905,
#               'groups': ['main'],
#               'height': 480,
#               'mime_type': 'image/jpeg',
#               'status': 'annotated',
#               'width': 640},
#  'object': 'asset',
#  'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'statistic': {'annotation_total': 3,
#                'tags_count': [{'count': 2, 'name': 'Platelets'},
#                               {'count': 1, 'name': 'new tag name'}]},
#  'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/12.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T064241Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063036235816&X-Goog-Signature=...'}

# %% [markdown]
# ## 5.4. Update An Asset Status

# %% [markdown]
# Updates the specified asset's metadata based on the values of the parameters specified. Currently this only allows the update of the asset's `status`. Currently the allowed `status` are 'annotated', 'review', 'completed' and 'tofix'

# %%
# Modify the specified asset's metadata
asset_modify_response = datature.Asset.modify(
    asset_list_response["data"][0]["id"], asset_meta={"status": "annotated"})

# Display response of the modification of the specified asset's metadata
pprint(asset_modify_response)
# Out:
# {'create_date': 1682063031519,
#  'filename': '12.jpg',
#  'id': 'asset_8f2b3898-b00a-4b2b-801c-afacf202e0a4',
#  'metadata': {'custom_metadata': {},
#               'file_size': 20905,
#               'groups': ['main'],
#               'height': 480,
#               'mime_type': 'image/jpeg',
#               'status': 'annotated',
#               'width': 640},
#  'object': 'asset',
#  'project': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'statistic': {'annotation_total': 3,
#                'tags_count': [{'count': 2, 'name': 'Platelets'},
#                               {'count': 1, 'name': 'new tag name'}]},
#  'url': 'https://storage.googleapis.com/assets.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/assets/12.jpg?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T064241Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1682063036235816&X-Goog-Signature=...'}

# %% [markdown]
# ## 5.5. Delete An Asset

# %% [markdown]
# Deletes an asset based on the specified asset id. Annotations related to this asset will also be deleted when this operation is executed.

# %%
# Delete the asset from the specified asset id
asset_delete_response = datature.Asset.delete(
    asset_list_response["data"][0]["id"])

# Display the response of the asset deletion operation
pprint(asset_delete_response)
# Out:
# {'deleted': True,
#  'id': 'asset_8f2b3898-b00a-4b2b-801c-afacf202e0a4',
#  'object': 'asset'}

# %% [markdown]
# # 6. Annotation API

# %% [markdown]
# This section describes how to perform any operations with regards to the annotations. Annotations are the labels that bounds and describes the objects of interest in the assets which are the images and videos themselves.

# %% [markdown]
# ## 6.1. Create An Annotation

# %% [markdown]
# Create a single annotation for the specified id. The annotation can either be `rectangle` and `polygon` for the `bound_type`.
#
# For the `bound_type` of `rectangle`, the format is as follows:
#
# `[ [xmin, ymin], [xmin, ymax], [xmax, ymax], [xmax, ymin] ]`
#
# For the `bound_type` of `polygon`, the format is as follows:
#
# `[ [x1, y1], [x2, y2], [x3, y3], ..., [xn, yn] ]`

# %%
# Create a new annotation for the specified asset id
annotation_create_response = datature.Annotation.create(
    {
        "asset_id": asset_list_response["data"][-1]["id"],
        "tag": "RBC",
        "bound_type": "rectangle",
        "bound": [
            [0.775, 0.500],
            [0.775, 0.710],
            [0.858, 0.710],
            [0.858, 0.500],
        ]
    }, )

# Display response of the creation of the annotation for the specified asset id
pprint(annotation_create_response)
# Out:
# {'asset_id': 'asset_eec2f52a-3814-479e-a2ae-2539d8793bc2',
#  'bound': [[0.775, 0.5], [0.775, 0.71], [0.858, 0.71], [0.858, 0.5]],
#  'bound_type': 'rectangle',
#  'id': 'annot_e8c87151-4f68-4402-9ede-75d50ad0224a',
#  'object': 'annotation',
#  'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'tag': 'RBC'}

# %% [markdown]
# ## 6.2. Export Annotations

# %% [markdown]
# Execute an export operation for the current set of annotations that are present on the project itself. Note that this starts the operation of the export and does not return the exported file directly.
#
# Current allow exported annotations formats are:
#
# `'csv_fourcorner', 'csv_widthheight', 'coco', 'pascal_voc', 'yolo_keras_pytorch', 'yolo_darknet', 'polygon_single', 'polygon_coco'`
#
# Please refer to the developer's documentation for more information about the different annotation formats as well as the description of the different configuration parameters.

# %%
# Request to start the export of the current annotations in the project
annotation_export_response = datature.Annotation.export(
    "csv_fourcorner",
    {
        "normalized": True,
        "shuffle": True,
        "split_ratio": 0.5,
        "seed": 1337
    },
    background=True,
)

# Display response from the export of the current annotations operation
pprint(annotation_export_response)
# Out:
# {'id': 'op_dcb9e7f0-7bb2-43d1-a3ae-8056f7788f3d',
#  'object': 'operation',
#  'op_link': 'users/api|957e4e69-e753-4dde-af0c-4c838cc93cdd/projects/2c2fc3676574f13413ecdf5a1ccf1473/operations/nexus.annotations.export/dcb9e7f0-7bb2-43d1-a3ae-8056f7788f3d',
#  'status': {'message': 'Operation queued',
#             'overview': 'Queued',
#             'progress': {'unit': 'whole operation',
#                          'with_status': {'cancelled': 0,
#                                          'errored': 0,
#                                          'finished': 0,
#                                          'queued': 1,
#                                          'running': 0}},
#             'time_scheduled': 1694169608722,
#             'time_updated': 1694169608722}}

# %% [markdown]
# To track the status of the annotations export operation, simply use the `op_link` value from the response and call the retrieve operation API. To know more on how to use it, refer to [here](#7.1.-Retrieve-An-Operation).

# %%
# Retrieve the status for the export annotation operation
retrieve_export_annotation_operation_response = datature.Operation.retrieve(
    annotation_export_response['op_link'])

# Display response of the export annotation status retrieval operation
pprint(retrieve_export_annotation_operation_response)
# Out:
# {'id': 'op_dcb9e7f0-7bb2-43d1-a3ae-8056f7788f3d',
#  'object': 'operation',
#  'op_link': 'users/api|957e4e69-e753-4dde-af0c-4c838cc93cdd/projects/2c2fc3676574f13413ecdf5a1ccf1473/operations/nexus.annotations.export/dcb9e7f0-7bb2-43d1-a3ae-8056f7788f3d',
#  'status': {'message': 'Operation running',
#             'overview': 'Running',
#             'progress': {'unit': 'whole operation',
#                          'with_status': {'cancelled': 0,
#                                          'errored': 0,
#                                          'finished': 0,
#                                          'queued': 0,
#                                          'running': 1}},
#             'time_scheduled': 1694169608722,
#             'time_updated': 1694169609480}}

# %% [markdown]
# ## 6.3. Retrieve Exported Annotations File

# %% [markdown]
# Retrieves the url of the exported annotation file. Do note that this requires the previous code block above to be executed first to retrieve the related operation id to retrieve the download url for annotation file once the export is done. Retrieval of exported annotations is referenced by the `operation id` that executed the export of the annotations.

# %%
# Retrieve the url to download the exported annotations
annotation_retrieve_exported_file_response = datature.Annotation.retrieve_exported_file(
    retrieve_export_annotation_operation_response["id"])

# Display response of the retrieval of the download url for the exported annotations operation
pprint(annotation_retrieve_exported_file_response)
# Out:
# {'download': {'expiry': 1694256015937,
#               'method': 'GET',
#               'url': 'https://storage.googleapis.com/exports.datature.io/2c2fc3676574f13413ecdf5a1ccf1473/annotations/dcb9e7f0-7bb2-43d1-a3ae-8056f7788f3d.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=puppeteer-production%40datature-puppeteer.iam.gserviceaccount.com%2F20230908%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230908T104015Z&X-Goog-Expires=86401&X-Goog-SignedHeaders=host&X-Goog-Signature=...'},
#  'op_id': 'op_dcb9e7f0-7bb2-43d1-a3ae-8056f7788f3d',
#  'status': 'Finished'}

# %% [markdown]
# To download the exported annotations, simply copy the value in the `url` from the above response and paste it in the address bar of the browser to trigger the download.

# %% [markdown]
# ## 6.4. Import Annotations

# %% [markdown]
# Uploads an annotation file to be used for the project. Currently the allowed formats are as follows:
#
# `'csv_fourcorner', 'csv_widthheight', 'coco', 'pascal_voc', 'yolo_keras_pytorch', 'yolo_darknet', 'polygon_single', 'polygon_coco'`
#
# Please refer to the docs for more information about the different annotation formats.

# %%
# Uploads an annotation file to be imported into the project
annotation_upload_response = datature.Annotation.upload(
    "coco",
    "sdk-guides/dump.json",
    background=True,
)

# Display response of the upload annotation to be imported operation
pprint(annotation_upload_response)
# Out:
# {'id': 'op_67731f03-0b69-46bc-9213-736863f72982',
#  'object': 'operation',
#  'op_link': 'users/api|957e4e69-e753-4dde-af0c-4c838cc93cdd/projects/2c2fc3676574f13413ecdf5a1ccf1473/operations/nexus.annotations.import/67731f03-0b69-46bc-9213-736863f72982',
#  'status': {'message': 'Operation queued',
#             'overview': 'Queued',
#             'progress': {'unit': 'whole operation',
#                          'with_status': {'cancelled': 0,
#                                          'errored': 0,
#                                          'finished': 0,
#                                          'queued': 1,
#                                          'running': 0}},
#             'time_scheduled': 1694169626329,
#             'time_updated': 1694169626329}}

# %% [markdown]
# To track the status of the annotations import operation, simply use the `op_link` value from the response and call the retrieve operation API. To know more on how to use it, refer to [here](#7.1.-Retrieve-An-Operation).

# %%
# Retrieve the status for the upload annotation for import operation
retrieve_upload_annotation_operation_response = datature.Operation.retrieve(
    annotation_upload_response['op_link'])

# Display response of the upload annotation for import status retrieval operation
pprint(retrieve_upload_annotation_operation_response)
# Out:
# {'id': 'op_67731f03-0b69-46bc-9213-736863f72982',
#  'object': 'operation',
#  'op_link': 'users/api|957e4e69-e753-4dde-af0c-4c838cc93cdd/projects/2c2fc3676574f13413ecdf5a1ccf1473/operations/nexus.annotations.import/67731f03-0b69-46bc-9213-736863f72982',
#  'status': {'message': 'Operation finished',
#             'overview': 'Finished',
#             'payload': 'Number of files imported: 1',
#             'progress': {'unit': 'whole operation',
#                          'with_status': {'cancelled': 0,
#                                          'errored': 0,
#                                          'finished': 1,
#                                          'queued': 0,
#                                          'running': 0}},
#             'time_scheduled': 1694169626329,
#             'time_updated': 1694169629550}}

# %% [markdown]
# ## 6.5. List All Annotations In An Asset

# %% [markdown]
# List all annotations based on the specified asset id. This will include the `bound` of the annotation as well as the `bound_type` and the `tag` of the annotations along with other metadata related to the annotations for the specified asset.

# %%
# List all annotations based on the specified asset id
annotation_list_response = datature.Annotation.list(
    asset_list_response["data"][-1]["id"])

# Display response of the list annotations for the specified asset operation
pprint(annotation_list_response)
# Out:
# [{'asset_id': 'asset_eec2f52a-3814-479e-a2ae-2539d8793bc2',
#   'bound': [[0.228125, 0.3666666666666667],
#             [0.228125, 0.4395833333333333],
#             [0.290625, 0.4395833333333333],
#             [0.290625, 0.3666666666666667]],
#   'bound_type': 'rectangle',
#   'id': 'annot_61d3520b-6db1-4042-b308-41b6b72a9727',
#   'object': 'annotation',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'tag': 'Platelets'},
#  {'asset_id': 'asset_eec2f52a-3814-479e-a2ae-2539d8793bc2',
#   'bound': [[0.440625, 0.04166666666666663],
#             [0.440625, 0.11458333333333337],
#             [0.503125, 0.11458333333333337],
#             [0.503125, 0.04166666666666663]],
#   'bound_type': 'rectangle',
#   'id': 'annot_ab1ca432-df6a-4af3-9de8-396fc2d96302',
#   'object': 'annotation',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'tag': 'Platelets'},
#  {'asset_id': 'asset_eec2f52a-3814-479e-a2ae-2539d8793bc2',
#   'bound': [[0.6046875, 0.7875],
#             [0.6046875, 0.9979166666666667],
#             [0.88125, 0.9979166666666667],
#             [0.88125, 0.7875]],
#   'bound_type': 'rectangle',
#   'id': 'annot_ff33e3ea-9d2f-4699-992d-7cb62c303273',
#   'object': 'annotation',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'tag': 'new tag name'},
#  {'asset_id': 'asset_eec2f52a-3814-479e-a2ae-2539d8793bc2',
#   'bound': [[0.775, 0.5], [0.775, 0.71], [0.858, 0.71], [0.858, 0.5]],
#   'bound_type': 'rectangle',
#   'id': 'annot_e8c87151-4f68-4402-9ede-75d50ad0224a',
#   'object': 'annotation',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'tag': 'RBC'}]

# %% [markdown]
# ## 6.6. Retrieve An Annotation

# %% [markdown]
# Retrieves an annotation based on the specified annotation id. This returns the metadata regarding the specified annotation id like the `bound` as well as the `bound_type` and `tag` along with other metadata related to the annotation.

# %%
# Retrieve the metadata for the specified annotation id
annotation_retrieve_response = datature.Annotation.retrieve(
    annotation_list_response[0]["id"])

# Display response for the retrieve annotation operation
pprint(annotation_retrieve_response)
# Out:
# {'asset_id': 'asset_eec2f52a-3814-479e-a2ae-2539d8793bc2',
#  'bound': [[0.228125, 0.3666666666666667],
#            [0.228125, 0.4395833333333333],
#            [0.290625, 0.4395833333333333],
#            [0.290625, 0.3666666666666667]],
#  'bound_type': 'rectangle',
#  'id': 'annot_61d3520b-6db1-4042-b308-41b6b72a9727',
#  'object': 'annotation',
#  'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'tag': 'Platelets'}

# %% [markdown]
# ## 6.7. Delete An Annotation

# %% [markdown]
# Delete an annotation based on the specified annotation id.

# %%
# Delete an annotation based on the specified annotation id
annotation_delete_response = datature.Annotation.delete(
    annotation_list_response[0]["id"])

# Display the response of the delete annotation operation
pprint(annotation_delete_response)
# Out:
# {'deleted': True,
#  'id': 'annot_61d3520b-6db1-4042-b308-41b6b72a9727',
#  'object': 'annotation'}

# %% [markdown]
# # 7. Operation API

# %% [markdown]
# This section describes how to keep track of any operations that is currently in progress on Nexus itself.

# %% [markdown]
# ## 7.1. Retrieve An Operation

# %% [markdown]
# Retrieves an operation based on the specified `op_link`. This should be the primary method to use if there is a need to keep track of any ongoing operations by polling the specified url using this method.

# %%
# Retrieve an operation based on the specified op_link
operation_retrieve_response = datature.Operation.retrieve(
    retrieve_upload_annotation_operation_response['op_link'])

# Display response of the retrieve operation
pprint(operation_retrieve_response)
# Out:
# {'id': 'op_67731f03-0b69-46bc-9213-736863f72982',
#  'object': 'operation',
#  'op_link': 'users/api|957e4e69-e753-4dde-af0c-4c838cc93cdd/projects/2c2fc3676574f13413ecdf5a1ccf1473/operations/nexus.annotations.import/67731f03-0b69-46bc-9213-736863f72982',
#  'status': {'message': 'Operation finished',
#             'overview': 'Finished',
#             'payload': 'Number of files imported: 1',
#             'progress': {'unit': 'whole operation',
#                          'with_status': {'cancelled': 0,
#                                          'errored': 0,
#                                          'finished': 1,
#                                          'queued': 0,
#                                          'running': 0}},
#             'time_scheduled': 1694169626329,
#             'time_updated': 1694169629550}}

# %% [markdown]
# Poll the operation using a loop with a specified delay interval.

# %%
while datature.Operation.retrieve(
        retrieve_upload_annotation_operation_response['op_link']
)["status"]["overview"] != "Finished":
    time.sleep(5)
print("Operation completed!")
# Out:
# Operation completed!

# %% [markdown]
# # 8. Tag API

# %% [markdown]
# This section describes the operations to be used to perform any operations with regards to the tags in the project. Tags are the name of labels (e.g. boat) to represent the annotations.

# %% [markdown]
# ## 8.1. Create A Tag

# %% [markdown]
# Creates a tag to be added to the project based on the specified `name` to allocate to the new tag.

# %%
# Create a new tag with the specified tag name
tag_create_response = datature.Tag.create("new tag name")

# Display response for the create tag operation
pprint(tag_create_response)
# Out:
# [{'index': 0, 'name': 'Platelets'},
#  {'index': 2, 'name': 'WBC'},
#  {'index': 4, 'name': 'RBC'},
#  {'index': 5, 'name': 'new tag name'}]

# %% [markdown]
# ## 8.2. List All Tags

# %% [markdown]
# List all tags that exist in the project.

# %%
# List all tags in the project
tag_list_response = datature.Tag.list()

# Display response for listing all tags in the project operation
pprint(tag_list_response)
# Out:
# [{'index': 0, 'name': 'Platelets'},
#  {'index': 2, 'name': 'WBC'},
#  {'index': 4, 'name': 'RBC'},
#  {'index': 5, 'name': 'new tag name'}]

# %% [markdown]
# ## 8.3. Update A Tag

# %% [markdown]
# Updates the metadata of a tag object. Currently only `name` is allowed to be modified. Note that the to specify the tag to be modified, please reference the `index` of the tag to be modified as it is used by this method.

# %%
# Modify the metadata of the tag based on the specified index
tag_modify_response = datature.Tag.modify(index=0, name="modified tag name")

# Display response for the modification of tag operation
pprint(tag_modify_response)
# Out:
# [{'index': 0, 'name': 'modified tag name'},
#  {'index': 2, 'name': 'WBC'},
#  {'index': 4, 'name': 'RBC'},
#  {'index': 5, 'name': 'new tag name'}]

# %% [markdown]
# ## 8.4. Delete A Tag

# %% [markdown]
# Delete a tag based on the specified index.

# %%
# Delete a tag based on the specified index
tag_delete_response = datature.Tag.delete(index=0)

# Display response for the delete tag operation
pprint(tag_delete_response)
# Out:
# {'deleted': True}

# %% [markdown]
# # 9. Workflow API

# %% [markdown]
# This section contains all the operations with regards to the workflows. Workflows are the model training pipelines that are built by different building blocks.

# %% [markdown]
# ## 9.1. List All Workflows

# %% [markdown]
# List all workflows in the project itself. The returned workflows will include the metadata related to each of the workflows themselves.

# %%
# List all the workflows that exist in the project
workflow_list_response = datature.Workflow.list()

# Display response for the list all workflow operation
pprint(workflow_list_response)
# Out:
# [{'id': 'flow_64893ef311c478ae88892823',
#   'last_updated': 1687778743912,
#   'object': 'workflow',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'state': '[{"id":"11833b3d-a445-4f08-acdb-ba477780470f","type":"dataset","basetype":"dataset","data":{"schema":{"title":"Dataset","hasSource":false,"hasDestination":true,"subtitle":{"targetparam":"dataset_setup","targetarg":"train_test_split","template":"Train-Test '
#            'Split %% Ratio"},"parameters":{"dataset_setup":{"name":"Dataset '
#            'Setup","args":{"train_test_split":{"name":"Train-Test '
#            'Split","type":"float","value":"0.2","default":0.3},"shuffle":{"name":"Shuffle '
#            'Dataset","type":"boolean","value":true,"default":true},"random_seed":{"name":"Random '
#            'Seed","type":"number","value":0,"default":0}}}}}},"position":{"x":840,"y":195},"__rf":{"position":{"x":840,"y":195},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":null},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none","opacity":"100%"}},{"id":"65d6690c-2d32-450d-a09d-de9a142c364f","type":"augmentation","basetype":"augmentation","data":{"schema":{"title":"Augmentations","hasSource":true,"hasDestination":true,"subtitle":{"targetparam":"options","targetarg":"advanced_mode","template":"Advanced '
#            'Mode : '
#            '%%"},"parameters":{"options":{"name":"Options","args":{"advanced_mode":{"name":"Advanced '
#            'Mode","type":"boolean","value":true,"default":false}}},"position_transforms":{"name":"Random '
#            'Position Augmentations","args":{"center_crop":{"name":"Center '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height Of The Crop '
#            '(1%-100%)"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width Of The Crop '
#            '(1%-100%)"}}}},"random_horizontal_flip":{"name":"Flip '
#            'Horizontal","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"random_vertical_flip":{"name":"Flip '
#            'Vertical","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"}}}},"random_crop":{"name":"Random '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height Of The '
#            'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width Of The Crop"}}}},"random_rotate":{"name":"Random '
#            'Rotate","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_rotation":{"name":"Minimum '
#            'Rotation","value":-90,"default":-90,"min":-180,"max":180,"tooltip":"Minimum '
#            'Rotation Angle"},"max_rotation":{"name":"Maximum '
#            'Rotation","value":90,"default":90,"min":-180,"max":180,"tooltip":"Maximum '
#            'Rotation '
#            'Angle"}}},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_rotation":{"name":"Minimum '
#            'Rotation","value":-90,"default":-90,"min":-180,"max":180,"tooltip":"Minimum '
#            'Rotation Angle"},"max_rotation":{"name":"Maximum '
#            'Rotation","value":90,"default":90,"min":-180,"max":180,"tooltip":"Maximum '
#            'Rotation Angle"}}}},"random_resized_crop":{"name":"Random Resized '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height Of The '
#            'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width Of The Crop"},"min_scale":{"name":"Minimum '
#            'Scale","value":0.08,"default":0.08,"min":0,"max":1,"tooltip":"Minimum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"max_scale":{"name":"Maximum '
#            'Scale","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"min_aspect_ratio":{"name":"Minimum Aspect '
#            'Ratio","value":0.75,"default":0.75,"min":0.1,"max":10,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"max_aspect_ratio":{"name":"Maximum Aspect '
#            'Ratio","value":1.33,"default":1.33,"min":0.1,"max":10,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"}}}},"random_sized_crop":{"name":"Random Sized '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_height":{"name":"Minimum Crop '
#            'Size '
#            'Height","value":50,"default":50,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Minimum Crop Size Limit"},"max_height":{"name":"Maximum '
#            'Crop Size '
#            'Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Maximum Crop Size '
#            'Height"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height After The Crop And '
#            'Resize"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width After The Crop And '
#            'Resize"},"w2h_ratio":{"name":"Width to Height '
#            'Ratio","value":1,"default":1,"min":0.1,"max":1,"tooltip":"Aspect '
#            'Ratio of Crop"}}}},"shift_scale_rotate":{"name":"Shift Scale '
#            'Rotate","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_shift":{"name":"Minimum '
#            'Shift","value":-0.0625,"default":-0.0625,"min":-1,"max":1,"tooltip":"Minimum '
#            'Range Of Shift Factor For Height And '
#            'Width"},"max_shift":{"name":"Maximum '
#            'Shift","value":0.0625,"default":0.0625,"min":-1,"max":1,"tooltip":"Maximum '
#            'Range Of Shift Factor For Height And '
#            'Width"},"min_scale":{"name":"Minimum '
#            'Scale","value":-0.1,"default":-0.1,"min":-2,"max":2,"tooltip":"Minimum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"max_scale":{"name":"Maximum '
#            'Scale","value":0.1,"default":0.1,"min":-2,"max":2,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"min_rotation":{"name":"Minimum '
#            'Rotation","value":-45,"default":-45,"min":-360,"max":360,"tooltip":"Minimum '
#            'Rotation Angle"},"max_rotation":{"name":"Maximum '
#            'Rotation","value":45,"default":45,"min":-360,"max":360,"tooltip":"Maximum '
#            'Rotation Angle"}}}}}},"color_transforms":{"name":"Color Space '
#            'Augmentations","args":{"channel_dropout":{"name":"Channel '
#            'Dropout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"min_channel_dropout_range":{"name":"Min Channel '
#            'Dropout '
#            'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Minimum '
#            'Channel Dropout Limit That Should Be Used For This '
#            'Augmentation"},"max_channel_dropout_range":{"name":"Max Channel '
#            'Dropout '
#            'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Maximum '
#            'Channel Dropout Limit That Should Be Used For This '
#            'Augmentation"},"fill_value":{"name":"Fill '
#            'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#            'Value For The Dropped '
#            'Channel"}}}},"channel_shuffle":{"name":"Channel '
#            'Shuffle","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"CLAHE":{"name":"CLAHE","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_clip_limit":{"name":"Min Clip '
#            'Limit","value":1,"default":1,"min":1,"max":100,"tooltip":"Lower '
#            'Threshold Value For Contrast '
#            'Limiting"},"max_clip_limit":{"name":"Max Clip '
#            'Limit","value":4,"default":4,"min":1,"max":100,"tooltip":"Upper '
#            'Threshold Value For Contrast '
#            'Limiting"},"min_tile_grid_size":{"name":"Min Grid '
#            'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Lower '
#            'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#            'Equalization"},"max_tile_grid_size":{"name":"Max Grid '
#            'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Upper '
#            'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#            'Equalization"}}}},"color_jitter":{"name":"Color '
#            'Jitter","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_brightness":{"name":"Min '
#            'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter '
#            'Brightness"},"max_brightness":{"name":"Max '
#            'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter '
#            'Brightness"},"min_contrast":{"name":"Min '
#            'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter Contrast"},"max_contrast":{"name":"Max '
#            'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter '
#            'Contrast"},"min_saturation":{"name":"Min '
#            'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter '
#            'Saturation"},"max_saturation":{"name":"Max '
#            'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter Saturation"},"min_hue":{"name":"Min '
#            'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter Hue"},"max_hue":{"name":"Max '
#            'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter '
#            'Hue"}}}},"cutout":{"name":"Cutout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"num_holes":{"name":"Number Of '
#            'Holes","value":8,"default":8,"min":0,"max":100,"tooltip":"Number '
#            'Of Regions To Zero Out"},"max_h_size":{"name":"Max Hole '
#            'Height","value":8,"default":8,"min":0,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Maximum Height Of The Hole."},"max_w_size":{"name":"Max '
#            'Hole '
#            'Width","value":8,"default":8,"min":0,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Maximum Width Of The Hole"},"fill_value":{"name":"Fill '
#            'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#            'Value For The Dropped '
#            'Channel"}}}},"equalize":{"name":"Equalize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"fancy_pca":{"name":"FancyPCA","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"alpha":{"name":"Alpha","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"How '
#            'Much To Pertub/Scale The Eigen Vectors And '
#            'Values"}}}},"gaussian_blur":{"name":"Gaussian '
#            'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_sigma":{"name":"Min Sigma '
#            'Minimum","value":0,"default":0,"min":0,"max":3,"tooltip":"Minimum '
#            'Gaussian Kernel Standard Deviation"},"max_sigma":{"name":"Max '
#            'Sigma '
#            'Minimum","value":3,"default":3,"min":0,"max":3,"tooltip":"Maximum '
#            'Gaussian Kernel Standard '
#            'Deviation"}}}},"gauss_noise":{"name":"Gaussian '
#            'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_var":{"name":"Min Variance '
#            'Range","value":10,"default":10,"min":0,"max":500,"tooltip":"Minimum '
#            'Variance Range For Noise"},"max_var":{"name":"Max Variance '
#            'Range","value":50,"default":50,"min":0,"max":500,"tooltip":"Maximum '
#            'Variance Range For '
#            'Noise"},"mean":{"name":"Mean","value":0,"default":0,"min":-100,"max":100,"tooltip":"Mean '
#            'Of The Noise"}}}},"glass_blur":{"name":"Glass '
#            'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"sigma":{"name":"Sigma","value":0.7,"default":0.7,"min":0,"max":3,"tooltip":"Standard '
#            'Deviation For Gaussian Kernel"},"max_delta":{"name":"Max '
#            'Delta","value":4,"default":4,"min":1,"max":10,"tooltip":"Max '
#            'Distance Between Pixels Which Are '
#            'Swapped"},"iterations":{"name":"Iterations","value":2,"default":2,"min":1,"max":10,"tooltip":"Number '
#            'Of '
#            'Repeats"}}}},"random_rgb_to_gray":{"name":"Grayscale","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"}}}},"hue_sat_val":{"name":"Hue '
#            'Saturation '
#            'Value","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_hue_shift":{"name":"Min Hue '
#            'Shift","value":-20,"default":-20,"min":-100,"max":100,"tooltip":"Minimum '
#            'Hue Shift Range Limit"},"max_hue_shift":{"name":"Max Hue '
#            'Shift","value":20,"default":20,"min":-100,"max":100,"tooltip":"Maximum '
#            'Hue Shift Range Limit"},"min_sat_shift":{"name":"Min Saturation '
#            'Shift","value":-30,"default":-30,"min":-100,"max":100,"tooltip":"Minimum '
#            'Saturation Shift Range Limit"},"max_sat_shift":{"name":"Max '
#            'Saturation '
#            'Shift","value":30,"default":30,"min":-100,"max":100,"tooltip":"Maximum '
#            'Saturation Shift Range Limit"},"min_val_shift":{"name":"Min Value '
#            'Shift","value":-20,"default":-20,"min":-100,"max":100,"tooltip":"Minimum '
#            'Value Shift Range Limit"},"max_val_shift":{"name":"Max Value '
#            'Shift","value":20,"default":20,"min":-100,"max":100,"tooltip":"Maximum '
#            'Value Shift Range Limit"}}}},"image_compression":{"name":"Image '
#            'Compression","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"quality_lower":{"name":"Lower '
#            'Quality '
#            'Limit","value":80,"default":80,"min":1,"max":100,"tooltip":"Lower '
#            'Bound On The Image Quality"},"quality_upper":{"name":"Upper '
#            'Quality '
#            'Limit","value":100,"default":100,"min":1,"max":100,"tooltip":"Upper '
#            'Bound On The Image Quality"}}}},"iso_noise":{"name":"ISO '
#            'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_color_shift":{"name":"Min '
#            'Color '
#            'Shift","value":0.01,"default":0.01,"min":0,"max":1,"tooltip":"Minimum '
#            'Variance Range For Color Hue '
#            'Change"},"max_color_shift":{"name":"Max Color '
#            'Shift","value":0.05,"default":0.05,"min":0,"max":1,"tooltip":"Maximum '
#            'Variance Range For Color Hue Change"},"min_intensity":{"name":"Min '
#            'Intensity","value":0.1,"default":0.1,"min":0,"max":2,"tooltip":"Minimum '
#            'Strength Of Color And Luminace '
#            'Noise"},"max_intensity":{"name":"Max '
#            'Intensity","value":0.5,"default":0.5,"min":0,"max":2,"tooltip":"Maximum '
#            'Strength Of Color And Luminace '
#            'Noise"}}}},"median_blur":{"name":"Median '
#            'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#            'Blur","value":7,"default":7,"min":7,"max":99,"tooltip":"Maximum '
#            'Aperture Linear Size For Blurring Input '
#            'Image"}}}},"motion_blur":{"name":"Motion '
#            'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#            'Blur","value":7,"default":7,"min":7,"max":100,"tooltip":"Maximum '
#            'Kernel Size For Blurring Input '
#            'Image"}}}},"multiplicative_noise":{"name":"Multiplicative '
#            'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_multi":{"name":"Min '
#            'Multiplication '
#            'Limit","value":0.9,"default":0.9,"min":0.1,"max":5,"tooltip":"Minimum '
#            'Random Number To Multiple With Input '
#            'Image"},"max_multi":{"name":"Max Multiplication '
#            'Limit","value":1.1,"default":1.1,"min":0.1,"max":5,"tooltip":"Maximum '
#            'Random Number To Multiple With Input '
#            'Image"}}}},"posterize":{"name":"Posterize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"r_bits":{"name":"R Channel Number '
#            'Of Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number '
#            'Of Bits For Red Channel"},"g_bits":{"name":"G Channel Number Of '
#            'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#            'Bits For Green Channel"},"b_bits":{"name":"B Channel Number Of '
#            'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#            'Bits For Blue Channel"}}}},"random_blur":{"name":"Random '
#            'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_blur_limit":{"name":"Min Blur '
#            'Limit","value":3,"default":3,"min":3,"max":100,"tooltip":"Minimum '
#            'Blur Limit That Should Be Used For This '
#            'Augmentation"},"max_blur_limit":{"name":"Max Blur '
#            'Limit","value":7,"default":7,"min":3,"max":100,"tooltip":"Maximum '
#            'Blur Limit That Should Be Used For This '
#            'Augmentation"}}}},"random_brightness":{"name":"Random '
#            'Brightness","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_limit":{"name":"Min '
#            'Brightness '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing Brightness"},"max_limit":{"name":"Max '
#            'Brightness '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Brightness"}}}},"random_brightness_contrast":{"name":"Random '
#            'Brightness '
#            'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_bright_limit":{"name":"Min '
#            'Brightness '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing '
#            'Brightness"},"max_bright_limit":{"name":"Max Brightness '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Brightness"},"min_contrast_limit":{"name":"Min Contrast '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing '
#            'Contrast"},"max_contrast_limit":{"name":"Max Contrast '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Contrast"}}}},"random_contrast":{"name":"Random '
#            'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_limit":{"name":"Min Contrast '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing Contrast"},"max_limit":{"name":"Max '
#            'Contrast '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Contrast"}}}},"random_fog":{"name":"Random '
#            'Fog","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"fog_coef_lower":{"name":"Lower '
#            'Coefficient '
#            'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#            'Limit For Fog Intensity '
#            'Coefficient"},"fog_coef_upper":{"name":"Upper Coefficient '
#            'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#            'Limit For Fog Intensity Coefficient"},"alpha_coef":{"name":"Alpha '
#            'Coefficient '
#            'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Transparency '
#            'Of Fog Circles"}}}},"random_gamma":{"name":"Random '
#            'Gamma","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_gamma_limit":{"name":"Min '
#            'Gamma '
#            'Limit","value":80,"default":80,"min":0,"max":200,"tooltip":"Minimum '
#            'Limit For Gamma Range"},"max_gamma_limit":{"name":"Max Gamma '
#            'Limit","value":120,"default":120,"min":0,"max":200,"tooltip":"Maximum '
#            'Limit For Gamma Range"}}}},"random_rain":{"name":"Random '
#            'Rain","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"slant_lower":{"name":"Lower '
#            'Slant","value":-10,"default":-10,"min":-20,"max":20,"tooltip":"Lower '
#            'Slant Of Rain Droplet"},"slant_upper":{"name":"Upper '
#            'Slant","value":10,"default":10,"min":-20,"max":20,"tooltip":"Upper '
#            'Slant Of Rain Droplet"},"drop_length":{"name":"Drop '
#            'Length","value":20,"default":20,"min":0,"max":100,"tooltip":"Length '
#            'Of Rain Droplet"},"drop_width":{"name":"Drop '
#            'Width","value":1,"default":1,"min":1,"max":5,"tooltip":"Width Of '
#            'Rain Droplet"},"drop_color_red":{"name":"Drop Color '
#            'Red","value":0,"default":0,"min":0,"max":255,"tooltip":"Red '
#            'Channel Rain Droplet"},"drop_color_green":{"name":"Drop Color '
#            'Green","value":0,"default":0,"min":0,"max":255,"tooltip":"Green '
#            'Channel Rain Droplet"},"drop_color_blue":{"name":"Drop Color '
#            'Blue","value":0,"default":0,"min":0,"max":255,"tooltip":"Blue '
#            'Channel Rain Droplet"},"blur_value":{"name":"Blur '
#            'Value","value":7,"default":7,"min":1,"max":15,"tooltip":"Blue '
#            'Channel Rain '
#            'Droplet"},"brightness_coefficient":{"name":"Brightness '
#            'Coefficient","value":0.7,"default":0.7,"min":0,"max":1,"tooltip":"Brightness '
#            'Coefficient Factor For Rain '
#            'Droplet"}}}},"random_shadow":{"name":"Random '
#            'Shadow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"x_min":{"name":"X '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#            'Axis Of Image Where Shadows Will Appear"},"y_min":{"name":"Y '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#            'Axis Of Image Where Shadows Will Appear"},"x_max":{"name":"X '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#            'Axis Of Image Where Shadows Will Appear"},"y_max":{"name":"Y '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#            'Axis Of Image Where Shadows Will '
#            'Appear"},"num_shadows_lower":{"name":"Number Of Shadows Lower '
#            'Limit","value":1,"default":1,"min":0,"max":20,"tooltip":"Lower '
#            'Limit For Possible Number Of '
#            'Shadows"},"num_shadows_upper":{"name":"Number Of Shadows Upper '
#            'Limit","value":5,"default":5,"min":0,"max":20,"tooltip":"Upper '
#            'Limit For Possible Number Of '
#            'Shadows"},"shadow_dimension":{"name":"Number Of '
#            'Edges","value":5,"default":5,"min":3,"max":20,"tooltip":"Number Of '
#            'Edges In Shadow Polygons"}}}},"random_snow":{"name":"Random '
#            'Snow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"snow_point_lower":{"name":"Lower '
#            'Snow '
#            'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#            'Limit Of The Amount Of Snow"},"snow_point_upper":{"name":"Upper '
#            'Snow '
#            'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#            'Limit Of The Amount Of '
#            'Snow"},"brightness_coefficient":{"name":"Brightness '
#            'Coefficient","value":2.5,"default":2.5,"min":0,"max":5,"tooltip":"Brightness '
#            'Coefficient Factor For Snow"}}}},"random_sunflare":{"name":"Random '
#            'Sun '
#            'Flare","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"x_min":{"name":"X '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#            'Axis Of Image Where Flares Will Appear"},"y_min":{"name":"Y '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#            'Axis Of Image Where Flares Will Appear"},"x_max":{"name":"X '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#            'Axis Of Image Where Flares Will Appear"},"y_max":{"name":"Y '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#            'Axis Of Image Where Flares Will '
#            'Appear"},"angle_lower":{"name":"Angle Lower '
#            'Limit","value":0,"default":0,"min":0,"max":1,"tooltip":"Lower '
#            'Limit For Flares Angle"},"angle_upper":{"name":"Angle Upper '
#            'Limit","value":1,"default":1,"min":0,"max":1,"tooltip":"Upper '
#            'Limit For Flares Angle"},"num_flare_circles_lower":{"name":"Number '
#            'Of Flares Lower '
#            'Limit","value":6,"default":6,"min":0,"max":20,"tooltip":"Lower '
#            'Limit For Possible Number Of '
#            'Flares"},"num_flare_circles_upper":{"name":"Number Of Flares Upper '
#            'Limit","value":10,"default":10,"min":0,"max":20,"tooltip":"Upper '
#            'Limit For Possible Number Of Flares"}}}},"rgb_shift":{"name":"RGB '
#            'Shift","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"lower_r_shift_limit":{"name":"R '
#            'Channel Shift Lower '
#            'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#            'Limit For Changing Values For Red '
#            'Channel"},"upper_r_shift_limit":{"name":"R Channel Shift Upper '
#            'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#            'Limit For Changing Values For Red '
#            'Channel"},"lower_g_shift_limit":{"name":"G Channel Shift Lower '
#            'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#            'Limit For Changing Values For Green '
#            'Channel"},"upper_g_shift_limit":{"name":"G Channel Shift Upper '
#            'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#            'Limit For Changing Values For Green '
#            'Channel"},"lower_b_shift_limit":{"name":"B Channel Shift Lower '
#            'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#            'Limit For Changing Values For Blue '
#            'Channel"},"upper_b_shift_limit":{"name":"B Channel Shift Upper '
#            'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#            'Limit For Changing Values For Blue '
#            'Channel"}}}},"sepia":{"name":"Sepia","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"solarize":{"name":"Solarize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"threshold":{"name":"Threshold","value":128,"default":128,"min":0,"max":255,"tooltip":"Invert '
#            'All Pixel Values Above A '
#            'Threshold"}}}}}}}}},"position":{"x":840,"y":375},"__rf":{"position":{"x":840,"y":375},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none","opacity":"100%"}},{"id":"2c3d4b45-d6ab-4048-bb3a-81a2d8f278dc","type":"fasterrcnn-inceptionv2-1024x1024","basetype":"model","data":{"schema":{"title":"FasterRCNN '
#            'InceptionV2 '
#            '1024x1024","tag":"fasterrcnn-inceptionv2-1024x1024","hasSource":true,"hasDestination":false,"subtitle":{"targetparam":"training","targetarg":"batchsize","template":"%% '
#            'Images per Batch"},"parameters":{"training":{"name":"Training '
#            'Parameters","args":{"batchsize":{"name":"Batch '
#            'Size","type":"number","value":2,"default":2},"epochs":{"name":"Training '
#            'Epochs","type":"number","value":"3000","default":1000}}},"pipeline":{"name":"Model '
#            'Configurations","args":{"max_detection_per_class":{"name":"Max '
#            'Detections Per '
#            'Class","type":"number","value":30,"default":30}}}}}},"position":{"x":840,"y":555},"__rf":{"position":{"x":840,"y":555},"width":260,"height":88,"handleBounds":{"source":null,"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false},"style":{"opacity":"100%","boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"source":"11833b3d-a445-4f08-acdb-ba477780470f","sourceHandle":null,"target":"65d6690c-2d32-450d-a09d-de9a142c364f","targetHandle":null,"animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-11833b3d-a445-4f08-acdb-ba477780470fnull-65d6690c-2d32-450d-a09d-de9a142c364fnull","type":"default","style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"source":"65d6690c-2d32-450d-a09d-de9a142c364f","sourceHandle":null,"target":"2c3d4b45-d6ab-4048-bb3a-81a2d8f278dc","targetHandle":null,"animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-65d6690c-2d32-450d-a09d-de9a142c364fnull-2c3d4b45-d6ab-4048-bb3a-81a2d8f278dcnull","type":"default"}]',
#   'title': 'My Workflow'},
#  {'id': 'flow_6486b3cb448256e87d1226cf',
#   'last_updated': 1686549509368,
#   'object': 'workflow',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'state': '[{"id":"61144294-c1ec-4ec0-8c39-8b552449e9ff","type":"dataset","basetype":"dataset","data":{"schema":{"title":"Dataset","hasSource":false,"hasDestination":true,"subtitle":{"targetparam":"dataset_setup","targetarg":"train_test_split","template":"Train-Test '
#            'Split %% Ratio"},"parameters":{"dataset_setup":{"name":"Dataset '
#            'Setup","args":{"train_test_split":{"name":"Train-Test '
#            'Split","type":"float","value":"0.2","default":0.3},"shuffle":{"name":"Shuffle '
#            'Dataset","type":"boolean","value":true,"default":true},"random_seed":{"name":"Random '
#            'Seed","type":"number","value":0,"default":0}}}}}},"position":{"x":720,"y":240},"__rf":{"position":{"x":720,"y":240},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":null},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none","opacity":"100%"}},{"id":"a0019dfc-ca53-488c-a012-82a933a59eb8","type":"augmentation","basetype":"augmentation","data":{"schema":{"title":"Augmentations","hasSource":true,"hasDestination":true,"subtitle":{"targetparam":"options","targetarg":"advanced_mode","template":"Advanced '
#            'Mode : '
#            '%%"},"parameters":{"options":{"name":"Options","args":{"advanced_mode":{"name":"Advanced '
#            'Mode","type":"boolean","value":false,"default":false}}},"position_transforms":{"name":"Random '
#            'Position Augmentations","args":{"center_crop":{"name":"Center '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height Of The Crop '
#            '(1%-100%)"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width Of The Crop '
#            '(1%-100%)"}}}},"random_horizontal_flip":{"name":"Flip '
#            'Horizontal","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"random_vertical_flip":{"name":"Flip '
#            'Vertical","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"}}}},"random_crop":{"name":"Random '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height Of The '
#            'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width Of The Crop"}}}},"random_rotate":{"name":"Random '
#            'Rotate","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_rotation":{"name":"Minimum '
#            'Rotation","value":-90,"default":-90,"min":-180,"max":180,"tooltip":"Minimum '
#            'Rotation Angle"},"max_rotation":{"name":"Maximum '
#            'Rotation","value":90,"default":90,"min":-180,"max":180,"tooltip":"Maximum '
#            'Rotation Angle"}}}},"random_resized_crop":{"name":"Random Resized '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height Of The '
#            'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width Of The Crop"},"min_scale":{"name":"Minimum '
#            'Scale","value":0.08,"default":0.08,"min":0,"max":1,"tooltip":"Minimum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"max_scale":{"name":"Maximum '
#            'Scale","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"min_aspect_ratio":{"name":"Minimum Aspect '
#            'Ratio","value":0.75,"default":0.75,"min":0.1,"max":10,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"max_aspect_ratio":{"name":"Maximum Aspect '
#            'Ratio","value":1.33,"default":1.33,"min":0.1,"max":10,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"}}}},"random_sized_crop":{"name":"Random Sized '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_height":{"name":"Minimum Crop '
#            'Size '
#            'Height","value":50,"default":50,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Minimum Crop Size Limit"},"max_height":{"name":"Maximum '
#            'Crop Size '
#            'Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Maximum Crop Size '
#            'Height"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height After The Crop And '
#            'Resize"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width After The Crop And '
#            'Resize"},"w2h_ratio":{"name":"Width to Height '
#            'Ratio","value":1,"default":1,"min":0.1,"max":1,"tooltip":"Aspect '
#            'Ratio of Crop"}}}},"shift_scale_rotate":{"name":"Shift Scale '
#            'Rotate","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_shift":{"name":"Minimum '
#            'Shift","value":-0.0625,"default":-0.0625,"min":-1,"max":1,"tooltip":"Minimum '
#            'Range Of Shift Factor For Height And '
#            'Width"},"max_shift":{"name":"Maximum '
#            'Shift","value":0.0625,"default":0.0625,"min":-1,"max":1,"tooltip":"Maximum '
#            'Range Of Shift Factor For Height And '
#            'Width"},"min_scale":{"name":"Minimum '
#            'Scale","value":-0.1,"default":-0.1,"min":-2,"max":2,"tooltip":"Minimum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"max_scale":{"name":"Maximum '
#            'Scale","value":0.1,"default":0.1,"min":-2,"max":2,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"min_rotation":{"name":"Minimum '
#            'Rotation","value":-45,"default":-45,"min":-360,"max":360,"tooltip":"Minimum '
#            'Rotation Angle"},"max_rotation":{"name":"Maximum '
#            'Rotation","value":45,"default":45,"min":-360,"max":360,"tooltip":"Maximum '
#            'Rotation Angle"}}}}}},"color_transforms":{"name":"Color Space '
#            'Augmentations","args":{"channel_dropout":{"name":"Channel '
#            'Dropout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"min_channel_dropout_range":{"name":"Min Channel '
#            'Dropout '
#            'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Minimum '
#            'Channel Dropout Limit That Should Be Used For This '
#            'Augmentation"},"max_channel_dropout_range":{"name":"Max Channel '
#            'Dropout '
#            'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Maximum '
#            'Channel Dropout Limit That Should Be Used For This '
#            'Augmentation"},"fill_value":{"name":"Fill '
#            'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#            'Value For The Dropped '
#            'Channel"}}}},"channel_shuffle":{"name":"Channel '
#            'Shuffle","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"CLAHE":{"name":"CLAHE","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_clip_limit":{"name":"Min Clip '
#            'Limit","value":1,"default":1,"min":1,"max":100,"tooltip":"Lower '
#            'Threshold Value For Contrast '
#            'Limiting"},"max_clip_limit":{"name":"Max Clip '
#            'Limit","value":4,"default":4,"min":1,"max":100,"tooltip":"Upper '
#            'Threshold Value For Contrast '
#            'Limiting"},"min_tile_grid_size":{"name":"Min Grid '
#            'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Lower '
#            'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#            'Equalization"},"max_tile_grid_size":{"name":"Max Grid '
#            'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Upper '
#            'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#            'Equalization"}}}},"color_jitter":{"name":"Color '
#            'Jitter","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_brightness":{"name":"Min '
#            'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter '
#            'Brightness"},"max_brightness":{"name":"Max '
#            'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter '
#            'Brightness"},"min_contrast":{"name":"Min '
#            'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter Contrast"},"max_contrast":{"name":"Max '
#            'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter '
#            'Contrast"},"min_saturation":{"name":"Min '
#            'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter '
# ...
#            'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#            'Blur","value":7,"default":7,"min":7,"max":100,"tooltip":"Maximum '
#            'Kernel Size For Blurring Input '
#            'Image"}}}},"multiplicative_noise":{"name":"Multiplicative '
#            'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_multi":{"name":"Min '
#            'Multiplication '
#            'Limit","value":0.9,"default":0.9,"min":0.1,"max":5,"tooltip":"Minimum '
#            'Random Number To Multiple With Input '
#            'Image"},"max_multi":{"name":"Max Multiplication '
#            'Limit","value":1.1,"default":1.1,"min":0.1,"max":5,"tooltip":"Maximum '
#            'Random Number To Multiple With Input '
#            'Image"}}}},"posterize":{"name":"Posterize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"r_bits":{"name":"R Channel Number '
#            'Of Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number '
#            'Of Bits For Red Channel"},"g_bits":{"name":"G Channel Number Of '
#            'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#            'Bits For Green Channel"},"b_bits":{"name":"B Channel Number Of '
#            'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#            'Bits For Blue Channel"}}}},"random_blur":{"name":"Random '
#            'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_blur_limit":{"name":"Min Blur '
#            'Limit","value":3,"default":3,"min":3,"max":100,"tooltip":"Minimum '
#            'Blur Limit That Should Be Used For This '
#            'Augmentation"},"max_blur_limit":{"name":"Max Blur '
#            'Limit","value":7,"default":7,"min":3,"max":100,"tooltip":"Maximum '
#            'Blur Limit That Should Be Used For This '
#            'Augmentation"}}}},"random_brightness":{"name":"Random '
#            'Brightness","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_limit":{"name":"Min '
#            'Brightness '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing Brightness"},"max_limit":{"name":"Max '
#            'Brightness '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Brightness"}}}},"random_brightness_contrast":{"name":"Random '
#            'Brightness '
#            'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_bright_limit":{"name":"Min '
#            'Brightness '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing '
#            'Brightness"},"max_bright_limit":{"name":"Max Brightness '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Brightness"},"min_contrast_limit":{"name":"Min Contrast '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing '
#            'Contrast"},"max_contrast_limit":{"name":"Max Contrast '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Contrast"}}}},"random_contrast":{"name":"Random '
#            'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_limit":{"name":"Min Contrast '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing Contrast"},"max_limit":{"name":"Max '
#            'Contrast '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Contrast"}}}},"random_fog":{"name":"Random '
#            'Fog","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"fog_coef_lower":{"name":"Lower '
#            'Coefficient '
#            'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#            'Limit For Fog Intensity '
#            'Coefficient"},"fog_coef_upper":{"name":"Upper Coefficient '
#            'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#            'Limit For Fog Intensity Coefficient"},"alpha_coef":{"name":"Alpha '
#            'Coefficient '
#            'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Transparency '
#            'Of Fog Circles"}}}},"random_gamma":{"name":"Random '
#            'Gamma","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_gamma_limit":{"name":"Min '
#            'Gamma '
#            'Limit","value":80,"default":80,"min":0,"max":200,"tooltip":"Minimum '
#            'Limit For Gamma Range"},"max_gamma_limit":{"name":"Max Gamma '
#            'Limit","value":120,"default":120,"min":0,"max":200,"tooltip":"Maximum '
#            'Limit For Gamma Range"}}}},"random_rain":{"name":"Random '
#            'Rain","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"slant_lower":{"name":"Lower '
#            'Slant","value":-10,"default":-10,"min":-20,"max":20,"tooltip":"Lower '
#            'Slant Of Rain Droplet"},"slant_upper":{"name":"Upper '
#            'Slant","value":10,"default":10,"min":-20,"max":20,"tooltip":"Upper '
#            'Slant Of Rain Droplet"},"drop_length":{"name":"Drop '
#            'Length","value":20,"default":20,"min":0,"max":100,"tooltip":"Length '
#            'Of Rain Droplet"},"drop_width":{"name":"Drop '
#            'Width","value":1,"default":1,"min":1,"max":5,"tooltip":"Width Of '
#            'Rain Droplet"},"drop_color_red":{"name":"Drop Color '
#            'Red","value":0,"default":0,"min":0,"max":255,"tooltip":"Red '
#            'Channel Rain Droplet"},"drop_color_green":{"name":"Drop Color '
#            'Green","value":0,"default":0,"min":0,"max":255,"tooltip":"Green '
#            'Channel Rain Droplet"},"drop_color_blue":{"name":"Drop Color '
#            'Blue","value":0,"default":0,"min":0,"max":255,"tooltip":"Blue '
#            'Channel Rain Droplet"},"blur_value":{"name":"Blur '
#            'Value","value":7,"default":7,"min":1,"max":15,"tooltip":"Blue '
#            'Channel Rain '
#            'Droplet"},"brightness_coefficient":{"name":"Brightness '
#            'Coefficient","value":0.7,"default":0.7,"min":0,"max":1,"tooltip":"Brightness '
#            'Coefficient Factor For Rain '
#            'Droplet"}}}},"random_shadow":{"name":"Random '
#            'Shadow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"x_min":{"name":"X '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#            'Axis Of Image Where Shadows Will Appear"},"y_min":{"name":"Y '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#            'Axis Of Image Where Shadows Will Appear"},"x_max":{"name":"X '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#            'Axis Of Image Where Shadows Will Appear"},"y_max":{"name":"Y '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#            'Axis Of Image Where Shadows Will '
#            'Appear"},"num_shadows_lower":{"name":"Number Of Shadows Lower '
#            'Limit","value":1,"default":1,"min":0,"max":20,"tooltip":"Lower '
#            'Limit For Possible Number Of '
#            'Shadows"},"num_shadows_upper":{"name":"Number Of Shadows Upper '
#            'Limit","value":5,"default":5,"min":0,"max":20,"tooltip":"Upper '
#            'Limit For Possible Number Of '
#            'Shadows"},"shadow_dimension":{"name":"Number Of '
#            'Edges","value":5,"default":5,"min":3,"max":20,"tooltip":"Number Of '
#            'Edges In Shadow Polygons"}}}},"random_snow":{"name":"Random '
#            'Snow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"snow_point_lower":{"name":"Lower '
#            'Snow '
#            'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#            'Limit Of The Amount Of Snow"},"snow_point_upper":{"name":"Upper '
#            'Snow '
#            'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#            'Limit Of The Amount Of '
#            'Snow"},"brightness_coefficient":{"name":"Brightness '
#            'Coefficient","value":2.5,"default":2.5,"min":0,"max":5,"tooltip":"Brightness '
#            'Coefficient Factor For Snow"}}}},"random_sunflare":{"name":"Random '
#            'Sun '
#            'Flare","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"x_min":{"name":"X '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#            'Axis Of Image Where Flares Will Appear"},"y_min":{"name":"Y '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#            'Axis Of Image Where Flares Will Appear"},"x_max":{"name":"X '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#            'Axis Of Image Where Flares Will Appear"},"y_max":{"name":"Y '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#            'Axis Of Image Where Flares Will '
#            'Appear"},"angle_lower":{"name":"Angle Lower '
#            'Limit","value":0,"default":0,"min":0,"max":1,"tooltip":"Lower '
#            'Limit For Flares Angle"},"angle_upper":{"name":"Angle Upper '
#            'Limit","value":1,"default":1,"min":0,"max":1,"tooltip":"Upper '
#            'Limit For Flares Angle"},"num_flare_circles_lower":{"name":"Number '
#            'Of Flares Lower '
#            'Limit","value":6,"default":6,"min":0,"max":20,"tooltip":"Lower '
#            'Limit For Possible Number Of '
#            'Flares"},"num_flare_circles_upper":{"name":"Number Of Flares Upper '
#            'Limit","value":10,"default":10,"min":0,"max":20,"tooltip":"Upper '
#            'Limit For Possible Number Of Flares"}}}},"rgb_shift":{"name":"RGB '
#            'Shift","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"lower_r_shift_limit":{"name":"R '
#            'Channel Shift Lower '
#            'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#            'Limit For Changing Values For Red '
#            'Channel"},"upper_r_shift_limit":{"name":"R Channel Shift Upper '
#            'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#            'Limit For Changing Values For Red '
#            'Channel"},"lower_g_shift_limit":{"name":"G Channel Shift Lower '
#            'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#            'Limit For Changing Values For Green '
#            'Channel"},"upper_g_shift_limit":{"name":"G Channel Shift Upper '
#            'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#            'Limit For Changing Values For Green '
#            'Channel"},"lower_b_shift_limit":{"name":"B Channel Shift Lower '
#            'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#            'Limit For Changing Values For Blue '
#            'Channel"},"upper_b_shift_limit":{"name":"B Channel Shift Upper '
#            'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#            'Limit For Changing Values For Blue '
#            'Channel"}}}},"sepia":{"name":"Sepia","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"solarize":{"name":"Solarize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"threshold":{"name":"Threshold","value":128,"default":128,"min":0,"max":255,"tooltip":"Invert '
#            'All Pixel Values Above A '
#            'Threshold"}}}}}}}}},"position":{"x":450,"y":345},"__rf":{"position":{"x":450,"y":345},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none","opacity":"100%"}},{"source":"1654057606218","target":"1654057606242","animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-1654057606218undefined-1654057606242undefined","sourceHandle":null,"targetHandle":null,"type":"default","style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"id":"1682328415840","type":"retina-mobilenetv2-320x320","basetype":"model","data":{"schema":{"title":"Retina '
#            'MobileNetV2 '
#            '320x320","tag":"retina-mobilenetv2-320x320","hasSource":true,"hasDestination":false,"subtitle":{"targetparam":"training","targetarg":"batchsize","template":"%% '
#            'Images per Batch"},"parameters":{"training":{"name":"Training '
#            'Parameters","args":{"batchsize":{"name":"Batch '
#            'Size","type":"number","value":2,"default":2},"epochs":{"name":"Training '
#            'Epochs","type":"number","value":"3000","default":1000}}},"pipeline":{"name":"Model '
#            'Configurations","args":{"max_detection_per_class":{"name":"Max '
#            'Detections Per '
#            'Class","type":"number","value":30,"default":30}}}}}},"position":{"x":450,"y":540},"__rf":{"position":{"x":450,"y":540},"width":260,"height":88,"handleBounds":{"source":null,"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false},"style":{"opacity":"100%","boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"source":"1654057606242","sourceHandle":null,"target":"1682328415840","targetHandle":null,"animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-1654057606242null-1682328415840null","type":"default"}]',
#   'title': 'MobileNet'}]

# %% [markdown]
# ## 9.2. Retrieve A Workflow

# %% [markdown]
# Retrieve a workflow based on the workflow's id. This will include the metadata for the specified workflow itself.

# %%
# Retrieve a workflow by the specified workflow id
workflow_retrieve_response = datature.Workflow.retrieve(
    workflow_list_response[0]["id"])

# Display response for the retrieval of workflow operation
pprint(workflow_retrieve_response)
# Out:
# {'id': 'flow_64893ef311c478ae88892823',
#  'last_updated': 1687778743912,
#  'object': 'workflow',
#  'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'state': '[{"id":"11833b3d-a445-4f08-acdb-ba477780470f","type":"dataset","basetype":"dataset","data":{"schema":{"title":"Dataset","hasSource":false,"hasDestination":true,"subtitle":{"targetparam":"dataset_setup","targetarg":"train_test_split","template":"Train-Test '
#           'Split %% Ratio"},"parameters":{"dataset_setup":{"name":"Dataset '
#           'Setup","args":{"train_test_split":{"name":"Train-Test '
#           'Split","type":"float","value":"0.2","default":0.3},"shuffle":{"name":"Shuffle '
#           'Dataset","type":"boolean","value":true,"default":true},"random_seed":{"name":"Random '
#           'Seed","type":"number","value":0,"default":0}}}}}},"position":{"x":840,"y":195},"__rf":{"position":{"x":840,"y":195},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":null},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none","opacity":"100%"}},{"id":"65d6690c-2d32-450d-a09d-de9a142c364f","type":"augmentation","basetype":"augmentation","data":{"schema":{"title":"Augmentations","hasSource":true,"hasDestination":true,"subtitle":{"targetparam":"options","targetarg":"advanced_mode","template":"Advanced '
#           'Mode : '
#           '%%"},"parameters":{"options":{"name":"Options","args":{"advanced_mode":{"name":"Advanced '
#           'Mode","type":"boolean","value":true,"default":false}}},"position_transforms":{"name":"Random '
#           'Position Augmentations","args":{"center_crop":{"name":"Center '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height Of The Crop '
#           '(1%-100%)"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width Of The Crop '
#           '(1%-100%)"}}}},"random_horizontal_flip":{"name":"Flip '
#           'Horizontal","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"random_vertical_flip":{"name":"Flip '
#           'Vertical","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"}}}},"random_crop":{"name":"Random '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height Of The '
#           'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width Of The Crop"}}}},"random_rotate":{"name":"Random '
#           'Rotate","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_rotation":{"name":"Minimum '
#           'Rotation","value":-90,"default":-90,"min":-180,"max":180,"tooltip":"Minimum '
#           'Rotation Angle"},"max_rotation":{"name":"Maximum '
#           'Rotation","value":90,"default":90,"min":-180,"max":180,"tooltip":"Maximum '
#           'Rotation '
#           'Angle"}}},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_rotation":{"name":"Minimum '
#           'Rotation","value":-90,"default":-90,"min":-180,"max":180,"tooltip":"Minimum '
#           'Rotation Angle"},"max_rotation":{"name":"Maximum '
#           'Rotation","value":90,"default":90,"min":-180,"max":180,"tooltip":"Maximum '
#           'Rotation Angle"}}}},"random_resized_crop":{"name":"Random Resized '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height Of The '
#           'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width Of The Crop"},"min_scale":{"name":"Minimum '
#           'Scale","value":0.08,"default":0.08,"min":0,"max":1,"tooltip":"Minimum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"max_scale":{"name":"Maximum '
#           'Scale","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"min_aspect_ratio":{"name":"Minimum Aspect '
#           'Ratio","value":0.75,"default":0.75,"min":0.1,"max":10,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"max_aspect_ratio":{"name":"Maximum Aspect '
#           'Ratio","value":1.33,"default":1.33,"min":0.1,"max":10,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"}}}},"random_sized_crop":{"name":"Random Sized '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_height":{"name":"Minimum Crop '
#           'Size '
#           'Height","value":50,"default":50,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Minimum Crop Size Limit"},"max_height":{"name":"Maximum '
#           'Crop Size '
#           'Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Maximum Crop Size '
#           'Height"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height After The Crop And '
#           'Resize"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width After The Crop And '
#           'Resize"},"w2h_ratio":{"name":"Width to Height '
#           'Ratio","value":1,"default":1,"min":0.1,"max":1,"tooltip":"Aspect '
#           'Ratio of Crop"}}}},"shift_scale_rotate":{"name":"Shift Scale '
#           'Rotate","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_shift":{"name":"Minimum '
#           'Shift","value":-0.0625,"default":-0.0625,"min":-1,"max":1,"tooltip":"Minimum '
#           'Range Of Shift Factor For Height And '
#           'Width"},"max_shift":{"name":"Maximum '
#           'Shift","value":0.0625,"default":0.0625,"min":-1,"max":1,"tooltip":"Maximum '
#           'Range Of Shift Factor For Height And '
#           'Width"},"min_scale":{"name":"Minimum '
#           'Scale","value":-0.1,"default":-0.1,"min":-2,"max":2,"tooltip":"Minimum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"max_scale":{"name":"Maximum '
#           'Scale","value":0.1,"default":0.1,"min":-2,"max":2,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"min_rotation":{"name":"Minimum '
#           'Rotation","value":-45,"default":-45,"min":-360,"max":360,"tooltip":"Minimum '
#           'Rotation Angle"},"max_rotation":{"name":"Maximum '
#           'Rotation","value":45,"default":45,"min":-360,"max":360,"tooltip":"Maximum '
#           'Rotation Angle"}}}}}},"color_transforms":{"name":"Color Space '
#           'Augmentations","args":{"channel_dropout":{"name":"Channel '
#           'Dropout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"min_channel_dropout_range":{"name":"Min Channel '
#           'Dropout '
#           'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Minimum '
#           'Channel Dropout Limit That Should Be Used For This '
#           'Augmentation"},"max_channel_dropout_range":{"name":"Max Channel '
#           'Dropout '
#           'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Maximum '
#           'Channel Dropout Limit That Should Be Used For This '
#           'Augmentation"},"fill_value":{"name":"Fill '
#           'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#           'Value For The Dropped '
#           'Channel"}}}},"channel_shuffle":{"name":"Channel '
#           'Shuffle","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"CLAHE":{"name":"CLAHE","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_clip_limit":{"name":"Min Clip '
#           'Limit","value":1,"default":1,"min":1,"max":100,"tooltip":"Lower '
#           'Threshold Value For Contrast '
#           'Limiting"},"max_clip_limit":{"name":"Max Clip '
#           'Limit","value":4,"default":4,"min":1,"max":100,"tooltip":"Upper '
#           'Threshold Value For Contrast '
#           'Limiting"},"min_tile_grid_size":{"name":"Min Grid '
#           'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Lower '
#           'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#           'Equalization"},"max_tile_grid_size":{"name":"Max Grid '
#           'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Upper '
#           'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#           'Equalization"}}}},"color_jitter":{"name":"Color '
#           'Jitter","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_brightness":{"name":"Min '
#           'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter '
#           'Brightness"},"max_brightness":{"name":"Max '
#           'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter '
#           'Brightness"},"min_contrast":{"name":"Min '
#           'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter Contrast"},"max_contrast":{"name":"Max '
#           'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter '
#           'Contrast"},"min_saturation":{"name":"Min '
#           'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter '
#           'Saturation"},"max_saturation":{"name":"Max '
#           'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter Saturation"},"min_hue":{"name":"Min '
#           'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter Hue"},"max_hue":{"name":"Max '
#           'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter '
#           'Hue"}}}},"cutout":{"name":"Cutout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"num_holes":{"name":"Number Of '
#           'Holes","value":8,"default":8,"min":0,"max":100,"tooltip":"Number Of '
#           'Regions To Zero Out"},"max_h_size":{"name":"Max Hole '
#           'Height","value":8,"default":8,"min":0,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Maximum Height Of The Hole."},"max_w_size":{"name":"Max '
#           'Hole '
#           'Width","value":8,"default":8,"min":0,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Maximum Width Of The Hole"},"fill_value":{"name":"Fill '
#           'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#           'Value For The Dropped '
#           'Channel"}}}},"equalize":{"name":"Equalize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"fancy_pca":{"name":"FancyPCA","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"alpha":{"name":"Alpha","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"How '
#           'Much To Pertub/Scale The Eigen Vectors And '
#           'Values"}}}},"gaussian_blur":{"name":"Gaussian '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_sigma":{"name":"Min Sigma '
#           'Minimum","value":0,"default":0,"min":0,"max":3,"tooltip":"Minimum '
#           'Gaussian Kernel Standard Deviation"},"max_sigma":{"name":"Max Sigma '
#           'Minimum","value":3,"default":3,"min":0,"max":3,"tooltip":"Maximum '
#           'Gaussian Kernel Standard '
#           'Deviation"}}}},"gauss_noise":{"name":"Gaussian '
#           'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_var":{"name":"Min Variance '
#           'Range","value":10,"default":10,"min":0,"max":500,"tooltip":"Minimum '
#           'Variance Range For Noise"},"max_var":{"name":"Max Variance '
#           'Range","value":50,"default":50,"min":0,"max":500,"tooltip":"Maximum '
#           'Variance Range For '
#           'Noise"},"mean":{"name":"Mean","value":0,"default":0,"min":-100,"max":100,"tooltip":"Mean '
#           'Of The Noise"}}}},"glass_blur":{"name":"Glass '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"sigma":{"name":"Sigma","value":0.7,"default":0.7,"min":0,"max":3,"tooltip":"Standard '
#           'Deviation For Gaussian Kernel"},"max_delta":{"name":"Max '
#           'Delta","value":4,"default":4,"min":1,"max":10,"tooltip":"Max '
#           'Distance Between Pixels Which Are '
#           'Swapped"},"iterations":{"name":"Iterations","value":2,"default":2,"min":1,"max":10,"tooltip":"Number '
#           'Of '
#           'Repeats"}}}},"random_rgb_to_gray":{"name":"Grayscale","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"}}}},"hue_sat_val":{"name":"Hue '
#           'Saturation '
#           'Value","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_hue_shift":{"name":"Min Hue '
#           'Shift","value":-20,"default":-20,"min":-100,"max":100,"tooltip":"Minimum '
#           'Hue Shift Range Limit"},"max_hue_shift":{"name":"Max Hue '
#           'Shift","value":20,"default":20,"min":-100,"max":100,"tooltip":"Maximum '
#           'Hue Shift Range Limit"},"min_sat_shift":{"name":"Min Saturation '
#           'Shift","value":-30,"default":-30,"min":-100,"max":100,"tooltip":"Minimum '
#           'Saturation Shift Range Limit"},"max_sat_shift":{"name":"Max '
#           'Saturation '
#           'Shift","value":30,"default":30,"min":-100,"max":100,"tooltip":"Maximum '
#           'Saturation Shift Range Limit"},"min_val_shift":{"name":"Min Value '
#           'Shift","value":-20,"default":-20,"min":-100,"max":100,"tooltip":"Minimum '
#           'Value Shift Range Limit"},"max_val_shift":{"name":"Max Value '
#           'Shift","value":20,"default":20,"min":-100,"max":100,"tooltip":"Maximum '
#           'Value Shift Range Limit"}}}},"image_compression":{"name":"Image '
#           'Compression","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"quality_lower":{"name":"Lower '
#           'Quality '
#           'Limit","value":80,"default":80,"min":1,"max":100,"tooltip":"Lower '
#           'Bound On The Image Quality"},"quality_upper":{"name":"Upper Quality '
#           'Limit","value":100,"default":100,"min":1,"max":100,"tooltip":"Upper '
#           'Bound On The Image Quality"}}}},"iso_noise":{"name":"ISO '
#           'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_color_shift":{"name":"Min '
#           'Color '
#           'Shift","value":0.01,"default":0.01,"min":0,"max":1,"tooltip":"Minimum '
#           'Variance Range For Color Hue '
#           'Change"},"max_color_shift":{"name":"Max Color '
#           'Shift","value":0.05,"default":0.05,"min":0,"max":1,"tooltip":"Maximum '
#           'Variance Range For Color Hue Change"},"min_intensity":{"name":"Min '
#           'Intensity","value":0.1,"default":0.1,"min":0,"max":2,"tooltip":"Minimum '
#           'Strength Of Color And Luminace Noise"},"max_intensity":{"name":"Max '
#           'Intensity","value":0.5,"default":0.5,"min":0,"max":2,"tooltip":"Maximum '
#           'Strength Of Color And Luminace '
#           'Noise"}}}},"median_blur":{"name":"Median '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#           'Blur","value":7,"default":7,"min":7,"max":99,"tooltip":"Maximum '
#           'Aperture Linear Size For Blurring Input '
#           'Image"}}}},"motion_blur":{"name":"Motion '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#           'Blur","value":7,"default":7,"min":7,"max":100,"tooltip":"Maximum '
#           'Kernel Size For Blurring Input '
#           'Image"}}}},"multiplicative_noise":{"name":"Multiplicative '
#           'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_multi":{"name":"Min '
#           'Multiplication '
#           'Limit","value":0.9,"default":0.9,"min":0.1,"max":5,"tooltip":"Minimum '
#           'Random Number To Multiple With Input '
#           'Image"},"max_multi":{"name":"Max Multiplication '
#           'Limit","value":1.1,"default":1.1,"min":0.1,"max":5,"tooltip":"Maximum '
#           'Random Number To Multiple With Input '
#           'Image"}}}},"posterize":{"name":"Posterize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"r_bits":{"name":"R Channel Number '
#           'Of Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#           'Bits For Red Channel"},"g_bits":{"name":"G Channel Number Of '
#           'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#           'Bits For Green Channel"},"b_bits":{"name":"B Channel Number Of '
#           'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#           'Bits For Blue Channel"}}}},"random_blur":{"name":"Random '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_blur_limit":{"name":"Min Blur '
#           'Limit","value":3,"default":3,"min":3,"max":100,"tooltip":"Minimum '
#           'Blur Limit That Should Be Used For This '
#           'Augmentation"},"max_blur_limit":{"name":"Max Blur '
#           'Limit","value":7,"default":7,"min":3,"max":100,"tooltip":"Maximum '
#           'Blur Limit That Should Be Used For This '
#           'Augmentation"}}}},"random_brightness":{"name":"Random '
#           'Brightness","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_limit":{"name":"Min Brightness '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing Brightness"},"max_limit":{"name":"Max '
#           'Brightness '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Brightness"}}}},"random_brightness_contrast":{"name":"Random '
#           'Brightness '
#           'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_bright_limit":{"name":"Min '
#           'Brightness '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing '
#           'Brightness"},"max_bright_limit":{"name":"Max Brightness '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Brightness"},"min_contrast_limit":{"name":"Min Contrast '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing '
#           'Contrast"},"max_contrast_limit":{"name":"Max Contrast '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Contrast"}}}},"random_contrast":{"name":"Random '
#           'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_limit":{"name":"Min Contrast '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing Contrast"},"max_limit":{"name":"Max '
#           'Contrast '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Contrast"}}}},"random_fog":{"name":"Random '
#           'Fog","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"fog_coef_lower":{"name":"Lower '
#           'Coefficient '
#           'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#           'Limit For Fog Intensity '
#           'Coefficient"},"fog_coef_upper":{"name":"Upper Coefficient '
#           'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#           'Limit For Fog Intensity Coefficient"},"alpha_coef":{"name":"Alpha '
#           'Coefficient '
#           'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Transparency '
#           'Of Fog Circles"}}}},"random_gamma":{"name":"Random '
#           'Gamma","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_gamma_limit":{"name":"Min '
#           'Gamma '
#           'Limit","value":80,"default":80,"min":0,"max":200,"tooltip":"Minimum '
#           'Limit For Gamma Range"},"max_gamma_limit":{"name":"Max Gamma '
#           'Limit","value":120,"default":120,"min":0,"max":200,"tooltip":"Maximum '
#           'Limit For Gamma Range"}}}},"random_rain":{"name":"Random '
#           'Rain","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"slant_lower":{"name":"Lower '
#           'Slant","value":-10,"default":-10,"min":-20,"max":20,"tooltip":"Lower '
#           'Slant Of Rain Droplet"},"slant_upper":{"name":"Upper '
#           'Slant","value":10,"default":10,"min":-20,"max":20,"tooltip":"Upper '
#           'Slant Of Rain Droplet"},"drop_length":{"name":"Drop '
#           'Length","value":20,"default":20,"min":0,"max":100,"tooltip":"Length '
#           'Of Rain Droplet"},"drop_width":{"name":"Drop '
#           'Width","value":1,"default":1,"min":1,"max":5,"tooltip":"Width Of '
#           'Rain Droplet"},"drop_color_red":{"name":"Drop Color '
#           'Red","value":0,"default":0,"min":0,"max":255,"tooltip":"Red Channel '
#           'Rain Droplet"},"drop_color_green":{"name":"Drop Color '
#           'Green","value":0,"default":0,"min":0,"max":255,"tooltip":"Green '
#           'Channel Rain Droplet"},"drop_color_blue":{"name":"Drop Color '
#           'Blue","value":0,"default":0,"min":0,"max":255,"tooltip":"Blue '
#           'Channel Rain Droplet"},"blur_value":{"name":"Blur '
#           'Value","value":7,"default":7,"min":1,"max":15,"tooltip":"Blue '
#           'Channel Rain Droplet"},"brightness_coefficient":{"name":"Brightness '
#           'Coefficient","value":0.7,"default":0.7,"min":0,"max":1,"tooltip":"Brightness '
#           'Coefficient Factor For Rain '
#           'Droplet"}}}},"random_shadow":{"name":"Random '
#           'Shadow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"x_min":{"name":"X '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#           'Axis Of Image Where Shadows Will Appear"},"y_min":{"name":"Y '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#           'Axis Of Image Where Shadows Will Appear"},"x_max":{"name":"X '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#           'Axis Of Image Where Shadows Will Appear"},"y_max":{"name":"Y '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#           'Axis Of Image Where Shadows Will '
#           'Appear"},"num_shadows_lower":{"name":"Number Of Shadows Lower '
#           'Limit","value":1,"default":1,"min":0,"max":20,"tooltip":"Lower '
#           'Limit For Possible Number Of '
#           'Shadows"},"num_shadows_upper":{"name":"Number Of Shadows Upper '
#           'Limit","value":5,"default":5,"min":0,"max":20,"tooltip":"Upper '
#           'Limit For Possible Number Of '
#           'Shadows"},"shadow_dimension":{"name":"Number Of '
#           'Edges","value":5,"default":5,"min":3,"max":20,"tooltip":"Number Of '
#           'Edges In Shadow Polygons"}}}},"random_snow":{"name":"Random '
#           'Snow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"snow_point_lower":{"name":"Lower '
#           'Snow '
#           'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#           'Limit Of The Amount Of Snow"},"snow_point_upper":{"name":"Upper '
#           'Snow '
#           'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#           'Limit Of The Amount Of '
#           'Snow"},"brightness_coefficient":{"name":"Brightness '
#           'Coefficient","value":2.5,"default":2.5,"min":0,"max":5,"tooltip":"Brightness '
#           'Coefficient Factor For Snow"}}}},"random_sunflare":{"name":"Random '
#           'Sun '
#           'Flare","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"x_min":{"name":"X '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#           'Axis Of Image Where Flares Will Appear"},"y_min":{"name":"Y '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#           'Axis Of Image Where Flares Will Appear"},"x_max":{"name":"X '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#           'Axis Of Image Where Flares Will Appear"},"y_max":{"name":"Y '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#           'Axis Of Image Where Flares Will '
#           'Appear"},"angle_lower":{"name":"Angle Lower '
#           'Limit","value":0,"default":0,"min":0,"max":1,"tooltip":"Lower Limit '
#           'For Flares Angle"},"angle_upper":{"name":"Angle Upper '
#           'Limit","value":1,"default":1,"min":0,"max":1,"tooltip":"Upper Limit '
#           'For Flares Angle"},"num_flare_circles_lower":{"name":"Number Of '
#           'Flares Lower '
#           'Limit","value":6,"default":6,"min":0,"max":20,"tooltip":"Lower '
#           'Limit For Possible Number Of '
#           'Flares"},"num_flare_circles_upper":{"name":"Number Of Flares Upper '
#           'Limit","value":10,"default":10,"min":0,"max":20,"tooltip":"Upper '
#           'Limit For Possible Number Of Flares"}}}},"rgb_shift":{"name":"RGB '
#           'Shift","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"lower_r_shift_limit":{"name":"R '
#           'Channel Shift Lower '
#           'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#           'Limit For Changing Values For Red '
#           'Channel"},"upper_r_shift_limit":{"name":"R Channel Shift Upper '
#           'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#           'Limit For Changing Values For Red '
#           'Channel"},"lower_g_shift_limit":{"name":"G Channel Shift Lower '
#           'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#           'Limit For Changing Values For Green '
#           'Channel"},"upper_g_shift_limit":{"name":"G Channel Shift Upper '
#           'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#           'Limit For Changing Values For Green '
#           'Channel"},"lower_b_shift_limit":{"name":"B Channel Shift Lower '
#           'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#           'Limit For Changing Values For Blue '
#           'Channel"},"upper_b_shift_limit":{"name":"B Channel Shift Upper '
#           'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#           'Limit For Changing Values For Blue '
#           'Channel"}}}},"sepia":{"name":"Sepia","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"solarize":{"name":"Solarize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"threshold":{"name":"Threshold","value":128,"default":128,"min":0,"max":255,"tooltip":"Invert '
#           'All Pixel Values Above A '
#           'Threshold"}}}}}}}}},"position":{"x":840,"y":375},"__rf":{"position":{"x":840,"y":375},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none","opacity":"100%"}},{"id":"2c3d4b45-d6ab-4048-bb3a-81a2d8f278dc","type":"fasterrcnn-inceptionv2-1024x1024","basetype":"model","data":{"schema":{"title":"FasterRCNN '
#           'InceptionV2 '
#           '1024x1024","tag":"fasterrcnn-inceptionv2-1024x1024","hasSource":true,"hasDestination":false,"subtitle":{"targetparam":"training","targetarg":"batchsize","template":"%% '
#           'Images per Batch"},"parameters":{"training":{"name":"Training '
#           'Parameters","args":{"batchsize":{"name":"Batch '
#           'Size","type":"number","value":2,"default":2},"epochs":{"name":"Training '
#           'Epochs","type":"number","value":"3000","default":1000}}},"pipeline":{"name":"Model '
#           'Configurations","args":{"max_detection_per_class":{"name":"Max '
#           'Detections Per '
#           'Class","type":"number","value":30,"default":30}}}}}},"position":{"x":840,"y":555},"__rf":{"position":{"x":840,"y":555},"width":260,"height":88,"handleBounds":{"source":null,"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false},"style":{"opacity":"100%","boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"source":"11833b3d-a445-4f08-acdb-ba477780470f","sourceHandle":null,"target":"65d6690c-2d32-450d-a09d-de9a142c364f","targetHandle":null,"animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-11833b3d-a445-4f08-acdb-ba477780470fnull-65d6690c-2d32-450d-a09d-de9a142c364fnull","type":"default","style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"source":"65d6690c-2d32-450d-a09d-de9a142c364f","sourceHandle":null,"target":"2c3d4b45-d6ab-4048-bb3a-81a2d8f278dc","targetHandle":null,"animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-65d6690c-2d32-450d-a09d-de9a142c364fnull-2c3d4b45-d6ab-4048-bb3a-81a2d8f278dcnull","type":"default"}]',
#  'title': 'My Workflow'}

# %% [markdown]
# ## 9.3. Update A Workflow

# %% [markdown]
# Updates the properties of a workflow based on the specified workflow id. Currently the only metadata that can be modified is the `title` of the workflow.

# %%
# Modify the properties of the workflow
workflow_modify_response = datature.Workflow.modify(
    workflow_list_response[0]["id"], {"title": "My awesome workflow"})

# Display response for the modification of workflow operation
pprint(workflow_modify_response)
# Out:
# {'id': 'flow_64893ef311c478ae88892823',
#  'last_updated': 1687778743912,
#  'object': 'workflow',
#  'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'state': '[{"id":"11833b3d-a445-4f08-acdb-ba477780470f","type":"dataset","basetype":"dataset","data":{"schema":{"title":"Dataset","hasSource":false,"hasDestination":true,"subtitle":{"targetparam":"dataset_setup","targetarg":"train_test_split","template":"Train-Test '
#           'Split %% Ratio"},"parameters":{"dataset_setup":{"name":"Dataset '
#           'Setup","args":{"train_test_split":{"name":"Train-Test '
#           'Split","type":"float","value":"0.2","default":0.3},"shuffle":{"name":"Shuffle '
#           'Dataset","type":"boolean","value":true,"default":true},"random_seed":{"name":"Random '
#           'Seed","type":"number","value":0,"default":0}}}}}},"position":{"x":840,"y":195},"__rf":{"position":{"x":840,"y":195},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":null},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none","opacity":"100%"}},{"id":"65d6690c-2d32-450d-a09d-de9a142c364f","type":"augmentation","basetype":"augmentation","data":{"schema":{"title":"Augmentations","hasSource":true,"hasDestination":true,"subtitle":{"targetparam":"options","targetarg":"advanced_mode","template":"Advanced '
#           'Mode : '
#           '%%"},"parameters":{"options":{"name":"Options","args":{"advanced_mode":{"name":"Advanced '
#           'Mode","type":"boolean","value":true,"default":false}}},"position_transforms":{"name":"Random '
#           'Position Augmentations","args":{"center_crop":{"name":"Center '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height Of The Crop '
#           '(1%-100%)"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width Of The Crop '
#           '(1%-100%)"}}}},"random_horizontal_flip":{"name":"Flip '
#           'Horizontal","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"random_vertical_flip":{"name":"Flip '
#           'Vertical","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"}}}},"random_crop":{"name":"Random '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height Of The '
#           'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width Of The Crop"}}}},"random_rotate":{"name":"Random '
#           'Rotate","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_rotation":{"name":"Minimum '
#           'Rotation","value":-90,"default":-90,"min":-180,"max":180,"tooltip":"Minimum '
#           'Rotation Angle"},"max_rotation":{"name":"Maximum '
#           'Rotation","value":90,"default":90,"min":-180,"max":180,"tooltip":"Maximum '
#           'Rotation '
#           'Angle"}}},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_rotation":{"name":"Minimum '
#           'Rotation","value":-90,"default":-90,"min":-180,"max":180,"tooltip":"Minimum '
#           'Rotation Angle"},"max_rotation":{"name":"Maximum '
#           'Rotation","value":90,"default":90,"min":-180,"max":180,"tooltip":"Maximum '
#           'Rotation Angle"}}}},"random_resized_crop":{"name":"Random Resized '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height Of The '
#           'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width Of The Crop"},"min_scale":{"name":"Minimum '
#           'Scale","value":0.08,"default":0.08,"min":0,"max":1,"tooltip":"Minimum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"max_scale":{"name":"Maximum '
#           'Scale","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"min_aspect_ratio":{"name":"Minimum Aspect '
#           'Ratio","value":0.75,"default":0.75,"min":0.1,"max":10,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"max_aspect_ratio":{"name":"Maximum Aspect '
#           'Ratio","value":1.33,"default":1.33,"min":0.1,"max":10,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"}}}},"random_sized_crop":{"name":"Random Sized '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_height":{"name":"Minimum Crop '
#           'Size '
#           'Height","value":50,"default":50,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Minimum Crop Size Limit"},"max_height":{"name":"Maximum '
#           'Crop Size '
#           'Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Maximum Crop Size '
#           'Height"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height After The Crop And '
#           'Resize"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width After The Crop And '
#           'Resize"},"w2h_ratio":{"name":"Width to Height '
#           'Ratio","value":1,"default":1,"min":0.1,"max":1,"tooltip":"Aspect '
#           'Ratio of Crop"}}}},"shift_scale_rotate":{"name":"Shift Scale '
#           'Rotate","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_shift":{"name":"Minimum '
#           'Shift","value":-0.0625,"default":-0.0625,"min":-1,"max":1,"tooltip":"Minimum '
#           'Range Of Shift Factor For Height And '
#           'Width"},"max_shift":{"name":"Maximum '
#           'Shift","value":0.0625,"default":0.0625,"min":-1,"max":1,"tooltip":"Maximum '
#           'Range Of Shift Factor For Height And '
#           'Width"},"min_scale":{"name":"Minimum '
#           'Scale","value":-0.1,"default":-0.1,"min":-2,"max":2,"tooltip":"Minimum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"max_scale":{"name":"Maximum '
#           'Scale","value":0.1,"default":0.1,"min":-2,"max":2,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"min_rotation":{"name":"Minimum '
#           'Rotation","value":-45,"default":-45,"min":-360,"max":360,"tooltip":"Minimum '
#           'Rotation Angle"},"max_rotation":{"name":"Maximum '
#           'Rotation","value":45,"default":45,"min":-360,"max":360,"tooltip":"Maximum '
#           'Rotation Angle"}}}}}},"color_transforms":{"name":"Color Space '
#           'Augmentations","args":{"channel_dropout":{"name":"Channel '
#           'Dropout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"min_channel_dropout_range":{"name":"Min Channel '
#           'Dropout '
#           'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Minimum '
#           'Channel Dropout Limit That Should Be Used For This '
#           'Augmentation"},"max_channel_dropout_range":{"name":"Max Channel '
#           'Dropout '
#           'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Maximum '
#           'Channel Dropout Limit That Should Be Used For This '
#           'Augmentation"},"fill_value":{"name":"Fill '
#           'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#           'Value For The Dropped '
#           'Channel"}}}},"channel_shuffle":{"name":"Channel '
#           'Shuffle","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"CLAHE":{"name":"CLAHE","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_clip_limit":{"name":"Min Clip '
#           'Limit","value":1,"default":1,"min":1,"max":100,"tooltip":"Lower '
#           'Threshold Value For Contrast '
#           'Limiting"},"max_clip_limit":{"name":"Max Clip '
#           'Limit","value":4,"default":4,"min":1,"max":100,"tooltip":"Upper '
#           'Threshold Value For Contrast '
#           'Limiting"},"min_tile_grid_size":{"name":"Min Grid '
#           'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Lower '
#           'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#           'Equalization"},"max_tile_grid_size":{"name":"Max Grid '
#           'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Upper '
#           'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#           'Equalization"}}}},"color_jitter":{"name":"Color '
#           'Jitter","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_brightness":{"name":"Min '
#           'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter '
#           'Brightness"},"max_brightness":{"name":"Max '
#           'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter '
#           'Brightness"},"min_contrast":{"name":"Min '
#           'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter Contrast"},"max_contrast":{"name":"Max '
#           'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter '
#           'Contrast"},"min_saturation":{"name":"Min '
#           'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter '
#           'Saturation"},"max_saturation":{"name":"Max '
#           'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter Saturation"},"min_hue":{"name":"Min '
#           'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter Hue"},"max_hue":{"name":"Max '
#           'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter '
#           'Hue"}}}},"cutout":{"name":"Cutout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"num_holes":{"name":"Number Of '
#           'Holes","value":8,"default":8,"min":0,"max":100,"tooltip":"Number Of '
#           'Regions To Zero Out"},"max_h_size":{"name":"Max Hole '
#           'Height","value":8,"default":8,"min":0,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Maximum Height Of The Hole."},"max_w_size":{"name":"Max '
#           'Hole '
#           'Width","value":8,"default":8,"min":0,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Maximum Width Of The Hole"},"fill_value":{"name":"Fill '
#           'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#           'Value For The Dropped '
#           'Channel"}}}},"equalize":{"name":"Equalize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"fancy_pca":{"name":"FancyPCA","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"alpha":{"name":"Alpha","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"How '
#           'Much To Pertub/Scale The Eigen Vectors And '
#           'Values"}}}},"gaussian_blur":{"name":"Gaussian '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_sigma":{"name":"Min Sigma '
#           'Minimum","value":0,"default":0,"min":0,"max":3,"tooltip":"Minimum '
#           'Gaussian Kernel Standard Deviation"},"max_sigma":{"name":"Max Sigma '
#           'Minimum","value":3,"default":3,"min":0,"max":3,"tooltip":"Maximum '
#           'Gaussian Kernel Standard '
#           'Deviation"}}}},"gauss_noise":{"name":"Gaussian '
#           'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_var":{"name":"Min Variance '
#           'Range","value":10,"default":10,"min":0,"max":500,"tooltip":"Minimum '
#           'Variance Range For Noise"},"max_var":{"name":"Max Variance '
#           'Range","value":50,"default":50,"min":0,"max":500,"tooltip":"Maximum '
#           'Variance Range For '
#           'Noise"},"mean":{"name":"Mean","value":0,"default":0,"min":-100,"max":100,"tooltip":"Mean '
#           'Of The Noise"}}}},"glass_blur":{"name":"Glass '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"sigma":{"name":"Sigma","value":0.7,"default":0.7,"min":0,"max":3,"tooltip":"Standard '
#           'Deviation For Gaussian Kernel"},"max_delta":{"name":"Max '
#           'Delta","value":4,"default":4,"min":1,"max":10,"tooltip":"Max '
#           'Distance Between Pixels Which Are '
#           'Swapped"},"iterations":{"name":"Iterations","value":2,"default":2,"min":1,"max":10,"tooltip":"Number '
#           'Of '
#           'Repeats"}}}},"random_rgb_to_gray":{"name":"Grayscale","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"}}}},"hue_sat_val":{"name":"Hue '
#           'Saturation '
#           'Value","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_hue_shift":{"name":"Min Hue '
#           'Shift","value":-20,"default":-20,"min":-100,"max":100,"tooltip":"Minimum '
#           'Hue Shift Range Limit"},"max_hue_shift":{"name":"Max Hue '
#           'Shift","value":20,"default":20,"min":-100,"max":100,"tooltip":"Maximum '
#           'Hue Shift Range Limit"},"min_sat_shift":{"name":"Min Saturation '
#           'Shift","value":-30,"default":-30,"min":-100,"max":100,"tooltip":"Minimum '
#           'Saturation Shift Range Limit"},"max_sat_shift":{"name":"Max '
#           'Saturation '
#           'Shift","value":30,"default":30,"min":-100,"max":100,"tooltip":"Maximum '
#           'Saturation Shift Range Limit"},"min_val_shift":{"name":"Min Value '
#           'Shift","value":-20,"default":-20,"min":-100,"max":100,"tooltip":"Minimum '
#           'Value Shift Range Limit"},"max_val_shift":{"name":"Max Value '
#           'Shift","value":20,"default":20,"min":-100,"max":100,"tooltip":"Maximum '
#           'Value Shift Range Limit"}}}},"image_compression":{"name":"Image '
#           'Compression","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"quality_lower":{"name":"Lower '
#           'Quality '
#           'Limit","value":80,"default":80,"min":1,"max":100,"tooltip":"Lower '
#           'Bound On The Image Quality"},"quality_upper":{"name":"Upper Quality '
#           'Limit","value":100,"default":100,"min":1,"max":100,"tooltip":"Upper '
#           'Bound On The Image Quality"}}}},"iso_noise":{"name":"ISO '
#           'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_color_shift":{"name":"Min '
#           'Color '
#           'Shift","value":0.01,"default":0.01,"min":0,"max":1,"tooltip":"Minimum '
#           'Variance Range For Color Hue '
#           'Change"},"max_color_shift":{"name":"Max Color '
#           'Shift","value":0.05,"default":0.05,"min":0,"max":1,"tooltip":"Maximum '
#           'Variance Range For Color Hue Change"},"min_intensity":{"name":"Min '
#           'Intensity","value":0.1,"default":0.1,"min":0,"max":2,"tooltip":"Minimum '
#           'Strength Of Color And Luminace Noise"},"max_intensity":{"name":"Max '
#           'Intensity","value":0.5,"default":0.5,"min":0,"max":2,"tooltip":"Maximum '
#           'Strength Of Color And Luminace '
#           'Noise"}}}},"median_blur":{"name":"Median '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#           'Blur","value":7,"default":7,"min":7,"max":99,"tooltip":"Maximum '
#           'Aperture Linear Size For Blurring Input '
#           'Image"}}}},"motion_blur":{"name":"Motion '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#           'Blur","value":7,"default":7,"min":7,"max":100,"tooltip":"Maximum '
#           'Kernel Size For Blurring Input '
#           'Image"}}}},"multiplicative_noise":{"name":"Multiplicative '
#           'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_multi":{"name":"Min '
#           'Multiplication '
#           'Limit","value":0.9,"default":0.9,"min":0.1,"max":5,"tooltip":"Minimum '
#           'Random Number To Multiple With Input '
#           'Image"},"max_multi":{"name":"Max Multiplication '
#           'Limit","value":1.1,"default":1.1,"min":0.1,"max":5,"tooltip":"Maximum '
#           'Random Number To Multiple With Input '
#           'Image"}}}},"posterize":{"name":"Posterize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"r_bits":{"name":"R Channel Number '
#           'Of Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#           'Bits For Red Channel"},"g_bits":{"name":"G Channel Number Of '
#           'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#           'Bits For Green Channel"},"b_bits":{"name":"B Channel Number Of '
#           'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#           'Bits For Blue Channel"}}}},"random_blur":{"name":"Random '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_blur_limit":{"name":"Min Blur '
#           'Limit","value":3,"default":3,"min":3,"max":100,"tooltip":"Minimum '
#           'Blur Limit That Should Be Used For This '
#           'Augmentation"},"max_blur_limit":{"name":"Max Blur '
#           'Limit","value":7,"default":7,"min":3,"max":100,"tooltip":"Maximum '
#           'Blur Limit That Should Be Used For This '
#           'Augmentation"}}}},"random_brightness":{"name":"Random '
#           'Brightness","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_limit":{"name":"Min Brightness '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing Brightness"},"max_limit":{"name":"Max '
#           'Brightness '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Brightness"}}}},"random_brightness_contrast":{"name":"Random '
#           'Brightness '
#           'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_bright_limit":{"name":"Min '
#           'Brightness '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing '
#           'Brightness"},"max_bright_limit":{"name":"Max Brightness '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Brightness"},"min_contrast_limit":{"name":"Min Contrast '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing '
#           'Contrast"},"max_contrast_limit":{"name":"Max Contrast '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Contrast"}}}},"random_contrast":{"name":"Random '
#           'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_limit":{"name":"Min Contrast '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing Contrast"},"max_limit":{"name":"Max '
#           'Contrast '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Contrast"}}}},"random_fog":{"name":"Random '
#           'Fog","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"fog_coef_lower":{"name":"Lower '
#           'Coefficient '
#           'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#           'Limit For Fog Intensity '
#           'Coefficient"},"fog_coef_upper":{"name":"Upper Coefficient '
#           'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#           'Limit For Fog Intensity Coefficient"},"alpha_coef":{"name":"Alpha '
#           'Coefficient '
#           'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Transparency '
#           'Of Fog Circles"}}}},"random_gamma":{"name":"Random '
#           'Gamma","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_gamma_limit":{"name":"Min '
#           'Gamma '
#           'Limit","value":80,"default":80,"min":0,"max":200,"tooltip":"Minimum '
#           'Limit For Gamma Range"},"max_gamma_limit":{"name":"Max Gamma '
#           'Limit","value":120,"default":120,"min":0,"max":200,"tooltip":"Maximum '
#           'Limit For Gamma Range"}}}},"random_rain":{"name":"Random '
#           'Rain","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"slant_lower":{"name":"Lower '
#           'Slant","value":-10,"default":-10,"min":-20,"max":20,"tooltip":"Lower '
#           'Slant Of Rain Droplet"},"slant_upper":{"name":"Upper '
#           'Slant","value":10,"default":10,"min":-20,"max":20,"tooltip":"Upper '
#           'Slant Of Rain Droplet"},"drop_length":{"name":"Drop '
#           'Length","value":20,"default":20,"min":0,"max":100,"tooltip":"Length '
#           'Of Rain Droplet"},"drop_width":{"name":"Drop '
#           'Width","value":1,"default":1,"min":1,"max":5,"tooltip":"Width Of '
#           'Rain Droplet"},"drop_color_red":{"name":"Drop Color '
#           'Red","value":0,"default":0,"min":0,"max":255,"tooltip":"Red Channel '
#           'Rain Droplet"},"drop_color_green":{"name":"Drop Color '
#           'Green","value":0,"default":0,"min":0,"max":255,"tooltip":"Green '
#           'Channel Rain Droplet"},"drop_color_blue":{"name":"Drop Color '
#           'Blue","value":0,"default":0,"min":0,"max":255,"tooltip":"Blue '
#           'Channel Rain Droplet"},"blur_value":{"name":"Blur '
#           'Value","value":7,"default":7,"min":1,"max":15,"tooltip":"Blue '
#           'Channel Rain Droplet"},"brightness_coefficient":{"name":"Brightness '
#           'Coefficient","value":0.7,"default":0.7,"min":0,"max":1,"tooltip":"Brightness '
#           'Coefficient Factor For Rain '
#           'Droplet"}}}},"random_shadow":{"name":"Random '
#           'Shadow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"x_min":{"name":"X '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#           'Axis Of Image Where Shadows Will Appear"},"y_min":{"name":"Y '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#           'Axis Of Image Where Shadows Will Appear"},"x_max":{"name":"X '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#           'Axis Of Image Where Shadows Will Appear"},"y_max":{"name":"Y '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#           'Axis Of Image Where Shadows Will '
#           'Appear"},"num_shadows_lower":{"name":"Number Of Shadows Lower '
#           'Limit","value":1,"default":1,"min":0,"max":20,"tooltip":"Lower '
#           'Limit For Possible Number Of '
#           'Shadows"},"num_shadows_upper":{"name":"Number Of Shadows Upper '
#           'Limit","value":5,"default":5,"min":0,"max":20,"tooltip":"Upper '
#           'Limit For Possible Number Of '
#           'Shadows"},"shadow_dimension":{"name":"Number Of '
#           'Edges","value":5,"default":5,"min":3,"max":20,"tooltip":"Number Of '
#           'Edges In Shadow Polygons"}}}},"random_snow":{"name":"Random '
#           'Snow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"snow_point_lower":{"name":"Lower '
#           'Snow '
#           'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#           'Limit Of The Amount Of Snow"},"snow_point_upper":{"name":"Upper '
#           'Snow '
#           'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#           'Limit Of The Amount Of '
#           'Snow"},"brightness_coefficient":{"name":"Brightness '
#           'Coefficient","value":2.5,"default":2.5,"min":0,"max":5,"tooltip":"Brightness '
#           'Coefficient Factor For Snow"}}}},"random_sunflare":{"name":"Random '
#           'Sun '
#           'Flare","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"x_min":{"name":"X '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#           'Axis Of Image Where Flares Will Appear"},"y_min":{"name":"Y '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#           'Axis Of Image Where Flares Will Appear"},"x_max":{"name":"X '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#           'Axis Of Image Where Flares Will Appear"},"y_max":{"name":"Y '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#           'Axis Of Image Where Flares Will '
#           'Appear"},"angle_lower":{"name":"Angle Lower '
#           'Limit","value":0,"default":0,"min":0,"max":1,"tooltip":"Lower Limit '
#           'For Flares Angle"},"angle_upper":{"name":"Angle Upper '
#           'Limit","value":1,"default":1,"min":0,"max":1,"tooltip":"Upper Limit '
#           'For Flares Angle"},"num_flare_circles_lower":{"name":"Number Of '
#           'Flares Lower '
#           'Limit","value":6,"default":6,"min":0,"max":20,"tooltip":"Lower '
#           'Limit For Possible Number Of '
#           'Flares"},"num_flare_circles_upper":{"name":"Number Of Flares Upper '
#           'Limit","value":10,"default":10,"min":0,"max":20,"tooltip":"Upper '
#           'Limit For Possible Number Of Flares"}}}},"rgb_shift":{"name":"RGB '
#           'Shift","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"lower_r_shift_limit":{"name":"R '
#           'Channel Shift Lower '
#           'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#           'Limit For Changing Values For Red '
#           'Channel"},"upper_r_shift_limit":{"name":"R Channel Shift Upper '
#           'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#           'Limit For Changing Values For Red '
#           'Channel"},"lower_g_shift_limit":{"name":"G Channel Shift Lower '
#           'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#           'Limit For Changing Values For Green '
#           'Channel"},"upper_g_shift_limit":{"name":"G Channel Shift Upper '
#           'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#           'Limit For Changing Values For Green '
#           'Channel"},"lower_b_shift_limit":{"name":"B Channel Shift Lower '
#           'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#           'Limit For Changing Values For Blue '
#           'Channel"},"upper_b_shift_limit":{"name":"B Channel Shift Upper '
#           'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#           'Limit For Changing Values For Blue '
#           'Channel"}}}},"sepia":{"name":"Sepia","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"solarize":{"name":"Solarize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"threshold":{"name":"Threshold","value":128,"default":128,"min":0,"max":255,"tooltip":"Invert '
#           'All Pixel Values Above A '
#           'Threshold"}}}}}}}}},"position":{"x":840,"y":375},"__rf":{"position":{"x":840,"y":375},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none","opacity":"100%"}},{"id":"2c3d4b45-d6ab-4048-bb3a-81a2d8f278dc","type":"fasterrcnn-inceptionv2-1024x1024","basetype":"model","data":{"schema":{"title":"FasterRCNN '
#           'InceptionV2 '
#           '1024x1024","tag":"fasterrcnn-inceptionv2-1024x1024","hasSource":true,"hasDestination":false,"subtitle":{"targetparam":"training","targetarg":"batchsize","template":"%% '
#           'Images per Batch"},"parameters":{"training":{"name":"Training '
#           'Parameters","args":{"batchsize":{"name":"Batch '
#           'Size","type":"number","value":2,"default":2},"epochs":{"name":"Training '
#           'Epochs","type":"number","value":"3000","default":1000}}},"pipeline":{"name":"Model '
#           'Configurations","args":{"max_detection_per_class":{"name":"Max '
#           'Detections Per '
#           'Class","type":"number","value":30,"default":30}}}}}},"position":{"x":840,"y":555},"__rf":{"position":{"x":840,"y":555},"width":260,"height":88,"handleBounds":{"source":null,"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false},"style":{"opacity":"100%","boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"source":"11833b3d-a445-4f08-acdb-ba477780470f","sourceHandle":null,"target":"65d6690c-2d32-450d-a09d-de9a142c364f","targetHandle":null,"animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-11833b3d-a445-4f08-acdb-ba477780470fnull-65d6690c-2d32-450d-a09d-de9a142c364fnull","type":"default","style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"source":"65d6690c-2d32-450d-a09d-de9a142c364f","sourceHandle":null,"target":"2c3d4b45-d6ab-4048-bb3a-81a2d8f278dc","targetHandle":null,"animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-65d6690c-2d32-450d-a09d-de9a142c364fnull-2c3d4b45-d6ab-4048-bb3a-81a2d8f278dcnull","type":"default"}]',
#  'title': 'My awesome workflow'}

# %% [markdown]
# ## 9.4. Delete A Workflow

# %% [markdown]
# Delete a workflow based on the specified workflow id.

# %%
# Delete workflow based on specified workflow id
workflow_delete_response = datature.Workflow.delete(
    workflow_list_response[0]["id"])

# Display response for the deletion of the workflow operation
pprint(workflow_delete_response)
# Out:
# {'deleted': True, 'id': 'flow_64893ef311c478ae88892823'}

# %% [markdown]
# # 10. Training API

# %% [markdown]
# This section describes all the operations with regards to the training run. The training run executes the training based on the selected workflow specified.

# %% [markdown]
# ## 10.1. Create A Training Run

# %% [markdown]
# Create a training run based on the specified configuration. For more information about how to configure the training run, please refer to the developer's documentation itself.

# %%
# Start a training run based on the specified workflow id and configurations
run_start_response = datature.Run.start(
    workflow_list_response[-1]["id"], {
        "accelerator": {
            "name": "GPU_T4",
            "count": 1
        },
        "checkpoint": {
            "strategy": "STRAT_LOWEST_VALIDATION_LOSS",
            "evaluation_interval": 250,
            "metric": "Loss/total_loss"
        },
        "limit": {
            "metric": "LIM_MINUTE",
            "value": 10
        },
        "preview": True,
        "matrix": True,
    })

# Display response of the creation of training run operation
pprint(run_start_response)
# Out:
# {'create_date': 1694169748440,
#  'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                'checkpoint': {'evaluation_interval': 250,
#                               'metric': 'Loss/total_loss',
#                               'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'},
#                'limit': {'metric': 'LIM_MINUTE', 'value': 10}},
#  'features': {'matrix': True, 'preview': True},
#  'flow_id': 'flow_64464b4338a13f0256bff73e',
#  'id': 'run_6c830a79-b82c-4817-a89a-e5bf3b16bf7c',
#  'last_modified_date': 1694169748440,
#  'logs': ['log_UjZjODMwYTc5LWI4MmMtNDgxNy1hODlhLWU1YmYzYjE2YmY3Yw'],
#  'object': 'run',
#  'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'status': {'conditions': [{'condition': 'TrainingStarted',
#                             'last_transition_time': 1694169748440,
#                             'status': 'waiting'}],
#             'last_updated': 1694169748440}}

# %% [markdown]
# ## 10.2. List All Training Runs

# %% [markdown]
# List all trainings runs in the project. This will include the metadata related to the training run. Do note that the information of the workflow that is used in the training run will not be dispayed and will require the use of the `workflow` API itself to retrieve the information related to it.

# %%
# List all training runs in the project
run_list_response = datature.Run.list()

# Display response for listing all the training runs operation
pprint(run_list_response)
# Out:
# [{'create_date': 1654058842202,
#   'execution': {'accelerator': {'count': 2, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_64423ec8d65b201e79a3fa6f',
#   'id': 'run_6296ef1f15462575f578ab1f',
#   'last_modified_date': 1654060814199,
#   'logs': ['log_UjYyOTZlZjFmMTU0NjI1NzVmNTc4YWIxZg'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingStarted',
#                              'last_transition_time': 1654058842202,
#                              'status': 'finished'},
#                             {'condition': 'TrainingFinished',
#                              'last_transition_time': 1654060814199,
#                              'status': 'finished'}],
#              'last_updated': 1654060814199}},
#  {'create_date': 1682328450825,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'DetectionBoxes_Precision/mAP',
#                                'strategy': 'STRAT_HIGHEST_ACCURACY'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_64464b4338a13f0256bff73e',
#   'id': 'run_d41b904b-20a3-4605-9d55-1fbf60ca34a4',
#   'last_modified_date': 1682329261575,
#   'logs': ['log_UmQ0MWI5MDRiLTIwYTMtNDYwNS05ZDU1LTFmYmY2MGNhMzRhNA'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1682329260675,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1682328691832,
#                              'status': 'finished'}],
#              'last_updated': 1682329260983}},
#  {'create_date': 1683190699920,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'DetectionBoxes_Precision/mAP',
#                                'strategy': 'STRAT_HIGHEST_ACCURACY'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_6453737c18c209847e08c110',
#   'id': 'run_23d1566f-d024-4450-8625-f93232cbe0f3',
#   'last_modified_date': 1683191862164,
#   'logs': ['log_UjIzZDE1NjZmLWQwMjQtNDQ1MC04NjI1LWY5MzIzMmNiZTBmMw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683191861517,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683191127741,
#                              'status': 'finished'}],
#              'last_updated': 1683191861669}},
#  {'create_date': 1683190634963,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'DetectionBoxes_Precision/mAP',
#                                'strategy': 'STRAT_HIGHEST_ACCURACY'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_645373479b7134f3a58c82d3',
#   'id': 'run_190786fa-975e-4031-bc1c-733f92475eed',
#   'last_modified_date': 1683191897417,
#   'logs': ['log_UjE5MDc4NmZhLTk3NWUtNDAzMS1iYzFjLTczM2Y5MjQ3NWVlZA'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683191896780,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683191127809,
#                              'status': 'finished'}],
#              'last_updated': 1683191896926}},
#  {'create_date': 1683193820563,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'Loss/total_loss',
#                                'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_64423ec8d65b201e79a3fa6f',
#   'id': 'run_296bc99c-2e69-49f1-80d1-10fe4e2167ca',
#   'last_modified_date': 1683196136823,
#   'logs': ['log_UjI5NmJjOTljLTJlNjktNDlmMS04MGQxLTEwZmU0ZTIxNjdjYQ'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683196136166,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683194070883,
#                              'status': 'finished'}],
#              'last_updated': 1683196136319}},
#  {'create_date': 1683199094481,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_64423ec8d65b201e79a3fa6f',
#   'id': 'run_2899e28b-336f-4717-9dd9-1a55761d3ef7',
#   'last_modified_date': 1683201427683,
#   'logs': ['log_UjI4OTllMjhiLTMzNmYtNDcxNy05ZGQ5LTFhNTU3NjFkM2VmNw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683201426854,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683199374569,
#                              'status': 'finished'}],
#              'last_updated': 1683201427005}},
#  {'create_date': 1683210626268,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_645373479b7134f3a58c82d3',
#   'id': 'run_7e2f82f6-b254-4862-96a5-3c34ce6e80c6',
#   'last_modified_date': 1683277045971,
#   'logs': ['log_UjdlMmY4MmY2LWIyNTQtNDg2Mi05NmE1LTNjMzRjZTZlODBjNg'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683277045211,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683276558163,
#                              'status': 'finished'}],
#              'last_updated': 1683277045341}},
#  {'create_date': 1683275285746,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_645373479b7134f3a58c82d3',
#   'id': 'run_1129bbb5-b59e-425a-a66a-e8103683013b',
#   'last_modified_date': 1683277048112,
#   'logs': ['log_UjExMjliYmI1LWI1OWUtNDI1YS1hNjZhLWU4MTAzNjgzMDEzYg'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683277047148,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683276557572,
#                              'status': 'finished'}],
#              'last_updated': 1683277047599}},
#  {'create_date': 1683210600326,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_6453737c18c209847e08c110',
#   'id': 'run_e71ffed8-46e0-4369-b7a2-1b1370d0ae82',
#   'last_modified_date': 1683277101824,
#   'logs': ['log_UmU3MWZmZWQ4LTQ2ZTAtNDM2OS1iN2EyLTFiMTM3MGQwYWU4Mg'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683277101251,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683276556793,
#                              'status': 'finished'}],
#              'last_updated': 1683277101379}},
#  {'create_date': 1686281366262,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'matrix': True, 'preview': True},
#   'flow_id': 'flow_64423ec8d65b201e79a3fa6f',
#   'id': 'run_86a2ab2c-5ecc-4f87-825b-7ffbdc047ddc',
#   'last_modified_date': 1686282232926,
#   'logs': ['log_Ujg2YTJhYjJjLTVlY2MtNGY4Ny04MjViLTdmZmJkYzA0N2RkYw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingStarted',
#                              'last_transition_time': 1686282231983,
#                              'status': 'waiting'}],
#              'last_updated': 1686282232298}},
#  {'create_date': 1686549521897,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'DetectionBoxes_Precision/mAP',
#                                'strategy': 'STRAT_HIGHEST_ACCURACY'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'matrix': True, 'preview': True},
#   'flow_id': 'flow_6486b3cb448256e87d1226cf',
#   'id': 'run_db7f7347-66a6-40b3-860b-1712cc830287',
#   'last_modified_date': 1686554268786,
#   'logs': ['log_UmRiN2Y3MzQ3LTY2YTYtNDBiMy04NjBiLTE3MTJjYzgzMDI4Nw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1686554268174,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1686549849355,
#                              'status': 'finished'}],
#              'last_updated': 1686554268322}},
#  {'create_date': 1687163931577,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'Loss/total_loss',
#                                'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'matrix': True, 'preview': True},
#   'flow_id': 'flow_64893ef311c478ae88892823',
#   'id': 'run_586152af-c6d0-4bf9-b12c-7a0a76e9ed5e',
#   'last_modified_date': 1687169763913,
#   'logs': ['log_UjU4NjE1MmFmLWM2ZDAtNGJmOS1iMTJjLTdhMGE3NmU5ZWQ1ZQ'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1687169763337,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1687164144050,
#                              'status': 'finished'}],
#              'last_updated': 1687169763465}},
#  {'create_date': 1688109072692,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'Loss/total_loss',
#                                'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'matrix': True, 'preview': True},
#   'flow_id': 'flow_649e7fd88dc827272f76341a',
#   'id': 'run_8d0e50be-d484-47d6-847a-e872418e61bc',
#   'last_modified_date': 1688109878734,
#   'logs': ['log_UjhkMGU1MGJlLWQ0ODQtNDdkNi04NDdhLWU4NzI0MThlNjFiYw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1688109878076,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1688109311598,
#                              'status': 'finished'}],
#              'last_updated': 1688109878202}},
#  {'create_date': 1690189584694,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'DetectionBoxes_Precision/mAP@.50IOU',
#                                'strategy': 'STRAT_HIGHEST_ACCURACY'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'matrix': False, 'preview': True},
#   'flow_id': 'flow_649e7fd88dc827272f76341a',
#   'id': 'run_0c57c457-64f3-42d2-9c6a-d6b1c939928b',
#   'last_modified_date': 1690190464732,
#   'logs': ['log_UjBjNTdjNDU3LTY0ZjMtNDJkMi05YzZhLWQ2YjFjOTM5OTI4Yg'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1690190463967,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1690189973813,
#                              'status': 'finished'}],
#              'last_updated': 1690190464101}},
#  {'create_date': 1694166095844,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'Loss/total_loss',
#                                'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'},
#                 'limit': {'metric': 'LIM_MINUTE', 'value': 10}},
#   'features': {'matrix': True, 'preview': True},
#   'flow_id': 'flow_64464b4338a13f0256bff73e',
#   'id': 'run_3bfbc1a4-1737-4271-84ea-216bf3ae924c',
#   'last_modified_date': 1694166911126,
#   'logs': ['log_UjNiZmJjMWE0LTE3MzctNDI3MS04NGVhLTIxNmJmM2FlOTI0Yw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1694166910440,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1694166348007,
#                              'status': 'finished'}],
#              'last_updated': 1694166910647}},
#  {'create_date': 1694169748440,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'Loss/total_loss',
#                                'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'},
#                 'limit': {'metric': 'LIM_MINUTE', 'value': 10}},
#   'features': {'matrix': True, 'preview': True},
#   'flow_id': 'flow_64464b4338a13f0256bff73e',
#   'id': 'run_6c830a79-b82c-4817-a89a-e5bf3b16bf7c',
#   'last_modified_date': 1694169748440,
#   'logs': ['log_UjZjODMwYTc5LWI4MmMtNDgxNy1hODlhLWU1YmYzYjE2YmY3Yw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingStarted',
#                              'last_transition_time': 1694169748440,
#                              'status': 'waiting'}],
#              'last_updated': 1694169748440}}]

# %% [markdown]
# ## 10.3. Retrieve A Training Log

# %% [markdown]
# Retrieves a training log based on the specified training log id. The log id related to the training run can be retrieved from retrieving the information about the training run itself. Retrieval of training run information can be found [here](#10.4.-Retrieve-A-Training-Run). The log details information like the loss and metrics of training run itself.

# %%
# Retrieve the log information based on the specified log id
run_log_response = datature.Run.log(
    run_list_response[0]["logs"][-1])

# Display response for the retrieval of log operation
pprint(run_list_response)
# Out:
# [{'create_date': 1654058842202,
#   'execution': {'accelerator': {'count': 2, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_64423ec8d65b201e79a3fa6f',
#   'id': 'run_6296ef1f15462575f578ab1f',
#   'last_modified_date': 1654060814199,
#   'logs': ['log_UjYyOTZlZjFmMTU0NjI1NzVmNTc4YWIxZg'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingStarted',
#                              'last_transition_time': 1654058842202,
#                              'status': 'finished'},
#                             {'condition': 'TrainingFinished',
#                              'last_transition_time': 1654060814199,
#                              'status': 'finished'}],
#              'last_updated': 1654060814199}},
#  {'create_date': 1682328450825,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'DetectionBoxes_Precision/mAP',
#                                'strategy': 'STRAT_HIGHEST_ACCURACY'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_64464b4338a13f0256bff73e',
#   'id': 'run_d41b904b-20a3-4605-9d55-1fbf60ca34a4',
#   'last_modified_date': 1682329261575,
#   'logs': ['log_UmQ0MWI5MDRiLTIwYTMtNDYwNS05ZDU1LTFmYmY2MGNhMzRhNA'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1682329260675,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1682328691832,
#                              'status': 'finished'}],
#              'last_updated': 1682329260983}},
#  {'create_date': 1683190699920,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'DetectionBoxes_Precision/mAP',
#                                'strategy': 'STRAT_HIGHEST_ACCURACY'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_6453737c18c209847e08c110',
#   'id': 'run_23d1566f-d024-4450-8625-f93232cbe0f3',
#   'last_modified_date': 1683191862164,
#   'logs': ['log_UjIzZDE1NjZmLWQwMjQtNDQ1MC04NjI1LWY5MzIzMmNiZTBmMw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683191861517,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683191127741,
#                              'status': 'finished'}],
#              'last_updated': 1683191861669}},
#  {'create_date': 1683190634963,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'DetectionBoxes_Precision/mAP',
#                                'strategy': 'STRAT_HIGHEST_ACCURACY'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_645373479b7134f3a58c82d3',
#   'id': 'run_190786fa-975e-4031-bc1c-733f92475eed',
#   'last_modified_date': 1683191897417,
#   'logs': ['log_UjE5MDc4NmZhLTk3NWUtNDAzMS1iYzFjLTczM2Y5MjQ3NWVlZA'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683191896780,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683191127809,
#                              'status': 'finished'}],
#              'last_updated': 1683191896926}},
#  {'create_date': 1683193820563,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'Loss/total_loss',
#                                'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_64423ec8d65b201e79a3fa6f',
#   'id': 'run_296bc99c-2e69-49f1-80d1-10fe4e2167ca',
#   'last_modified_date': 1683196136823,
#   'logs': ['log_UjI5NmJjOTljLTJlNjktNDlmMS04MGQxLTEwZmU0ZTIxNjdjYQ'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683196136166,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683194070883,
#                              'status': 'finished'}],
#              'last_updated': 1683196136319}},
#  {'create_date': 1683199094481,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_64423ec8d65b201e79a3fa6f',
#   'id': 'run_2899e28b-336f-4717-9dd9-1a55761d3ef7',
#   'last_modified_date': 1683201427683,
#   'logs': ['log_UjI4OTllMjhiLTMzNmYtNDcxNy05ZGQ5LTFhNTU3NjFkM2VmNw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683201426854,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683199374569,
#                              'status': 'finished'}],
#              'last_updated': 1683201427005}},
#  {'create_date': 1683210626268,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_645373479b7134f3a58c82d3',
#   'id': 'run_7e2f82f6-b254-4862-96a5-3c34ce6e80c6',
#   'last_modified_date': 1683277045971,
#   'logs': ['log_UjdlMmY4MmY2LWIyNTQtNDg2Mi05NmE1LTNjMzRjZTZlODBjNg'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683277045211,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683276558163,
#                              'status': 'finished'}],
#              'last_updated': 1683277045341}},
#  {'create_date': 1683275285746,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_645373479b7134f3a58c82d3',
#   'id': 'run_1129bbb5-b59e-425a-a66a-e8103683013b',
#   'last_modified_date': 1683277048112,
#   'logs': ['log_UjExMjliYmI1LWI1OWUtNDI1YS1hNjZhLWU4MTAzNjgzMDEzYg'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683277047148,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683276557572,
#                              'status': 'finished'}],
#              'last_updated': 1683277047599}},
#  {'create_date': 1683210600326,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'preview': True},
#   'flow_id': 'flow_6453737c18c209847e08c110',
#   'id': 'run_e71ffed8-46e0-4369-b7a2-1b1370d0ae82',
#   'last_modified_date': 1683277101824,
#   'logs': ['log_UmU3MWZmZWQ4LTQ2ZTAtNDM2OS1iN2EyLTFiMTM3MGQwYWU4Mg'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1683277101251,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1683276556793,
#                              'status': 'finished'}],
#              'last_updated': 1683277101379}},
#  {'create_date': 1686281366262,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'matrix': True, 'preview': True},
#   'flow_id': 'flow_64423ec8d65b201e79a3fa6f',
#   'id': 'run_86a2ab2c-5ecc-4f87-825b-7ffbdc047ddc',
#   'last_modified_date': 1686282232926,
#   'logs': ['log_Ujg2YTJhYjJjLTVlY2MtNGY4Ny04MjViLTdmZmJkYzA0N2RkYw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingStarted',
#                              'last_transition_time': 1686282231983,
#                              'status': 'waiting'}],
#              'last_updated': 1686282232298}},
#  {'create_date': 1686549521897,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'DetectionBoxes_Precision/mAP',
#                                'strategy': 'STRAT_HIGHEST_ACCURACY'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'matrix': True, 'preview': True},
#   'flow_id': 'flow_6486b3cb448256e87d1226cf',
#   'id': 'run_db7f7347-66a6-40b3-860b-1712cc830287',
#   'last_modified_date': 1686554268786,
#   'logs': ['log_UmRiN2Y3MzQ3LTY2YTYtNDBiMy04NjBiLTE3MTJjYzgzMDI4Nw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1686554268174,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1686549849355,
#                              'status': 'finished'}],
#              'last_updated': 1686554268322}},
#  {'create_date': 1687163931577,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'Loss/total_loss',
#                                'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'matrix': True, 'preview': True},
#   'flow_id': 'flow_64893ef311c478ae88892823',
#   'id': 'run_586152af-c6d0-4bf9-b12c-7a0a76e9ed5e',
#   'last_modified_date': 1687169763913,
#   'logs': ['log_UjU4NjE1MmFmLWM2ZDAtNGJmOS1iMTJjLTdhMGE3NmU5ZWQ1ZQ'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1687169763337,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1687164144050,
#                              'status': 'finished'}],
#              'last_updated': 1687169763465}},
#  {'create_date': 1688109072692,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'Loss/total_loss',
#                                'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'matrix': True, 'preview': True},
#   'flow_id': 'flow_649e7fd88dc827272f76341a',
#   'id': 'run_8d0e50be-d484-47d6-847a-e872418e61bc',
#   'last_modified_date': 1688109878734,
#   'logs': ['log_UjhkMGU1MGJlLWQ0ODQtNDdkNi04NDdhLWU4NzI0MThlNjFiYw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1688109878076,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1688109311598,
#                              'status': 'finished'}],
#              'last_updated': 1688109878202}},
#  {'create_date': 1690189584694,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'DetectionBoxes_Precision/mAP@.50IOU',
#                                'strategy': 'STRAT_HIGHEST_ACCURACY'},
#                 'limit': {'metric': 'LIM_NONE', 'value': 0}},
#   'features': {'matrix': False, 'preview': True},
#   'flow_id': 'flow_649e7fd88dc827272f76341a',
#   'id': 'run_0c57c457-64f3-42d2-9c6a-d6b1c939928b',
#   'last_modified_date': 1690190464732,
#   'logs': ['log_UjBjNTdjNDU3LTY0ZjMtNDJkMi05YzZhLWQ2YjFjOTM5OTI4Yg'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1690190463967,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1690189973813,
#                              'status': 'finished'}],
#              'last_updated': 1690190464101}},
#  {'create_date': 1694166095844,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'Loss/total_loss',
#                                'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'},
#                 'limit': {'metric': 'LIM_MINUTE', 'value': 10}},
#   'features': {'matrix': True, 'preview': True},
#   'flow_id': 'flow_64464b4338a13f0256bff73e',
#   'id': 'run_3bfbc1a4-1737-4271-84ea-216bf3ae924c',
#   'last_modified_date': 1694166911126,
#   'logs': ['log_UjNiZmJjMWE0LTE3MzctNDI3MS04NGVhLTIxNmJmM2FlOTI0Yw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingFinished',
#                              'last_transition_time': 1694166910440,
#                              'status': 'finished'},
#                             {'condition': 'TrainingStarted',
#                              'last_transition_time': 1694166348007,
#                              'status': 'finished'}],
#              'last_updated': 1694166910647}},
#  {'create_date': 1694169748440,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'Loss/total_loss',
#                                'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'},
#                 'limit': {'metric': 'LIM_MINUTE', 'value': 10}},
#   'features': {'matrix': True, 'preview': True},
#   'flow_id': 'flow_64464b4338a13f0256bff73e',
#   'id': 'run_6c830a79-b82c-4817-a89a-e5bf3b16bf7c',
#   'last_modified_date': 1694169748440,
#   'logs': ['log_UjZjODMwYTc5LWI4MmMtNDgxNy1hODlhLWU1YmYzYjE2YmY3Yw'],
#   'object': 'run',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'status': {'conditions': [{'condition': 'TrainingStarted',
#                              'last_transition_time': 1694169748440,
#                              'status': 'waiting'}],
#              'last_updated': 1694169748440}}]

# %% [markdown]
# ## 10.4. Retrieve A Training Run

# %% [markdown]
# Retrieves a training run based on the specified training run id.

# %%
# Retrieve the metadata for the specified training run id
run_retrieve_response = datature.Run.retrieve(
    run_list_response[0]["id"])

# Display response for the retrieval of training run operation
pprint(run_retrieve_response)
# Out:
# {'create_date': 1654058842202,
#  'execution': {'accelerator': {'count': 2, 'name': 'GPU_T4'},
#                'checkpoint': {'evaluation_interval': 250,
#                               'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                'limit': {'metric': 'LIM_NONE', 'value': 0}},
#  'features': {'preview': True},
#  'flow_id': 'flow_64423ec8d65b201e79a3fa6f',
#  'id': 'run_6296ef1f15462575f578ab1f',
#  'last_modified_date': 1654060814199,
#  'logs': ['log_UjYyOTZlZjFmMTU0NjI1NzVmNTc4YWIxZg'],
#  'object': 'run',
#  'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'status': {'conditions': [{'condition': 'TrainingStarted',
#                             'last_transition_time': 1654058842202,
#                             'status': 'finished'},
#                            {'condition': 'TrainingFinished',
#                             'last_transition_time': 1654060814199,
#                             'status': 'finished'}],
#             'last_updated': 1654060814199}}

# %% [markdown]
# ## 10.5. Kill A Training Run

# %% [markdown]
# Kill an ongoing training run based on the specified training run id. Note that the this will ony work if the training has already initialized and is currently ongoing.

# %%
# Kill an ongoing training run
run_kill_response = datature.Run.kill(
    run_list_response[0]["id"])

# Display response for the killing of training run operation
pprint(run_kill_response)
# Out:
# {'create_date': 1654058842202,
#  'execution': {'accelerator': {'count': 2, 'name': 'GPU_T4'},
#                'checkpoint': {'evaluation_interval': 250,
#                               'strategy': 'STRAT_ALWAYS_SAVE_LATEST'},
#                'limit': {'metric': 'LIM_NONE', 'value': 0}},
#  'features': {'preview': True},
#  'flow_id': 'flow_64423ec8d65b201e79a3fa6f',
#  'id': 'run_6296ef1f15462575f578ab1f',
#  'last_modified_date': 1654060814199,
#  'logs': ['log_UjYyOTZlZjFmMTU0NjI1NzVmNTc4YWIxZg'],
#  'object': 'run',
#  'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'status': {'conditions': [{'condition': 'TrainingStarted',
#                             'last_transition_time': 1654058842202,
#                             'status': 'finished'},
#                            {'condition': 'TrainingFinished',
#                             'last_transition_time': 1654060814199,
#                             'status': 'finished'}],
#             'last_updated': 1654060814199}}

# %% [markdown]
# # 11. Artifact API

# %% [markdown]
# This section contains all the operations with regards to the artifacts. Artifacts are the model files that are generated from the training runs where it can be exported to a variety of formats like `tensorflow`, `tflite` or `onnx`.

# %% [markdown]
# ## 11.1. List All Artifacts

# %% [markdown]
# List all artifacts in the project. The listed artifacts will include the metadata related to the artifacts like the `metric` and the `exports` that has been made to export the artifact to the specified model format as well as other metadata.

# %%
# List all artifacts in the project
artifact_list_response = datature.Artifact.list()

# Display response for the listing of all artifacts operations
pprint(artifact_list_response)
# Out:
# [{'artifact': 'ckpt-11',
#   'create_date': 1694166818555,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx'],
#   'exports': [],
#   'files': [{'md5': 'd13516a17fa610da3ac13f41eb60617e',
#              'name': 'ckpt-11.index'},
#             {'md5': '811d39fe19c8f4b05c0c9c2c92e35c7e',
#              'name': 'ckpt-11.data-00000-of-00001'}],
#   'flow_title': 'MobileNet',
#   'id': 'artifact_64faef23f5862ac2d3bd8072',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 0.104,
#              'localization_loss': 0.08,
#              'regularization_loss': 0.147,
#              'total_loss': 0.331},
#   'model_name': 'retina-mobilenetv2-320x320',
#   'model_type': 'objectDetection',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_3bfbc1a4-1737-4271-84ea-216bf3ae924c',
#   'step': 2500},
#  {'artifact': 'ckpt-4-datature-yolov8s',
#   'create_date': 1690190202619,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx', 'pytorch'],
#   'exports': ['pytorch', 'onnx'],
#   'files': [{'md5': 'a04272208d48fe97147581ef32c6e736',
#              'name': 'ckpt-4-datature-yolov8s.pt'}],
#   'flow_title': 'YOLOv8',
#   'id': 'artifact_64be417b734da9b23a14dd68',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 5.202, 'total_loss': 24.587},
#   'model_name': 'yolov8-small-320x320',
#   'model_type': 'yolov8',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_0c57c457-64f3-42d2-9c6a-d6b1c939928b',
#   'step': 4},
#  {'artifact': 'ckpt-12-datature-yolov8n',
#   'create_date': 1688109819811,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx', 'pytorch'],
#   'exports': ['onnx', 'pytorch'],
#   'files': [{'md5': '76954c2e7c32043c92bec635b17d34af',
#              'name': 'ckpt-12-datature-yolov8n.pt'}],
#   'flow_title': 'YOLOv8',
#   'id': 'artifact_649e82fc2e2afe4cb18ea169',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 2.181, 'total_loss': 10.165},
#   'model_name': 'yolov8-nano-320x320',
#   'model_type': 'yolov8',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_8d0e50be-d484-47d6-847a-e872418e61bc',
#   'step': 12},
#  {'artifact': 'ckpt-5',
#   'create_date': 1687166187979,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx'],
#   'exports': [],
#   'files': [{'md5': '09a42affbe455baecd3fd2da893c137d', 'name': 'ckpt-5.index'},
#             {'md5': '6d25cdfc6cd3ec6ce5d92a7239c95b53',
#              'name': 'ckpt-5.data-00000-of-00001'}],
#   'flow_title': 'My Workflow',
#   'id': 'artifact_64901cec4093d503c578d6c2',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 0.803,
#              'localization_loss': 1.976,
#              'regularization_loss': 0,
#              'total_loss': 2.778},
#   'model_name': 'fasterrcnn-inceptionv2-1024x1024',
#   'model_type': 'objectDetection',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_586152af-c6d0-4bf9-b12c-7a0a76e9ed5e',
#   'step': 1000},
#  {'artifact': 'ckpt-13',
#   'create_date': 1686554183165,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx'],
#   'exports': ['tensorflow', 'onnx'],
#   'files': [{'md5': 'b6025567ef1711c52b3d01bbd9b32a69',
#              'name': 'ckpt-13.index'},
#             {'md5': '6c309cecaf2d6a381e60b49aadc67998',
#              'name': 'ckpt-13.data-00000-of-00001'}],
#   'flow_title': 'FasterRCNN',
#   'id': 'artifact_6486c647f16c3d264ecc974a',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 1.43,
#              'localization_loss': 0.991,
#              'regularization_loss': 0,
#              'total_loss': 2.421},
#   'model_name': 'fasterrcnn-inceptionv2-640x640',
#   'model_type': 'objectDetection',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_db7f7347-66a6-40b3-860b-1712cc830287',
#   'step': 3000},
#  {'artifact': 'ckpt-12',
#   'create_date': 1683277042800,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx', 'pytorch'],
#   'exports': ['tensorflow', 'onnx', 'tflite', 'pytorch'],
#   'files': [{'md5': 'd0552c6f350d6d55fdd2dbcf477c7fc5', 'name': 'ckpt-12.pth'}],
#   'flow_title': 'YOLOX',
#   'id': 'artifact_6454c4f37ec1f032527481f6',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 0.669,
#              'localization_loss': 2.32,
#              'total_loss': 4.391},
#   'model_name': 'yolox-small-320x320',
#   'model_type': 'yolox',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_e71ffed8-46e0-4369-b7a2-1b1370d0ae82',
#   'step': 12},
#  {'artifact': 'ckpt-12',
#   'create_date': 1683277013681,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx', 'pytorch'],
#   'exports': [],
#   'files': [{'md5': 'd83aa726eaa1ece1048d0ac5005c616e', 'name': 'ckpt-12.h5'}],
#   'flow_title': 'YOLOv4',
#   'id': 'artifact_6454c4d57ec1f032527481e7',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 0.043,
#              'localization_loss': 10.077,
#              'total_loss': 19.77},
#   'model_name': 'yolov4-darknet-320x320',
#   'model_type': 'yolo',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_7e2f82f6-b254-4862-96a5-3c34ce6e80c6',
#   'step': 12},
#  {'artifact': 'ckpt-12',
#   'create_date': 1683277010021,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx', 'pytorch'],
#   'exports': ['tensorflow', 'tflite', 'onnx'],
#   'files': [{'md5': '3b7b0f5eed2e21091f8b28863c5e85a1', 'name': 'ckpt-12.h5'}],
#   'flow_title': 'YOLOv4',
#   'id': 'artifact_6454c4d27ec1f032527481e1',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 0.08,
#              'localization_loss': 10.178,
#              'total_loss': 19.802},
#   'model_name': 'yolov4-darknet-320x320',
#   'model_type': 'yolo',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_1129bbb5-b59e-425a-a66a-e8103683013b',
#   'step': 12},
#  {'artifact': 'ckpt-13',
#   'create_date': 1683201389747,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx'],
#   'exports': ['tensorflow', 'onnx', 'tflite'],
#   'files': [{'md5': '3b066faa168842e0fe91d7720d74acb4',
#              'name': 'ckpt-13.index'},
#             {'md5': 'd365ee3306fdedc2354b3eb1216d919c',
#              'name': 'ckpt-13.data-00000-of-00001'}],
#   'flow_title': 'EfficientDet',
#   'id': 'artifact_64539d6e9881d614656dedcf',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 0.47,
#              'localization_loss': 0.006,
#              'regularization_loss': 0.03,
#              'total_loss': 0.506},
#   'model_name': 'efficientdet-d1-640x640',
#   'model_type': 'objectDetection',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_2899e28b-336f-4717-9dd9-1a55761d3ef7',
#   'step': 3000},
#  {'artifact': 'ckpt-4',
#   'create_date': 1683194749747,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx'],
#   'exports': ['tensorflow', 'onnx', 'tflite'],
#   'files': [{'md5': '460835a9c6629667b6373a061806751c', 'name': 'ckpt-4.index'},
#             {'md5': '36991f189a59fee05f8fc5d3fa2e2d75',
#              'name': 'ckpt-4.data-00000-of-00001'}],
#   'flow_title': 'EfficientDet',
#   'id': 'artifact_6453837e9881d614656ded47',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 0.349,
#              'localization_loss': 0.009,
#              'regularization_loss': 0.03,
#              'total_loss': 0.388},
#   'model_name': 'efficientdet-d1-640x640',
#   'model_type': 'objectDetection',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_296bc99c-2e69-49f1-80d1-10fe4e2167ca',
#   'step': 750},
#  {'artifact': 'ckpt-20',
#   'create_date': 1683191834530,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx', 'pytorch'],
#   'exports': ['tensorflow', 'onnx', 'tflite', 'pytorch'],
#   'files': [{'md5': 'c2e4594c82c0572f24d98e04ca3f7748', 'name': 'ckpt-20.h5'}],
#   'flow_title': 'Copy of Blood Cell Detector',
#   'id': 'artifact_6453781b9881d614656ded14',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 0.051,
#              'localization_loss': 9.473,
#              'total_loss': 19.39},
#   'model_name': 'yolov4-darknet-320x320',
#   'model_type': 'yolo',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_190786fa-975e-4031-bc1c-733f92475eed',
#   'step': 20},
#  {'artifact': 'ckpt-20',
#   'create_date': 1683191821875,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx', 'pytorch'],
#   'exports': ['tensorflow', 'tflite', 'onnx', 'pytorch'],
#   'files': [{'md5': '786e25df3c534ae8dc05f0a34272bca5', 'name': 'ckpt-20.pth'}],
#   'flow_title': 'YOLOX',
#   'id': 'artifact_6453780e9881d614656ded0e',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 0.68,
#              'localization_loss': 2.267,
#              'total_loss': 4.555},
#   'model_name': 'yolox-small-320x320',
#   'model_type': 'yolox',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_23d1566f-d024-4450-8625-f93232cbe0f3',
#   'step': 20},
#  {'artifact': 'ckpt-13',
#   'create_date': 1682329224099,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx'],
#   'exports': ['tflite', 'tensorflow', 'onnx'],
#   'files': [{'md5': '6d150cb4512f789019396e5df86af946',
#              'name': 'ckpt-13.index'},
#             {'md5': 'c3ba2ac7852e4f1b91341fcdc8519467',
#              'name': 'ckpt-13.data-00000-of-00001'}],
#   'flow_title': 'MobileNet',
#   'id': 'artifact_64464e886e27181361740bbd',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 0.296,
#              'localization_loss': 0.166,
#              'regularization_loss': 0.147,
#              'total_loss': 0.609},
#   'model_name': 'retina-mobilenetv2-320x320',
#   'model_type': 'objectDetection',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_d41b904b-20a3-4605-9d55-1fbf60ca34a4',
#   'step': 3000},
#  {'artifact': 'ckpt-13',
#   'create_date': 1682063049129,
#   'exportable_formats': ['tensorflow', 'tflite', 'onnx'],
#   'exports': ['tensorflow', 'onnx', 'tflite'],
#   'flow_title': 'Blood Cell Detector',
#   'id': 'artifact_64423ec9d65b201e79a3fa73',
#   'is_deployed': True,
#   'is_training': False,
#   'metric': {'classification_loss': 0.537,
#              'localization_loss': 0.005,
#              'regularization_loss': 0.031,
#              'total_loss': 0.573},
#   'model_name': 'efficientdet-d1-640x640',
#   'model_type': 'objectDetection',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'run_id': 'run_6296ef1f15462575f578ab1f',
#   'step': 3000}]

# %% [markdown]
# ## 11.2. Retrieve An Artifact

# %% [markdown]
# Retrieves an artifact information based on the specified artifact id. The return response will include the metadata related to the specified artifact like the `metric` and the `exports` that has been made to export the artifact to the specified model format as well as other metadata.

# %%
# Retrieve an artifact's information based on the specified artifact id
artifact_retrieve_response = datature.Artifact.retrieve(
    artifact_list_response[0]["id"])

# Display response of artifact retrieval operation
pprint(artifact_retrieve_response)
# Out:
# {'artifact': 'ckpt-11',
#  'create_date': 1694166818555,
#  'exportable_formats': ['tensorflow', 'tflite', 'onnx'],
#  'exports': [],
#  'files': [{'md5': 'd13516a17fa610da3ac13f41eb60617e', 'name': 'ckpt-11.index'},
#            {'md5': '811d39fe19c8f4b05c0c9c2c92e35c7e',
#             'name': 'ckpt-11.data-00000-of-00001'}],
#  'flow_title': 'MobileNet',
#  'id': 'artifact_64faef23f5862ac2d3bd8072',
#  'is_deployed': False,
#  'is_training': False,
#  'metric': {'classification_loss': 0.104,
#             'localization_loss': 0.08,
#             'regularization_loss': 0.147,
#             'total_loss': 0.331},
#  'model_name': 'retina-mobilenetv2-320x320',
#  'model_type': 'objectDetection',
#  'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'run_id': 'run_3bfbc1a4-1737-4271-84ea-216bf3ae924c',
#  'step': 2500}

# %% [markdown]
# ## 11.3. Export An Artifact Model

# %% [markdown]
# Triggers an artifact export operation based on the specified artifact id as well as specified model format. Allowed formats to be exported are as follows:
#
# `tensorflow`, `tflite`, `onnx`, `pytorch`

# %%
# Export a model to the specified model format for specified artifact id
artifact_export_model_response = datature.Artifact.export_model(
    artifact_list_response[0]["id"], "onnx")

# Display response for triggering the export model artifact operation
pprint(artifact_export_model_response)
# Out:
# {'artifact_id': 'artifact_64faef23f5862ac2d3bd8072',
#  'create_date': 1694169788992,
#  'format': 'onnx',
#  'id': 'model_497wx2vy2xx16rr2r07qrw0y3vr62wy7',
#  'object': 'model',
#  'status': 'Queued'}

# %% [markdown]
# ## 11.4. Retrieve Exported Artifact Models

# %% [markdown]
# Retrieves all the models for an artifact based on the specified artifact id. The models here refers to the different possible model format that the artifact has been exported to like `tensorflow`, `tflite` or `onnx`.

# %%
# List all exported models for the specified artifact id
artifact_list_exported_response = datature.Artifact.list_exported(
    artifact_list_response[0]["id"])

# Display response for the list exported artifact response
pprint(artifact_list_exported_response)
# Out:
# [{'artifact_id': 'artifact_64faef23f5862ac2d3bd8072',
#   'create_date': 1694169788992,
#   'format': 'onnx',
#   'id': 'model_497wx2vy2xx16rr2r07qrw0y3vr62wy7',
#   'object': 'model',
#   'status': 'Queued'}]

# %% [markdown]
# # 12. Deploy API

# %% [markdown]
# This section describes all the operations related to deployment. Deployment helps to serve the model into an API endpoint to be consumed.

# %% [markdown]
# ## 12.1. Create A Deployment

# %% [markdown]
# Create a model deployment based on the specified model id. Configurable parameters are the `name` of the deployment as well as the `num_of_instances` which represents the number of instances of the model deployment to serve. Do note that it will take some time (5-7 minutes) for the deployment to be created.
#
# **NOTE: An ONNX model is required to be exported first in order to trigger the creation of a deployment API**

# %%
# Create a deployment based on the specified model id
deploy_create_response = datature.Deploy.create({
    "name": "My First API",
    "model_id": artifact_list_exported_response[0]["id"],
    "num_of_instances": 1,
})

# Display response of the create deployment operation
pprint(deploy_create_response)
# Out:
# {'artifact_id': 'artifact_64faef23f5862ac2d3bd8072',
#  'create_date': 1694169808750,
#  'id': 'deploy_cb9f0ed1-5905-46f8-874b-aba00b7687d4',
#  'last_modified_date': 1694169808750,
#  'name': 'My First API',
#  'object': 'deploy',
#  'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'resources': {'cpu': 4, 'ram': 8192},
#  'scaling': {'mode': 'FixedReplicaCount', 'num_instances': 1},
#  'status': {'message': 'Creating service',
#             'overview': 'CREATING',
#             'status_date': 1694169809792},
#  'version_tag': 'v1.0.0'}

# %% [markdown]
# ## 12.2. List All Deployments

# %% [markdown]
# List all deployments in a project. The listed deployments will include the metadata of related to the deployments like the `status` as well as the `scaling` method of the deployment along with other metadata.

# %%
# List all deployments in the project
deploy_list_response = datature.Deploy.list()

# Display response for listing of deployments operations
pprint(deploy_list_response)
# Out:
# [{'artifact_id': 'artifact_64423ec9d65b201e79a3fa73',
#   'create_date': 1694166452513,
#   'id': 'deploy_204a2b6b-f688-414f-a0c9-7f2dfac65f08',
#   'last_modified_date': 1694167615024,
#   'name': 'My Second API',
#   'object': 'deploy',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'resources': {'GPU_T4': 1, 'cpu': 8, 'ram': 8192},
#   'scaling': {'mode': 'FixedReplicaCount', 'num_instances': 1},
#   'status': {'message': 'Created service successfully',
#              'overview': 'AVAILABLE',
#              'status_date': 1694167614642},
#   'url': 'https://asia.inference.datature.io/204a2b6b-f688-414f-a0c9-7f2dfac65f08',
#   'version_tag': 'v2.0.0'},
#  {'artifact_id': 'artifact_64faef23f5862ac2d3bd8072',
#   'create_date': 1694169808750,
#   'id': 'deploy_cb9f0ed1-5905-46f8-874b-aba00b7687d4',
#   'last_modified_date': 1694169808750,
#   'name': 'My First API',
#   'object': 'deploy',
#   'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#   'resources': {'cpu': 4, 'ram': 8192},
#   'scaling': {'mode': 'FixedReplicaCount', 'num_instances': 1},
#   'status': {'message': 'Creating service',
#              'overview': 'CREATING',
#              'status_date': 1694169814380},
#   'version_tag': 'v1.0.0'}]

# %% [markdown]
# ## 12.3. Retrieve A Deployment

# %% [markdown]
# Retrieves a deployment based on the specified deployment id. The results will include the metadata of related to the deployments like the `status` as well as the `scaling` method of the deployment along with other metadata.

# %%
# Retrieve a deployment by the specified deployment id
deploy_retrieve_response = datature.Deploy.retrieve(
    deploy_list_response[0]["id"])

# Display response for the retrieval of deployment operation
pprint(deploy_retrieve_response)
# Out:
# {'artifact_id': 'artifact_64423ec9d65b201e79a3fa73',
#  'create_date': 1694166452513,
#  'id': 'deploy_204a2b6b-f688-414f-a0c9-7f2dfac65f08',
#  'last_modified_date': 1694167615024,
#  'name': 'My Second API',
#  'object': 'deploy',
#  'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'resources': {'GPU_T4': 1, 'cpu': 8, 'ram': 8192},
#  'scaling': {'mode': 'FixedReplicaCount', 'num_instances': 1},
#  'status': {'message': 'Created service successfully',
#             'overview': 'AVAILABLE',
#             'status_date': 1694167614642},
#  'url': 'https://asia.inference.datature.io/204a2b6b-f688-414f-a0c9-7f2dfac65f08',
#  'version_tag': 'v2.0.0'}

# %% [markdown]
# ## 12.4. Modify A Deployment

# %% [markdown]
# Modifies the configuration metadata of the deployment based on the specified deployment id.

# %%
# Modify the properties of the deployment based on the specified deployment id
deploy_modify_response = datature.Deploy.modify(
    deploy_list_response[-1]["id"], {
        "name": "My Second API",
        "resources": {
            "GPU_T4": 1
        },
        "version_tag": "car.staging.v2",
        "artifact_id": "artifact_63fd950a64845427a706d57d"
    })

# Display response for the modification of deployment operation
pprint(deploy_modify_response)
# Out:
# {'artifact_id': 'artifact_64faef23f5862ac2d3bd8072',
#  'create_date': 1694169808750,
#  'id': 'deploy_cb9f0ed1-5905-46f8-874b-aba00b7687d4',
#  'last_modified_date': 1694169824441,
#  'name': 'My Second API',
#  'object': 'deploy',
#  'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'resources': {'GPU_T4': 1, 'cpu': 8, 'ram': 8192},
#  'scaling': {'mode': 'FixedReplicaCount', 'num_instances': 1},
#  'status': {'message': 'Creating service',
#             'overview': 'UPDATING',
#             'status_date': 1694169825192},
#  'version_tag': 'v1.0.0'}

# %% [markdown]
# ## 12.5. Create New Version Tag Of A Deployment

# %% [markdown]
# Changes the version tag of the deployment based on the specified deployment id. This will trigger the deployment to be updated with a new artifact based on the artifact id provided.

# %%
# Create a new version for the specified deployment id
deploy_create_version_response = datature.Deploy.create_version(
    deploy_list_response[-1]["id"], "v2.0", artifact_list_response[-1]["id"])

# Display response for the creation of version operation
pprint(deploy_create_version_response)
# Out:
# {'artifact_id': 'artifact_64423ec9d65b201e79a3fa73',
#  'create_date': 1694169808750,
#  'id': 'deploy_cb9f0ed1-5905-46f8-874b-aba00b7687d4',
#  'last_modified_date': 1694169831838,
#  'name': 'My Second API',
#  'object': 'deploy',
#  'project_id': 'proj_2c2fc3676574f13413ecdf5a1ccf1473',
#  'resources': {'GPU_T4': 1, 'cpu': 8, 'ram': 8192},
#  'scaling': {'mode': 'FixedReplicaCount', 'num_instances': 1},
#  'status': {'message': 'Creating service',
#             'overview': 'UPDATING',
#             'status_date': 1694169832134},
#  'version_tag': 'v2.0'}

# %% [markdown]
# ## 12.6. Delete A Deployment

# %% [markdown]
# Delete a deployment based on the specified deployment id. Do note that it will take some time (5-7 minutes) for the deployment to be removed on the platform.

# %%
# Delete a deployment based on the specified deployment id
deploy_delete_response = datature.Deploy.delete(
    deploy_list_response[0]["id"]
)

# Display response for the deletion of the deployment operation
pprint(deploy_delete_response)
# Out:
# {'deleted': True, 'id': 'deploy_204a2b6b-f688-414f-a0c9-7f2dfac65f08'}
