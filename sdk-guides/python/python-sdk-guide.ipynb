# %% [markdown]
# This notebook is to give a brief overview on the different APIs provided by datature's python SDK. The notebook will simply demonstate how to use it and an example of how the output will look like. For more information, always refer to the developer's documentation for the details of the response's parameters.

# %% [markdown]
# ## Table Of Contents

# %% [markdown]
# 1. [Install Libraries](#1.-Install-Libraries)<br>
# 2. [Import Libraries](#2.-Import-Libraries)<br>
# 3. [Set Configurations](#3.-Set-Configurations)<br>
# 4. [Project API](#4.-Project-API)<br>
#     4.1. [Retrieve A Project](#4.1.-Retrieve-A-Project)<br>
#     4.2. [Update A Project](#4.2.-Update-A-Project)<br>
#     4.3. [Retrieve Project's Insights](#4.3.-Retrieve-Project's-Insights)<br>
#     4.4. [Retrieve Project's Quota](#4.4.-Retrieve-Project's-Quota)<br>
#     4.5. [Retrieve Project's Users](#4.5.-Retrieve-Project's-Users)<br>
# 5. [Asset API](#Asset-API)<br>
#     5.1. [List All Assets](#5.1.-List-All-Assets)<br>
#     5.2. [Create An Upload Session](#5.2.-Create-An-Upload-Session)<br>
#     5.3. [Retrieve An Asset](#5.3.-Retrieve-An-Asset)<br>
#     5.4. [Update An Asset](#5.4.-Update-An-Asset)<br>
#     5.5. [Delete An Asset](#5.5.-Delete-An-Asset)<br>
# 6. [Annotation API](#6.-Annotation-API)<br>
#     6.1. [Create An Annotation](#6.1.-Create-An-Annotation)<br>
#     6.2. [Export Annotations](#6.2.-Export-Annotations)<br>
#     6.3. [Retrieve Exported Annotations File](#6.3.-Retrieve-Exported-Annotations-File)<br>
#     6.4. [Import Annotations](#6.4.-Import-Annotations)<br>
#     6.5. [List All Annotations In An Asset](#6.5.-List-All-Annotations-In-An-Asset)<br>
#     6.6. [Retrieve An Annotation](#6.6.-Retrieve-An-Annotation)<br>
#     6.7. [Delete An Annotation](#6.7.-Delete-An-Annotation)<br>
# 7. [Operation API](#7.-Operation-API)<br>
#     7.1. [Retrieve An Operation](#7.1.-Retrieve-An-Operation)<br>
# 8. [Tag API](#8.-Tag-API)<br>
#     8.1. [Create A Tag](#8.1.-Create-A-Tag)<br>
#     8.2. [List All Tags](#8.2.-List-All-Tags)<br>
#     8.3. [Update A Tag](#8.3.-Update-A-Tag)<br>
#     8.4. [Delete A Tag](#8.4.-Delete-A-Tag)<br>
# 9. [Workflow API](#9.-Workflow-API)<br>
#     9.1. [List All Workflows](#9.1.-List-All-Workflows)<br>
#     9.2. [Retrieve A Workflow](#9.2.-Retrieve-A-Workflow)<br>
#     9.3. [Update A Workflow](#9.3.-Update-A-Workflow)<br>
#     9.4. [Delete A Workflow](#9.4.-Delete-A-Workflow)<br>
# 10. [Training API](#10.-Training-API)<br>
#     10.1. [Create A Training Run](#10.1.-Create-A-Training-Run)<br>
#     10.2. [List All Training Runs](#10.2.-List-All-Training-Runs)<br>
#     10.3. [Retrieve A Training Log](#10.3.-Retrieve-A-Training-Log)<br>
#     10.4. [Retrieve A Training Run](#10.4.-Retrieve-A-Training-Run)<br>
#     10.5. [Kill A Training Run](#10.5.-Kill-A-Training-Run)<br>
#     10.6. [Delete A Training Run](#10.6.-Delete-A-Training-Run)<br>
# 11. [Artifact API](#11.-Artifact-API)<br>
#     11.1. [List All Artifacts](#11.1.-List-All-Artifacts)<br>
#     11.2. [Retrieve An Artifact](#11.2.-Retrieve-An-Artifact)<br>
#     11.3. [Export An Artifact Model](#11.3.-Export-An-Artifact-Model)<br>
#     11.4. [Retrieve Artifact Models](#11.4.-Retrieve-Artifact-Models)<br>
# 12. [Deploy API](#12.-Deploy-API)<br>
#     12.1. [Create A Deployment](#12.1.-Create-A-Deployment)<br>
#     12.2. [List All Deployments](#12.2.-List-All-Deployments)<br>
#     12.3. [Retrieve A Deployment](#12.3.-Retrieve-A-Deployment)<br>
#     12.4. [Delete A Deployment](#12.4.-Delete-A-Deployment)<br>

# %% [markdown]
# # 1. Install Libraries

# %% [markdown]
# Run the command below to install the `datature` library.

# %%
# Use this to install the latest version of datature
# !pip install datature

# If a specific version is desired, please comment the above command and use the command below
# Replace the appropriate version value desired after '=='
# !pip install datature==0.6.0
# Out:
# Collecting datature
#   Using cached datature-0.6.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: pyhumps in /home/jianming/develop-3.8/lib/python3.8/site-packages (from datature) (3.8.0)
# Requirement already satisfied: google-crc32c in /home/jianming/develop-3.8/lib/python3.8/site-packages (from datature) (1.5.0)
# Requirement already satisfied: requests in /home/jianming/develop-3.8/lib/python3.8/site-packages (from datature) (2.28.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jianming/develop-3.8/lib/python3.8/site-packages (from requests->datature) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jianming/develop-3.8/lib/python3.8/site-packages (from requests->datature) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jianming/develop-3.8/lib/python3.8/site-packages (from requests->datature) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jianming/develop-3.8/lib/python3.8/site-packages (from requests->datature) (3.0.1)
# Installing collected packages: datature
# Successfully installed datature-0.6.2

# %% [markdown]
# # 2. Import Libraries

# %% [markdown]
# Import the necessary libraries to be used for this notebook. This includes the `datature` library itself to showcase how to use the different APIs present in the library.

# %%
import glob
import pprint

import datature

# %% [markdown]
# # 3. Set Configurations

# %% [markdown]
# Replace the project secret with your own project's secret. Do note that you will need to generate this secret key first on the Nexus platform first.
#
# **NOTE: Please remember to store your Secret Key somewhere safe. For illustration purpose, the secret key is written in the notebook.**

# %%
# Set project_secret
datature.project_secret = "<Please replace this string with your own project secret key>"

# %% [markdown]
# # 4. Project API

# %% [markdown]
# This section describes how to perform any operations with regards to any Project level operations.

# %% [markdown]
# ## 4.1. Retrieve A Project

# %% [markdown]
# Retrieves the overview information of the current project specified in the `project_secret` configured in the earlier section.

# %%
# Retrieve the current project's overview
project_retrieve_response = datature.Project.retrieve()
# Display response from the retrieve project operation
pprint.pprint(project_retrieve_response)
# Out:
# {'create_date': 1676342173637,
#  'id': 'proj_c4df32bdb04a34877c1693540a710b05',
#  'localization': 'MULTI',
#  'name': 'Example Ship Project',
#  'object': 'project',
#  'owner': 'user_63c4bee2aa7c3b289a5e02f3',
#  'statistic': {'annotation_total': 6168,
#                'asset_annotated': 483,
#                'asset_total': 488,
#                'tags_count': [{'count': 6168, 'name': 'boat'}]},
#  'tags': ['boat'],
#  'type': 'classification'}

# %% [markdown]
# ## 4.2. Update A Project

# %% [markdown]
# Performs an update on a property of the current project. Currently only allows updating the `name` property of the current project.

# %%
# Modify the project name's property
project_modify_response = datature.Project.modify(
    {"name": "My Cool Project"}
)
# Display response from the modify project operation
pprint.pprint(project_modify_response)
# Out:
# {'create_date': 1676342173637,
#  'id': 'proj_c4df32bdb04a34877c1693540a710b05',
#  'localization': 'MULTI',
#  'name': 'My Cool Project',
#  'object': 'project',
#  'owner': 'user_63c4bee2aa7c3b289a5e02f3',
#  'statistic': {'annotation_total': 6168,
#                'asset_annotated': 483,
#                'asset_total': 488,
#                'tags_count': [{'count': 6168, 'name': 'boat'}]},
#  'tags': ['boat'],
#  'type': 'classification'}

# %% [markdown]
# ## 4.3. Retrieve Project's Insights

# %% [markdown]
# Retrieves insights of the projects which involves the details of the training runs made during the lifetime of the project itself.

# %%
# Retrieve the project's insights
project_insight_response = datature.Project.insight()
# Display response from the retrival of project's insights operation
pprint.pprint(project_insight_response)
# Out:
# [{'batch_size': 2,
#   'checkpoint_every_n': 250,
#   'create_date': 1676361841029,
#   'data_type': 'bbox',
#   'epochs': 500,
#   'flow_title': 'Example Old Workflow',
#   'learning_rate': 0.04,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 1.484,
#              'localization_loss': 0.173,
#              'regularization_loss': 0,
#              'total_loss': 1.658},
#   'metric_target': 'STRAT_ALWAYS_SAVE_LATEST',
#   'mode_name': 'fasterrcnn-inceptionv2-1024x1024',
#   'momentum': 0.9,
#   'num_classes': 1,
#   'optimizer': 'momentum_optimizer',
#   'run_id': 'run_63eb3dfdf45218f93dbb34a4',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.3,
#   'statistic': {'average_annotations': 12.39},
#   'step': 0},
#  {'batch_size': 2,
#   'checkpoint_every_n': 100,
#   'create_date': 1676355798502,
#   'data_type': 'bbox',
#   'epochs': 300,
#   'flow_title': 'Example Old Workflow',
#   'learning_rate': 0.04,
#   'max_detection_per_class': 30,
#   'metric': {'classification_loss': 0.148,
#              'localization_loss': 0.195,
#              'regularization_loss': 0,
#              'total_loss': 0.343},
#   'metric_target': 'STRAT_ALWAYS_SAVE_LATEST',
#   'mode_name': 'fasterrcnn-inceptionv2-1024x1024',
#   'momentum': 0.9,
#   'num_classes': 1,
#   'optimizer': 'momentum_optimizer',
#   'run_id': 'run_63eb22b7bec73541a7b3728f',
#   'seed': 0,
#   'shuffle': True,
#   'split_ratio': 0.3,
#   'statistic': {'average_annotations': 3.27},
#   'step': 300}]

# %% [markdown]
# ## 4.4. Retrieve Project's Quota

# %% [markdown]
# Retrieves the different quotas limit and usage in a project.

# %%
# Retrieves the quotas in the project
project_quota_response = datature.Project.quota()
# Display response from the retrival of project's quota operation
pprint.pprint(project_quota_response)
# Out:
# {'limit': {'artifact': 50,
#            'artifact_export': 50,
#            'collaborator': 10,
#            'compute': 5000,
#            'external_source': 5,
#            'image': 10000,
#            'intellibrush': 5500,
#            'octopod': 5},
#  'usage': {'artifact': 2,
#            'artifact_export': 8,
#            'collaborator': 0,
#            'compute': 337.6,
#            'external_source': 0,
#            'image': 489,
#            'intellibrush': 16,
#            'octopod': 1}}

# %% [markdown]
# ## 4.5. Retrieve Project's Users

# %% [markdown]
# Retrieves all users in a project. This includes the metadata related to the individual users including the access type of the different users.

# %%
# Retrieves the quotas in the project
project_users_response = datature.Project.users()
# Display response from the retrival of project's quota operation
pprint.pprint(project_users_response)
# Out:
# [{'access_type': 'owner',
#   'email': 'jianming@datature.io',
#   'id': 'user_63c4bee2aa7c3b289a5e02f3',
#   'nickname': 'jianming',
#   'object': 'user',
#   'picture': 'https://s.gravatar.com/avatar/9937ab1b4a657a9688d02857a43a31a1?s=480&r=pg&d=https%3A%2F%2Fcdn.auth0.com%2Favatars%2Fji.png'}]

# %% [markdown]
# # 5. Asset API

# %% [markdown]
# This section describes how to perform any operations with regards to the assets in the project. The assets refer to the images and videos in general.

# %% [markdown]
# ## 5.1. List All Assets

# %% [markdown]
# List all the assets that are present in the project. The assets listed will include the metadata pertaining to each of the asset that is present in the project itself.
#
#
# **Note that the assets are paginated, meaning calling the list will not list all objects at once. The max `limit` that can be set for asset retrieval is `100`.**

# %%
# Retrieves the first page of the assets present in the project
asset_list_response = datature.Asset.list(
    {"limit": 3}
)
# Display response from the retrieval of the assets for the first page
pprint.pprint(asset_list_response)
# Out:
# {'data': [{'create_date': 1676342277486,
#            'filename': 'boat22.png',
#            'id': 'asset_b9bac26b-d7c7-40ac-be74-d26207f37056',
#            'metadata': {'file_size': 175891,
#                         'height': 356,
#                         'mime_type': 'image/png',
#                         'status': 'annotated',
#                         'width': 400},
#            'object': 'asset',
#            'project': 'proj_c4df32bdb04a34877c1693540a710b05',
#            'statistic': {'annotation_total': 24,
#                          'tags_count': [{'count': 24, 'name': 'boat'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/c4df32bdb04a34877c1693540a710b05/assets/boat22.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230214%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230214T024207Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1676342292125133&X-Goog-Signature=...'},
#           {'create_date': 1676342277486,
#            'filename': 'boat396.png',
#            'id': 'asset_717ebeaa-09e6-48da-99b2-9ae8924a0ce3',
#            'metadata': {'file_size': 130849,
#                         'height': 300,
#                         'mime_type': 'image/png',
#                         'status': 'annotated',
#                         'width': 306},
#            'object': 'asset',
#            'project': 'proj_c4df32bdb04a34877c1693540a710b05',
#            'statistic': {'annotation_total': 4,
#                          'tags_count': [{'count': 4, 'name': 'boat'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/c4df32bdb04a34877c1693540a710b05/assets/boat396.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230214%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230214T024207Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1676342291459685&X-Goog-Signature=...'},
#           {'create_date': 1676342277486,
#            'filename': 'boat248.png',
#            'id': 'asset_40075c3f-ff53-4b98-acff-831e6c297f97',
#            'metadata': {'file_size': 299961,
#                         'height': 510,
#                         'mime_type': 'image/png',
#                         'status': 'annotated',
#                         'width': 544},
#            'object': 'asset',
#            'project': 'proj_c4df32bdb04a34877c1693540a710b05',
#            'statistic': {'annotation_total': 4,
#                          'tags_count': [{'count': 4, 'name': 'boat'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/c4df32bdb04a34877c1693540a710b05/assets/boat248.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230214%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230214T024207Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1676342295307048&X-Goog-Signature=...'}],
#  'next_page': 'ZjYzZWFmNDA1MzVhN2FjMDBmMmIzYmFkNA'}

# %% [markdown]
# As there are limits set for listing of assets, to list the next batch of assets, simply retrieve the value from the `'next_page'` key and reuse the above method again.

# %%
# Retrieves the next page of the assets present in the project using the earlier list response
# This is to retrieve the page id to be passed into the body parameters
asset_list_next_response = datature.Asset.list(
    {"limit": 3, "page": asset_list_response['next_page']}
)
# Display response from the retrieval of the assets for the next page
pprint.pprint(asset_list_next_response)
# Out:
# {'data': [{'create_date': 1676342277486,
#            'filename': 'boat198.png',
#            'id': 'asset_7a7ad0ea-4a8d-487a-9816-4ee0faa574a1',
#            'metadata': {'file_size': 283916,
#                         'height': 394,
#                         'mime_type': 'image/png',
#                         'status': 'annotated',
#                         'width': 400},
#            'object': 'asset',
#            'project': 'proj_c4df32bdb04a34877c1693540a710b05',
#            'statistic': {'annotation_total': 8,
#                          'tags_count': [{'count': 8, 'name': 'boat'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/c4df32bdb04a34877c1693540a710b05/assets/boat198.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230214%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230214T024207Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1676342294637988&X-Goog-Signature=...'},
#           {'create_date': 1676342277486,
#            'filename': 'boat367.png',
#            'id': 'asset_b37645aa-27a6-448f-b6ab-9be13d9dd470',
#            'metadata': {'file_size': 271069,
#                         'height': 365,
#                         'mime_type': 'image/png',
#                         'status': 'annotated',
#                         'width': 400},
#            'object': 'asset',
#            'project': 'proj_c4df32bdb04a34877c1693540a710b05',
#            'statistic': {'annotation_total': 4,
#                          'tags_count': [{'count': 4, 'name': 'boat'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/c4df32bdb04a34877c1693540a710b05/assets/boat367.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230214%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230214T024207Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1676342293828675&X-Goog-Signature=...'},
#           {'create_date': 1676342277486,
#            'filename': 'boat284.png',
#            'id': 'asset_7fbc0edc-c3da-4887-b000-3d6d2ae64a19',
#            'metadata': {'file_size': 234307,
#                         'height': 243,
#                         'mime_type': 'image/png',
#                         'status': 'annotated',
#                         'width': 400},
#            'object': 'asset',
#            'project': 'proj_c4df32bdb04a34877c1693540a710b05',
#            'statistic': {'annotation_total': 820,
#                          'tags_count': [{'count': 820, 'name': 'boat'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/c4df32bdb04a34877c1693540a710b05/assets/boat284.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230214%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230214T024207Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1676342313758584&X-Goog-Signature=...'}],
#  'next_page': 'ZjYzZWFmNDA1MzVhN2FjMDBmMmIzYmFkZg',
#  'prev_page': 'YjYzZWFmNDA1MzVhN2FjMDBmMmIzYmFkNA'}

# %% [markdown]
# Likewise, if there is a need to navigate back to the previous page, simply retrieve the value from the `'prev_page'` key and reuse the above method again. With reference to the example in this section, the output of this code block will be the same as the very first code block demonstrating this API.

# %%
# Retrieves the previous page of the assets present in the project using the earlier list response
# This is to retrieve the page id to be passed into the body parameters
asset_list_prev_response = datature.Asset.list(
    {"limit": 3, "page": asset_list_next_response['prev_page']}
)
# Display response from the retrieval of the assets for the previous page
pprint.pprint(asset_list_prev_response)
# Out:
# {'data': [{'create_date': 1676342277486,
#            'filename': 'boat22.png',
#            'id': 'asset_b9bac26b-d7c7-40ac-be74-d26207f37056',
#            'metadata': {'file_size': 175891,
#                         'height': 356,
#                         'mime_type': 'image/png',
#                         'status': 'annotated',
#                         'width': 400},
#            'object': 'asset',
#            'project': 'proj_c4df32bdb04a34877c1693540a710b05',
#            'statistic': {'annotation_total': 24,
#                          'tags_count': [{'count': 24, 'name': 'boat'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/c4df32bdb04a34877c1693540a710b05/assets/boat22.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230214%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230214T024207Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1676342292125133&X-Goog-Signature=...'},
#           {'create_date': 1676342277486,
#            'filename': 'boat396.png',
#            'id': 'asset_717ebeaa-09e6-48da-99b2-9ae8924a0ce3',
#            'metadata': {'file_size': 130849,
#                         'height': 300,
#                         'mime_type': 'image/png',
#                         'status': 'annotated',
#                         'width': 306},
#            'object': 'asset',
#            'project': 'proj_c4df32bdb04a34877c1693540a710b05',
#            'statistic': {'annotation_total': 4,
#                          'tags_count': [{'count': 4, 'name': 'boat'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/c4df32bdb04a34877c1693540a710b05/assets/boat396.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230214%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230214T024207Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1676342291459685&X-Goog-Signature=...'},
#           {'create_date': 1676342277486,
#            'filename': 'boat248.png',
#            'id': 'asset_40075c3f-ff53-4b98-acff-831e6c297f97',
#            'metadata': {'file_size': 299961,
#                         'height': 510,
#                         'mime_type': 'image/png',
#                         'status': 'annotated',
#                         'width': 544},
#            'object': 'asset',
#            'project': 'proj_c4df32bdb04a34877c1693540a710b05',
#            'statistic': {'annotation_total': 4,
#                          'tags_count': [{'count': 4, 'name': 'boat'}]},
#            'url': 'https://storage.googleapis.com/assets.datature.io/c4df32bdb04a34877c1693540a710b05/assets/boat248.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230214%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230214T024207Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1676342295307048&X-Goog-Signature=...'}],
#  'next_page': 'ZjYzZWFmNDA1MzVhN2FjMDBmMmIzYmFkNA'}

# %% [markdown]
# ## 5.2. Create An Upload Session

# %% [markdown]
# Create an upload session. This is required to upload assets to the platform itself. For the types of assets that can be uploaded, both **images (.PNG, .JPG, .JPEG)** and **videos (.MP4)** are allowed to be uploaded.

# %%
# Instantiate an upload session
upload_session = datature.Asset.upload_session()

# %% [markdown]
# Once the session is created, simply run a loop to add all your desired files to be uploaded and start the upload

# %%
# Retrieve all filepaths of assets to be uploaded
filepaths = glob.glob("/home/assets/*")
# For loop to add the assets to be uploaded
for filepath in filepaths:
    upload_session.add(filepath)
# Execute the upload once all the specified assets to be uploaded have been added
asset_upload_session_start_response = upload_session.start(early_return=True)
# Display response of the asset upload operation
pprint.pprint(asset_upload_session_start_response)
# Out:
# {'op_link': 'users/api|9ba9baf9-178a-47ed-9d2b-60155eda2359/projects/c4df32bdb04a34877c1693540a710b05/operations/nexus.assets.upload/579f6273-cf62-46ad-b1bb-a59df2d0be39'}

# %% [markdown]
# To check on the status of the upload, simply use the `op_link` value from the response and call the retrieve operation API. To know more on how to use it, refer to [here](#7.1.-Retrieve-An-Operation).

# %%
# Retrieve the status for the asset upload operation
retrieve_asset_upload_operation_response = datature.Operation.retrieve(
    asset_upload_session_start_response['op_link']
)
# Display response of the asset upload status retrieval operation
pprint.pprint(retrieve_asset_upload_operation_response)
# Out:
# {'id': 'op_579f6273-cf62-46ad-b1bb-a59df2d0be39',
#  'object': 'operation',
#  'op_link': 'users/api|9ba9baf9-178a-47ed-9d2b-60155eda2359/projects/c4df32bdb04a34877c1693540a710b05/operations/nexus.assets.upload/579f6273-cf62-46ad-b1bb-a59df2d0be39',
#  'status': {'message': 'Operation running',
#             'overview': 'Running',
#             'progress': {'unit': 'asset',
#                          'with_status': {'cancelled': 0,
#                                          'errored': 0,
#                                          'finished': 0,
#                                          'queued': 5,
#                                          'running': 0}},
#             'time_scheduled': 1676365241869,
#             'time_updated': 1676365242383}}

# %% [markdown]
# ## 5.3. Retrieve An Asset

# %% [markdown]
# Retrieves an asset based on the specified asset id. This returns the metadata related to the specified asset which also includes an overview of the annotations present in the asset itself.

# %%
# Retrieve an asset based on the specified asset id
asset_retrieve_response = datature.Asset.retrieve(
    "asset_b9bac26b-d7c7-40ac-be74-d26207f37056"
)
# Display response of the retrieve asset operation
pprint.pprint(asset_retrieve_response)
# Out:
# {'create_date': 1676342277486,
#  'filename': 'boat22.png',
#  'id': 'asset_b9bac26b-d7c7-40ac-be74-d26207f37056',
#  'metadata': {'file_size': 175891,
#               'height': 356,
#               'mime_type': 'image/png',
#               'status': 'annotated',
#               'width': 400},
#  'object': 'asset',
#  'project': 'proj_c4df32bdb04a34877c1693540a710b05',
#  'statistic': {'annotation_total': 24,
#                'tags_count': [{'count': 24, 'name': 'boat'}]},
#  'url': 'https://storage.googleapis.com/assets.datature.io/c4df32bdb04a34877c1693540a710b05/assets/boat22.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230214%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230214T024207Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1676342292125133&X-Goog-Signature=...'}

# %% [markdown]
# ## 5.4. Update An Asset Status

# %% [markdown]
# Updates the specified asset's metadata based on the values of the parameters specified. Currently this only allows the update of the asset's `status`. Currently the allowed `status` are 'annotated', 'review', 'completed' and 'tofix'

# %%
# Modify the specified asset's metadata
asset_modify_response = datature.Asset.modify(
    "asset_b9bac26b-d7c7-40ac-be74-d26207f37056",
    asset_meta={"status": "annotated"}
)
# Display response of the modification of the specified asset's metadata
pprint.pprint(asset_modify_response)
# Out:
# {'create_date': 1676342277486,
#  'filename': 'boat22.png',
#  'id': 'asset_b9bac26b-d7c7-40ac-be74-d26207f37056',
#  'metadata': {'file_size': 175891,
#               'height': 356,
#               'mime_type': 'image/png',
#               'status': 'annotated',
#               'width': 400},
#  'object': 'asset',
#  'project': 'proj_c4df32bdb04a34877c1693540a710b05',
#  'statistic': {'annotation_total': 24,
#                'tags_count': [{'count': 24, 'name': 'boat'}]},
#  'url': 'https://storage.googleapis.com/assets.datature.io/c4df32bdb04a34877c1693540a710b05/assets/boat22.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcs-asset-signer%40datature-nexus.iam.gserviceaccount.com%2F20230214%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230214T024207Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&generation=1676342292125133&X-Goog-Signature=...'}

# %% [markdown]
# ## 5.5. Delete An Asset

# %% [markdown]
# Deletes an asset based on the specified asset id. Annotations related to this asset will also be deleted when this operation is executed.

# %%
# Delete the asset from the specified asset id
asset_delete_response = datature.Asset.delete(
    "asset_b9bac26b-d7c7-40ac-be74-d26207f37056"
)
# Display the response of the asset deletion operation
pprint.pprint(asset_delete_response)
# Out:
# {'deleted': True,
#  'id': 'asset_b9bac26b-d7c7-40ac-be74-d26207f37056',
#  'object': 'asset'}

# %% [markdown]
# # 6. Annotation API

# %% [markdown]
# This section describes how to perform any operations with regards to the annotations. Annotations are the labels that bounds and describes the objects of interest in the assets which are the images and videos themselves.

# %% [markdown]
# ## 6.1. Create An Annotation

# %% [markdown]
# Create a single annotation for the specified id. The annotation can either be `rectangle` and `polygon` for the `bound_type`.
#
# For the `bound_type` of `rectangle`, the format is as follows:
#
# `[ [xmin, ymin], [xmin, ymax], [xmax, ymax], [xmax, ymin] ]`
#
# For the `bound_type` of `polygon`, the format is as follows:
#
# `[ [x1, y1], [x2, y2], [x3, y3], ..., [xn, yn] ]`

# %%
# Create a new annotation for the specified asset id
annotation_create_response = datature.Annotation.create(
    {
        "asset_id": "asset_717ebeaa-09e6-48da-99b2-9ae8924a0ce3",
        "tag": "boat",
        "bound_type": "rectangle",
        "bound": [[0.775, 0.500],[0.775, 0.710],[0.858, 0.710],[0.858, 0.500]]
    }
)
# Display response of the creation of the annotaiton for the specified asset id
pprint.pprint(annotation_create_response)
# Out:
# {'asset_id': 'asset_717ebeaa-09e6-48da-99b2-9ae8924a0ce3',
#  'bound': [[0.775, 0.5], [0.775, 0.71], [0.858, 0.71], [0.858, 0.5]],
#  'bound_type': 'rectangle',
#  'id': 'annot_2b09b0dc-e2ba-4a3a-8c27-fbe6100e3a3a',
#  'object': 'annotation',
#  'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#  'tag': 'boat'}

# %% [markdown]
# ## 6.2. Export Annotations

# %% [markdown]
# Execute an export operation for the current set of annotations that are present on the project itself. Note that this starts the operation of the export and does not return the exported file directly.
#
# Current allow exported annotations formats are:
#
# `'csv_fourcorner', 'csv_widthheight', 'coco', 'pascal_voc', 'yolo_keras_pytorch', 'yolo_darknet', 'polygon_single', 'polygon_coco'`
#
# Please refer to the developer's documentation for more information about the different annotation formats as well as the description of the different configuration parameters.

# %%
# Request to start the export of the current annotations in the project
annotation_export_response = datature.Annotation.export(
    "csv_fourcorner",
    {"normalized": True, "shuffle": True, "split_ratio": 0.5,"seed": 1337},
    early_return=True
)
# Display response from the export of the current annotations operation
pprint.pprint(annotation_export_response)
# Out:
# {'id': 'op_869f0ccc-7d88-42e7-bccd-746d632de0a8',
#  'object': 'operation',
#  'op_link': 'users/api|9ba9baf9-178a-47ed-9d2b-60155eda2359/projects/c4df32bdb04a34877c1693540a710b05/operations/nexus.annotations.export/869f0ccc-7d88-42e7-bccd-746d632de0a8',
#  'status': {'message': 'Operation queued',
#             'overview': 'Queued',
#             'progress': {'unit': 'whole operation',
#                          'with_status': {'cancelled': 0,
#                                          'errored': 0,
#                                          'finished': 0,
#                                          'queued': 1,
#                                          'running': 0}},
#             'time_scheduled': 1676365276204,
#             'time_updated': 1676365276204}}

# %% [markdown]
# To track the status of the annotations export operation, simply use the `op_link` value from the response and call the retrieve operation API. To know more on how to use it, refer to [here](#7.1.-Retrieve-An-Operation).

# %%
# Retrieve the status for the export annotation operation
retrieve_export_annotation_operation_response = datature.Operation.retrieve(
    annotation_export_response['op_link']
)
# Display response of the export annotation status retrieval operation
pprint.pprint(retrieve_export_annotation_operation_response)
# Out:
# {'id': 'op_869f0ccc-7d88-42e7-bccd-746d632de0a8',
#  'object': 'operation',
#  'op_link': 'users/api|9ba9baf9-178a-47ed-9d2b-60155eda2359/projects/c4df32bdb04a34877c1693540a710b05/operations/nexus.annotations.export/869f0ccc-7d88-42e7-bccd-746d632de0a8',
#  'status': {'message': 'Operation finished',
#             'overview': 'Finished',
#             'payload': '',
#             'progress': {'unit': 'whole operation',
#                          'with_status': {'cancelled': 0,
#                                          'errored': 0,
#                                          'finished': 1,
#                                          'queued': 0,
#                                          'running': 0}},
#             'time_scheduled': 1676365276204,
#             'time_updated': 1676365280304}}

# %% [markdown]
# ## 6.3. Retrieve Exported Annotations File

# %% [markdown]
# Retrieves the url of the exported annotation file. Do note that this requires the previous code block above to be executed first to retrieve the related operation id to retrieve the download url for annotation file once the export is done. Retrieval of exported annotations is referenced by the `operation id` that executed the export of the annotations.

# %%
# Retrieve the url to download the exported annotations
annotation_retrieve_exported_file_response = datature.Annotation.retrieve_exported_file(
    "op_869f0ccc-7d88-42e7-bccd-746d632de0a8"
)
# Display response of the retrieval of the download url for the exported annotations operation
pprint.pprint(annotation_retrieve_exported_file_response)
# Out:
# {'download': {'expiry': 1676365641908,
#               'method': 'GET',
#               'url': 'https://storage.googleapis.com/exports.datature.io/c4df32bdb04a34877c1693540a710b05/annotations/869f0ccc-7d88-42e7-bccd-746d632de0a8.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=puppeteer-production%40datature-puppeteer.iam.gserviceaccount.com%2F20230214%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230214T090706Z&X-Goog-Expires=16&X-Goog-SignedHeaders=host&X-Goog-Signature=...'},
#  'op_id': 'op_869f0ccc-7d88-42e7-bccd-746d632de0a8',
#  'status': 'Finished'}

# %% [markdown]
# To download the exported annotations, simply copy the value in the `url` from the above response and paste it in the address bar of the browser to trigger the download.

# %% [markdown]
# ## 6.4. Import Annotations

# %% [markdown]
# Uploads an annotation file to be used for the project. Currently the allowed formats are as follows:
#
# `'csv_fourcorner', 'csv_widthheight', 'coco', 'pascal_voc', 'yolo_keras_pytorch', 'yolo_darknet', 'polygon_single', 'polygon_coco'`
#
# Please refer to the docs for more information about the different annotation formats.

# %%
# Uploads an annotation file to be imported into the project
annotation_upload_response = datature.Annotation.upload(
    "csv_fourcorner",
    "/home/Training.csv",
    early_return=True
)
# Display response of the upload annotation to be imported operation
pprint.pprint(annotation_upload_response)
# Out:
# {'id': 'op_b6d92abb-dd63-4856-9329-565d896fdeef',
#  'object': 'operation',
#  'op_link': 'users/api|9ba9baf9-178a-47ed-9d2b-60155eda2359/projects/c4df32bdb04a34877c1693540a710b05/operations/nexus.annotations.import/b6d92abb-dd63-4856-9329-565d896fdeef',
#  'status': {'message': 'Operation queued',
#             'overview': 'Queued',
#             'progress': {'unit': 'whole operation',
#                          'with_status': {'cancelled': 0,
#                                          'errored': 0,
#                                          'finished': 0,
#                                          'queued': 1,
#                                          'running': 0}},
#             'time_scheduled': 1676365303542,
#             'time_updated': 1676365303542}}

# %% [markdown]
# To track the status of the annotations import operation, simply use the `op_link` value from the response and call the retrieve operation API. To know more on how to use it, refer to [here](#7.1.-Retrieve-An-Operation).

# %%
# Retrieve the status for the upload annotation for import operation
retrieve_upload_annotation_operation_response = datature.Operation.retrieve(
    annotation_upload_response['op_link']
)
# Display response of the upload annotation for import status retrieval operation
pprint.pprint(retrieve_upload_annotation_operation_response)
# Out:
# {'id': 'op_b6d92abb-dd63-4856-9329-565d896fdeef',
#  'object': 'operation',
#  'op_link': 'users/api|9ba9baf9-178a-47ed-9d2b-60155eda2359/projects/c4df32bdb04a34877c1693540a710b05/operations/nexus.annotations.import/b6d92abb-dd63-4856-9329-565d896fdeef',
#  'status': {'message': 'Operation running',
#             'overview': 'Running',
#             'progress': {'unit': 'whole operation',
#                          'with_status': {'cancelled': 0,
#                                          'errored': 0,
#                                          'finished': 0,
#                                          'queued': 0,
#                                          'running': 1}},
#             'time_scheduled': 1676365303542,
#             'time_updated': 1676365305084}}

# %% [markdown]
# ## 6.5. List All Annotations In An Asset

# %% [markdown]
# List all annotations based on the specified asset id. This will include the `bound` of the annotation as well as the `bound_type` and the `tag` of the annotations along with other metadata related to the annotations for the specified asset.

# %%
# List all annotations based on the specified asset id
annotation_list_response = datature.Annotation.list(
    "asset_717ebeaa-09e6-48da-99b2-9ae8924a0ce3"
)
# Display response of the list annotations for the specified asset operation
pprint.pprint(annotation_list_response)
# Out:
# [{'asset_id': 'asset_717ebeaa-09e6-48da-99b2-9ae8924a0ce3',
#   'bound': [[0.4019607843137255, 0.3533333333333334],
#             [0.4019607843137255, 0.6033333333333333],
#             [0.6339869281045751, 0.6033333333333333],
#             [0.6339869281045751, 0.3533333333333334]],
#   'bound_type': 'rectangle',
#   'id': 'annot_2f1c573c-6701-47e0-bb19-f18fea4e6782',
#   'object': 'annotation',
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'tag': 'boat'},
#  {'asset_id': 'asset_717ebeaa-09e6-48da-99b2-9ae8924a0ce3',
#   'bound': [[0.4019607843137255, 0.3533333333333334],
#             [0.4019607843137255, 0.6033333333333333],
#             [0.6339869281045751, 0.6033333333333333],
#             [0.6339869281045751, 0.3533333333333334]],
#   'bound_type': 'rectangle',
#   'id': 'annot_e9ec533c-0fbb-4bad-a7ce-6fd56e4a2f7c',
#   'object': 'annotation',
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'tag': 'boat'},
#  {'asset_id': 'asset_717ebeaa-09e6-48da-99b2-9ae8924a0ce3',
#   'bound': [[0.4019607843137255, 0.3533333333333334],
#             [0.4019607843137255, 0.6033333333333333],
#             [0.6339869281045751, 0.6033333333333333],
#             [0.6339869281045751, 0.3533333333333334]],
#   'bound_type': 'rectangle',
#   'id': 'annot_79dcf79e-92a0-429c-bf68-acf34071c4b5',
#   'object': 'annotation',
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'tag': 'boat'},
#  {'asset_id': 'asset_717ebeaa-09e6-48da-99b2-9ae8924a0ce3',
#   'bound': [[0.4019607843137255, 0.3533333333333334],
#             [0.4019607843137255, 0.6033333333333333],
#             [0.6339869281045751, 0.6033333333333333],
#             [0.6339869281045751, 0.3533333333333334]],
#   'bound_type': 'rectangle',
#   'id': 'annot_1c5bb52d-c031-458b-83b9-134d77b4984c',
#   'object': 'annotation',
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'tag': 'boat'},
#  {'asset_id': 'asset_717ebeaa-09e6-48da-99b2-9ae8924a0ce3',
#   'bound': [[0.775, 0.5], [0.775, 0.71], [0.858, 0.71], [0.858, 0.5]],
#   'bound_type': 'rectangle',
#   'id': 'annot_2b09b0dc-e2ba-4a3a-8c27-fbe6100e3a3a',
#   'object': 'annotation',
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'tag': 'boat'}]

# %% [markdown]
# ## 6.6. Retrieve An Annotation

# %% [markdown]
# Retrieves an annotation based on the specified annotation id. This returns the metadata regarding the specified annotation id like the `bound` as well as the `bound_type` and `tag` along with other metadata related to the annotation.

# %%
# Retrieve the metadata for the specified annotation id
annotation_retrieve_response = datature.Annotation.retrieve(
    "annot_2b09b0dc-e2ba-4a3a-8c27-fbe6100e3a3a"
)
# Display response for the retrieve annotation operation 
pprint.pprint(annotation_retrieve_response)
# Out:
# {'asset_id': 'asset_717ebeaa-09e6-48da-99b2-9ae8924a0ce3',
#  'bound': [[0.775, 0.5], [0.775, 0.71], [0.858, 0.71], [0.858, 0.5]],
#  'bound_type': 'rectangle',
#  'id': 'annot_2b09b0dc-e2ba-4a3a-8c27-fbe6100e3a3a',
#  'object': 'annotation',
#  'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#  'tag': 'boat'}

# %% [markdown]
# ## 6.7. Delete An Annotation

# %% [markdown]
# Delete an annotation based on the specified annotation id.

# %%
# Delete an annotation based on the specified annotation id
annotation_delete_response = datature.Annotation.delete(
    "annot_2b09b0dc-e2ba-4a3a-8c27-fbe6100e3a3a"
)
# Display the response of the delete annotation operation
pprint.pprint(annotation_delete_response)
# Out:
# {'deleted': True,
#  'id': 'annot_2b09b0dc-e2ba-4a3a-8c27-fbe6100e3a3a',
#  'object': 'annotation'}

# %% [markdown]
# # 7. Operation API

# %% [markdown]
# This section describes how to keep track of any operations that is currently in progress on Nexus itself.

# %% [markdown]
# ## 7.1. Retrieve An Operation

# %% [markdown]
# Retrieves an operation based on the specified `op_link`. This should be the primary method to use if there is a need to keep track of any ongoing operations by polling the specified url using this method.

# %%
# Retrieve an operation based on the speicifed op_link
operation_retrieve_response = datature.Operation.retrieve(
    "users/api|9ba9baf9-178a-47ed-9d2b-60155eda2359/projects/c4df32bdb04a34877c1693540a710b05/operations/nexus.annotations.import/b6d92abb-dd63-4856-9329-565d896fdeef"
)
# Display response of the retrieve operation
pprint.pprint(operation_retrieve_response)
# Out:
# {'id': 'op_b6d92abb-dd63-4856-9329-565d896fdeef',
#  'object': 'operation',
#  'op_link': 'users/api|9ba9baf9-178a-47ed-9d2b-60155eda2359/projects/c4df32bdb04a34877c1693540a710b05/operations/nexus.annotations.import/b6d92abb-dd63-4856-9329-565d896fdeef',
#  'status': {'message': 'Operation finished',
#             'overview': 'Finished',
#             'payload': 'Number of files imported: 1',
#             'progress': {'unit': 'whole operation',
#                          'with_status': {'cancelled': 0,
#                                          'errored': 0,
#                                          'finished': 1,
#                                          'queued': 0,
#                                          'running': 0}},
#             'time_scheduled': 1676365303542,
#             'time_updated': 1676365308562}}

# %% [markdown]
# # 8. Tag API

# %% [markdown]
# This section describes the operations to be used to perform any operations with regards to the tags in the project. Tags are the name of labels (e.g. boat) to represent the annotations.

# %% [markdown]
# ## 8.1. Create A Tag

# %% [markdown]
# Creates a tag to be added to the project based on the specified `name` to allocate to the new tag.

# %%
# Create a new tag with the specified tag name
tag_create_response = datature.Tag.create(
    "new tag name"
)
# Display response for the create tag operation
pprint.pprint(tag_create_response)
# Out:
# [{'index': 0, 'name': 'boat'}, {'index': 1, 'name': 'new tag name'}]

# %% [markdown]
# ## 8.2. List All Tags

# %% [markdown]
# List all tags that exist in the project.

# %%
# List all tags in the project
tag_list_response = datature.Tag.list()
# Display response for listing all tags in the project operation
pprint.pprint(tag_list_response)
# Out:
# [{'index': 0, 'name': 'boat'}, {'index': 1, 'name': 'new tag name'}]

# %% [markdown]
# ## 8.3. Update A Tag

# %% [markdown]
# Updates the metadata of a tag object. Currently only `name` is allowed to be modified. Note that the to specify the tag to be modified, please reference the `index` of the tag to be modified as it is used by this method.

# %%
# Modify the metadata of the tag based on the specified index
tag_modify_response = datature.Tag.modify(index=1, name="modify tag name")
# Display response for the modification of tag operation
pprint.pprint(tag_modify_response)
# Out:
# [{'index': 0, 'name': 'boat'}, {'index': 1, 'name': 'modify tag name'}]

# %% [markdown]
# ## 8.4. Delete A Tag

# %% [markdown]
# Delete a tag based on the specified index.

# %%
# Delete a tag based on the specified index
tag_delete_response = datature.Tag.delete(index=1)
# Display response for the delete tag operation
pprint.pprint(tag_delete_response)
# Out:
# {'deleted': True}

# %% [markdown]
# # 9. Workflow API

# %% [markdown]
# This section contains all the operations with regards to the workflows. Workflows are the model training pipelines that are built by different building blocks.

# %% [markdown]
# ## 9.1. List All Workflows

# %% [markdown]
# List all workflows in the project itself. The returned workflows will include the metadata related to each of the workflows themselves.

# %%
# List all the workflows that exist in the project
workflow_list_response = datature.Workflow.list()
# Display response for the list all workflow operation
pprint.pprint(workflow_list_response)
# Out:
# [{'id': 'flow_63eb50320915a2159bf5442b',
#   'last_updated': 1676365892830,
#   'object': 'workflow',
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'state': '[{"id":"1676365876014","type":"dataset","basetype":"dataset","data":{"schema":{"title":"Dataset","hasSource":false,"hasDestination":true,"subtitle":{"targetparam":"dataset_setup","targetarg":"train_test_split","template":"Train-Test '
#            'Split %% Ratio"},"parameters":{"dataset_setup":{"name":"Dataset '
#            'Setup","args":{"train_test_split":{"name":"Train-Test '
#            'Split","type":"float","value":0.3,"default":0.3},"shuffle":{"name":"Shuffle '
#            'Dataset","type":"boolean","value":true,"default":true},"random_seed":{"name":"Random '
#            'Seed","type":"number","value":0,"default":0}}}}}},"position":{"x":450,"y":150},"__rf":{"position":{"x":450,"y":150},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":null},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"id":"1676365876027","type":"augmentation","basetype":"augmentation","data":{"schema":{"title":"Augmentations","hasSource":true,"hasDestination":true,"subtitle":{"targetparam":"options","targetarg":"advanced_mode","template":"Advanced '
#            'Mode : '
#            '%%"},"parameters":{"options":{"name":"Options","args":{"advanced_mode":{"name":"Advanced '
#            'Mode","type":"boolean","value":false,"default":false}}},"position_transforms":{"name":"Random '
#            'Position Augmentations","args":{"center_crop":{"name":"Center '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height Of The Crop '
#            '(1%-100%)"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width Of The Crop '
#            '(1%-100%)"}}}},"random_horizontal_flip":{"name":"Flip '
#            'Horizontal","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"random_vertical_flip":{"name":"Flip '
#            'Vertical","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"}}}},"random_crop":{"name":"Random '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height Of The '
#            'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width Of The Crop"}}}},"random_rotate":{"name":"Random '
#            'Rotate","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_rotation":{"name":"Minimum '
#            'Rotation","value":-90,"default":-90,"min":-180,"max":180,"tooltip":"Minimum '
#            'Rotation Angle"},"max_rotation":{"name":"Maximum '
#            'Rotation","value":90,"default":90,"min":-180,"max":180,"tooltip":"Maximum '
#            'Rotation Angle"}}}},"random_resized_crop":{"name":"Random Resized '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height Of The '
#            'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width Of The Crop"},"min_scale":{"name":"Minimum '
#            'Scale","value":0.08,"default":0.08,"min":0,"max":1,"tooltip":"Minimum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"max_scale":{"name":"Maximum '
#            'Scale","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"min_aspect_ratio":{"name":"Minimum Aspect '
#            'Ratio","value":0.75,"default":0.75,"min":0.1,"max":10,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"max_aspect_ratio":{"name":"Maximum Aspect '
#            'Ratio","value":1.33,"default":1.33,"min":0.1,"max":10,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"}}}},"random_sized_crop":{"name":"Random Sized '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_height":{"name":"Minimum Crop '
#            'Size '
#            'Height","value":50,"default":50,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Minimum Crop Size Limit"},"max_height":{"name":"Maximum '
#            'Crop Size '
#            'Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Maximum Crop Size '
#            'Height"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height After The Crop And '
#            'Resize"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width After The Crop And '
#            'Resize"},"w2h_ratio":{"name":"Width to Height '
#            'Ratio","value":1,"default":1,"min":0.1,"max":1,"tooltip":"Aspect '
#            'Ratio of Crop"}}}},"shift_scale_rotate":{"name":"Shift Scale '
#            'Rotate","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_shift":{"name":"Minimum '
#            'Shift","value":-0.0625,"default":-0.0625,"min":-1,"max":1,"tooltip":"Minimum '
#            'Range Of Shift Factor For Height And '
#            'Width"},"max_shift":{"name":"Maximum '
#            'Shift","value":0.0625,"default":0.0625,"min":-1,"max":1,"tooltip":"Maximum '
#            'Range Of Shift Factor For Height And '
#            'Width"},"min_scale":{"name":"Minimum '
#            'Scale","value":-0.1,"default":-0.1,"min":-2,"max":2,"tooltip":"Minimum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"max_scale":{"name":"Maximum '
#            'Scale","value":0.1,"default":0.1,"min":-2,"max":2,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"min_rotation":{"name":"Minimum '
#            'Rotation","value":-45,"default":-45,"min":-360,"max":360,"tooltip":"Minimum '
#            'Rotation Angle"},"max_rotation":{"name":"Maximum '
#            'Rotation","value":45,"default":45,"min":-360,"max":360,"tooltip":"Maximum '
#            'Rotation Angle"}}}}}},"color_transforms":{"name":"Color Space '
#            'Augmentations","args":{"channel_dropout":{"name":"Channel '
#            'Dropout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"min_channel_dropout_range":{"name":"Min Channel '
#            'Dropout '
#            'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Minimum '
#            'Channel Dropout Limit That Should Be Used For This '
#            'Augmentation"},"max_channel_dropout_range":{"name":"Max Channel '
#            'Dropout '
#            'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Maximum '
#            'Channel Dropout Limit That Should Be Used For This '
#            'Augmentation"},"fill_value":{"name":"Fill '
#            'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#            'Value For The Dropped '
#            'Channel"}}}},"channel_shuffle":{"name":"Channel '
#            'Shuffle","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"CLAHE":{"name":"CLAHE","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_clip_limit":{"name":"Min Clip '
#            'Limit","value":1,"default":1,"min":1,"max":100,"tooltip":"Lower '
#            'Threshold Value For Contrast '
#            'Limiting"},"max_clip_limit":{"name":"Max Clip '
#            'Limit","value":4,"default":4,"min":1,"max":100,"tooltip":"Upper '
#            'Threshold Value For Contrast '
#            'Limiting"},"min_tile_grid_size":{"name":"Min Grid '
#            'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Lower '
#            'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#            'Equalization"},"max_tile_grid_size":{"name":"Max Grid '
#            'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Upper '
#            'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#            'Equalization"}}}},"color_jitter":{"name":"Color '
#            'Jitter","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_brightness":{"name":"Min '
#            'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter '
#            'Brightness"},"max_brightness":{"name":"Max '
#            'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter '
#            'Brightness"},"min_contrast":{"name":"Min '
#            'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter Contrast"},"max_contrast":{"name":"Max '
#            'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter '
#            'Contrast"},"min_saturation":{"name":"Min '
#            'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter '
#            'Saturation"},"max_saturation":{"name":"Max '
#            'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter Saturation"},"min_hue":{"name":"Min '
#            'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter Hue"},"max_hue":{"name":"Max '
#            'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter '
#            'Hue"}}}},"cutout":{"name":"Cutout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"num_holes":{"name":"Number Of '
#            'Holes","value":8,"default":8,"min":0,"max":100,"tooltip":"Number '
#            'Of Regions To Zero Out"},"max_h_size":{"name":"Max Hole '
#            'Height","value":8,"default":8,"min":0,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Maximum Height Of The Hole."},"max_w_size":{"name":"Max '
#            'Hole '
#            'Width","value":8,"default":8,"min":0,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Maximum Width Of The Hole"},"fill_value":{"name":"Fill '
#            'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#            'Value For The Dropped '
#            'Channel"}}}},"equalize":{"name":"Equalize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"fancy_pca":{"name":"FancyPCA","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"alpha":{"name":"Alpha","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"How '
#            'Much To Pertub/Scale The Eigen Vectors And '
#            'Values"}}}},"gaussian_blur":{"name":"Gaussian '
#            'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_sigma":{"name":"Min Sigma '
#            'Minimum","value":0,"default":0,"min":0,"max":3,"tooltip":"Minimum '
#            'Gaussian Kernel Standard Deviation"},"max_sigma":{"name":"Max '
#            'Sigma '
#            'Minimum","value":3,"default":3,"min":0,"max":3,"tooltip":"Maximum '
#            'Gaussian Kernel Standard '
#            'Deviation"}}}},"gauss_noise":{"name":"Gaussian '
#            'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_var":{"name":"Min Variance '
#            'Range","value":10,"default":10,"min":0,"max":500,"tooltip":"Minimum '
#            'Variance Range For Noise"},"max_var":{"name":"Max Variance '
#            'Range","value":50,"default":50,"min":0,"max":500,"tooltip":"Maximum '
#            'Variance Range For '
#            'Noise"},"mean":{"name":"Mean","value":0,"default":0,"min":-100,"max":100,"tooltip":"Mean '
#            'Of The Noise"}}}},"glass_blur":{"name":"Glass '
#            'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"sigma":{"name":"Sigma","value":0.7,"default":0.7,"min":0,"max":3,"tooltip":"Standard '
#            'Deviation For Gaussian Kernel"},"max_delta":{"name":"Max '
#            'Delta","value":4,"default":4,"min":1,"max":10,"tooltip":"Max '
#            'Distance Between Pixels Which Are '
#            'Swapped"},"iterations":{"name":"Iterations","value":2,"default":2,"min":1,"max":10,"tooltip":"Number '
#            'Of '
#            'Repeats"}}}},"random_rgb_to_gray":{"name":"Grayscale","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"}}}},"hue_sat_val":{"name":"Hue '
#            'Saturation '
#            'Value","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_hue_shift":{"name":"Min Hue '
#            'Shift","value":-20,"default":-20,"min":-100,"max":100,"tooltip":"Minimum '
#            'Hue Shift Range Limit"},"max_hue_shift":{"name":"Max Hue '
#            'Shift","value":20,"default":20,"min":-100,"max":100,"tooltip":"Maximum '
#            'Hue Shift Range Limit"},"min_sat_shift":{"name":"Min Saturation '
#            'Shift","value":-30,"default":-30,"min":-100,"max":100,"tooltip":"Minimum '
#            'Saturation Shift Range Limit"},"max_sat_shift":{"name":"Max '
#            'Saturation '
#            'Shift","value":30,"default":30,"min":-100,"max":100,"tooltip":"Maximum '
#            'Saturation Shift Range Limit"},"min_val_shift":{"name":"Min Value '
#            'Shift","value":-20,"default":-20,"min":-100,"max":100,"tooltip":"Minimum '
#            'Value Shift Range Limit"},"max_val_shift":{"name":"Max Value '
#            'Shift","value":20,"default":20,"min":-100,"max":100,"tooltip":"Maximum '
#            'Value Shift Range Limit"}}}},"image_compression":{"name":"Image '
#            'Compression","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"quality_lower":{"name":"Lower '
#            'Quality '
#            'Limit","value":80,"default":80,"min":1,"max":100,"tooltip":"Lower '
#            'Bound On The Image Quality"},"quality_upper":{"name":"Upper '
#            'Quality '
#            'Limit","value":100,"default":100,"min":1,"max":100,"tooltip":"Upper '
#            'Bound On The Image Quality"}}}},"iso_noise":{"name":"ISO '
#            'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_color_shift":{"name":"Min '
#            'Color '
#            'Shift","value":0.01,"default":0.01,"min":0,"max":1,"tooltip":"Minimum '
#            'Variance Range For Color Hue '
#            'Change"},"max_color_shift":{"name":"Max Color '
#            'Shift","value":0.05,"default":0.05,"min":0,"max":1,"tooltip":"Maximum '
#            'Variance Range For Color Hue Change"},"min_intensity":{"name":"Min '
#            'Intensity","value":0.1,"default":0.1,"min":0,"max":2,"tooltip":"Minimum '
#            'Strength Of Color And Luminace '
#            'Noise"},"max_intensity":{"name":"Max '
#            'Intensity","value":0.5,"default":0.5,"min":0,"max":2,"tooltip":"Maximum '
#            'Strength Of Color And Luminace '
#            'Noise"}}}},"median_blur":{"name":"Median '
#            'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#            'Blur","value":7,"default":7,"min":7,"max":99,"tooltip":"Maximum '
#            'Aperture Linear Size For Blurring Input '
#            'Image"}}}},"motion_blur":{"name":"Motion '
#            'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#            'Blur","value":7,"default":7,"min":7,"max":100,"tooltip":"Maximum '
#            'Kernel Size For Blurring Input '
#            'Image"}}}},"multiplicative_noise":{"name":"Multiplicative '
#            'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_multi":{"name":"Min '
#            'Multiplication '
#            'Limit","value":0.9,"default":0.9,"min":0.1,"max":5,"tooltip":"Minimum '
#            'Random Number To Multiple With Input '
#            'Image"},"max_multi":{"name":"Max Multiplication '
#            'Limit","value":1.1,"default":1.1,"min":0.1,"max":5,"tooltip":"Maximum '
#            'Random Number To Multiple With Input '
#            'Image"}}}},"posterize":{"name":"Posterize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"r_bits":{"name":"R Channel Number '
#            'Of Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number '
#            'Of Bits For Red Channel"},"g_bits":{"name":"G Channel Number Of '
#            'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#            'Bits For Green Channel"},"b_bits":{"name":"B Channel Number Of '
#            'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#            'Bits For Blue Channel"}}}},"random_blur":{"name":"Random '
#            'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_blur_limit":{"name":"Min Blur '
#            'Limit","value":3,"default":3,"min":3,"max":100,"tooltip":"Minimum '
#            'Blur Limit That Should Be Used For This '
#            'Augmentation"},"max_blur_limit":{"name":"Max Blur '
#            'Limit","value":7,"default":7,"min":3,"max":100,"tooltip":"Maximum '
#            'Blur Limit That Should Be Used For This '
#            'Augmentation"}}}},"random_brightness":{"name":"Random '
#            'Brightness","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_limit":{"name":"Min '
#            'Brightness '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing Brightness"},"max_limit":{"name":"Max '
#            'Brightness '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Brightness"}}}},"random_brightness_contrast":{"name":"Random '
#            'Brightness '
#            'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_bright_limit":{"name":"Min '
#            'Brightness '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing '
#            'Brightness"},"max_bright_limit":{"name":"Max Brightness '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Brightness"},"min_contrast_limit":{"name":"Min Contrast '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing '
#            'Contrast"},"max_contrast_limit":{"name":"Max Contrast '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Contrast"}}}},"random_contrast":{"name":"Random '
#            'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_limit":{"name":"Min Contrast '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing Contrast"},"max_limit":{"name":"Max '
#            'Contrast '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Contrast"}}}},"random_fog":{"name":"Random '
#            'Fog","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"fog_coef_lower":{"name":"Lower '
#            'Coefficient '
#            'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#            'Limit For Fog Intensity '
#            'Coefficient"},"fog_coef_upper":{"name":"Upper Coefficient '
#            'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#            'Limit For Fog Intensity Coefficient"},"alpha_coef":{"name":"Alpha '
#            'Coefficient '
#            'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Transparency '
#            'Of Fog Circles"}}}},"random_gamma":{"name":"Random '
#            'Gamma","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_gamma_limit":{"name":"Min '
#            'Gamma '
#            'Limit","value":80,"default":80,"min":0,"max":200,"tooltip":"Minimum '
#            'Limit For Gamma Range"},"max_gamma_limit":{"name":"Max Gamma '
#            'Limit","value":120,"default":120,"min":0,"max":200,"tooltip":"Maximum '
#            'Limit For Gamma Range"}}}},"random_rain":{"name":"Random '
#            'Rain","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"slant_lower":{"name":"Lower '
#            'Slant","value":-10,"default":-10,"min":-20,"max":20,"tooltip":"Lower '
#            'Slant Of Rain Droplet"},"slant_upper":{"name":"Upper '
#            'Slant","value":10,"default":10,"min":-20,"max":20,"tooltip":"Upper '
#            'Slant Of Rain Droplet"},"drop_length":{"name":"Drop '
#            'Length","value":20,"default":20,"min":0,"max":100,"tooltip":"Length '
#            'Of Rain Droplet"},"drop_width":{"name":"Drop '
#            'Width","value":1,"default":1,"min":1,"max":5,"tooltip":"Width Of '
#            'Rain Droplet"},"drop_color_red":{"name":"Drop Color '
#            'Red","value":0,"default":0,"min":0,"max":255,"tooltip":"Red '
#            'Channel Rain Droplet"},"drop_color_green":{"name":"Drop Color '
#            'Green","value":0,"default":0,"min":0,"max":255,"tooltip":"Green '
#            'Channel Rain Droplet"},"drop_color_blue":{"name":"Drop Color '
#            'Blue","value":0,"default":0,"min":0,"max":255,"tooltip":"Blue '
#            'Channel Rain Droplet"},"blur_value":{"name":"Blur '
#            'Value","value":7,"default":7,"min":1,"max":15,"tooltip":"Blue '
#            'Channel Rain '
#            'Droplet"},"brightness_coefficient":{"name":"Brightness '
#            'Coefficient","value":0.7,"default":0.7,"min":0,"max":1,"tooltip":"Brightness '
#            'Coefficient Factor For Rain '
#            'Droplet"}}}},"random_shadow":{"name":"Random '
#            'Shadow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"x_min":{"name":"X '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#            'Axis Of Image Where Shadows Will Appear"},"y_min":{"name":"Y '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#            'Axis Of Image Where Shadows Will Appear"},"x_max":{"name":"X '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#            'Axis Of Image Where Shadows Will Appear"},"y_max":{"name":"Y '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#            'Axis Of Image Where Shadows Will '
#            'Appear"},"num_shadows_lower":{"name":"Number Of Shadows Lower '
#            'Limit","value":1,"default":1,"min":0,"max":20,"tooltip":"Lower '
#            'Limit For Possible Number Of '
#            'Shadows"},"num_shadows_upper":{"name":"Number Of Shadows Upper '
#            'Limit","value":5,"default":5,"min":0,"max":20,"tooltip":"Upper '
#            'Limit For Possible Number Of '
#            'Shadows"},"shadow_dimension":{"name":"Number Of '
#            'Edges","value":5,"default":5,"min":3,"max":20,"tooltip":"Number Of '
#            'Edges In Shadow Polygons"}}}},"random_snow":{"name":"Random '
#            'Snow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"snow_point_lower":{"name":"Lower '
#            'Snow '
#            'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#            'Limit Of The Amount Of Snow"},"snow_point_upper":{"name":"Upper '
#            'Snow '
#            'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#            'Limit Of The Amount Of '
#            'Snow"},"brightness_coefficient":{"name":"Brightness '
#            'Coefficient","value":2.5,"default":2.5,"min":0,"max":5,"tooltip":"Brightness '
#            'Coefficient Factor For Snow"}}}},"random_sunflare":{"name":"Random '
#            'Sun '
#            'Flare","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"x_min":{"name":"X '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#            'Axis Of Image Where Flares Will Appear"},"y_min":{"name":"Y '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#            'Axis Of Image Where Flares Will Appear"},"x_max":{"name":"X '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#            'Axis Of Image Where Flares Will Appear"},"y_max":{"name":"Y '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#            'Axis Of Image Where Flares Will '
#            'Appear"},"angle_lower":{"name":"Angle Lower '
#            'Limit","value":0,"default":0,"min":0,"max":1,"tooltip":"Lower '
#            'Limit For Flares Angle"},"angle_upper":{"name":"Angle Upper '
#            'Limit","value":1,"default":1,"min":0,"max":1,"tooltip":"Upper '
#            'Limit For Flares Angle"},"num_flare_circles_lower":{"name":"Number '
#            'Of Flares Lower '
#            'Limit","value":6,"default":6,"min":0,"max":20,"tooltip":"Lower '
#            'Limit For Possible Number Of '
#            'Flares"},"num_flare_circles_upper":{"name":"Number Of Flares Upper '
#            'Limit","value":10,"default":10,"min":0,"max":20,"tooltip":"Upper '
#            'Limit For Possible Number Of Flares"}}}},"rgb_shift":{"name":"RGB '
#            'Shift","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"lower_r_shift_limit":{"name":"R '
#            'Channel Shift Lower '
#            'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#            'Limit For Changing Values For Red '
#            'Channel"},"upper_r_shift_limit":{"name":"R Channel Shift Upper '
#            'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#            'Limit For Changing Values For Red '
#            'Channel"},"lower_g_shift_limit":{"name":"G Channel Shift Lower '
#            'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#            'Limit For Changing Values For Green '
#            'Channel"},"upper_g_shift_limit":{"name":"G Channel Shift Upper '
#            'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#            'Limit For Changing Values For Green '
#            'Channel"},"lower_b_shift_limit":{"name":"B Channel Shift Lower '
#            'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#            'Limit For Changing Values For Blue '
#            'Channel"},"upper_b_shift_limit":{"name":"B Channel Shift Upper '
#            'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#            'Limit For Changing Values For Blue '
#            'Channel"}}}},"sepia":{"name":"Sepia","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"solarize":{"name":"Solarize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"threshold":{"name":"Threshold","value":128,"default":128,"min":0,"max":255,"tooltip":"Invert '
#            'All Pixel Values Above A '
#            'Threshold"}}}}}}}}},"position":{"x":450,"y":345},"__rf":{"position":{"x":450,"y":345},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"id":"1676365876032","type":"fasterrcnn-inceptionv2-1024x1024","basetype":"model","data":{"schema":{"title":"FasterRCNN '
#            'InceptionV2 '
#            '1024x1024","tag":"fasterrcnn-inceptionv2-1024x1024","hasSource":true,"hasDestination":false,"subtitle":{"targetparam":"training","targetarg":"batchsize","template":"%% '
#            'Images per Batch"},"parameters":{"training":{"name":"Training '
#            'Parameters","args":{"batchsize":{"name":"Batch '
#            'Size","type":"number","value":2,"default":2},"epochs":{"name":"Training '
#            'Epochs","type":"number","value":1000,"default":1000}}},"pipeline":{"name":"Model '
#            'Configurations","args":{"max_detection_per_class":{"name":"Max '
#            'Detections Per '
#            'Class","type":"number","value":30,"default":30}}}}}},"position":{"x":450,"y":555},"__rf":{"position":{"x":450,"y":555},"width":260,"height":88,"handleBounds":{"source":null,"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false}},{"source":"1676365876014","target":"1676365876027","animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-1676365876014undefined-1676365876027undefined","sourceHandle":null,"targetHandle":null,"type":"default"},{"source":"1676365876027","target":"1676365876032","animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-1676365876027undefined-1676365876032undefined","sourceHandle":null,"targetHandle":null,"type":"default"}]',
#   'title': 'Example Workflow To Be Deleted'},
#  {'id': 'flow_63eb229abec73541a7b37280',
#   'last_updated': 1676361213209,
#   'object': 'workflow',
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'state': '[{"id":"1676354211779","type":"dataset","basetype":"dataset","data":{"schema":{"title":"Dataset","hasSource":false,"hasDestination":true,"subtitle":{"targetparam":"dataset_setup","targetarg":"train_test_split","template":"Train-Test '
#            'Split %% Ratio"},"parameters":{"dataset_setup":{"name":"Dataset '
#            'Setup","args":{"train_test_split":{"name":"Train-Test '
#            'Split","type":"float","value":0.3,"default":0.3},"shuffle":{"name":"Shuffle '
#            'Dataset","type":"boolean","value":true,"default":true},"random_seed":{"name":"Random '
#            'Seed","type":"number","value":0,"default":0}}}}}},"position":{"x":450,"y":150},"__rf":{"position":{"x":450,"y":150},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":null},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"id":"1676354211789","type":"augmentation","basetype":"augmentation","data":{"schema":{"title":"Augmentations","hasSource":true,"hasDestination":true,"subtitle":{"targetparam":"options","targetarg":"advanced_mode","template":"Advanced '
#            'Mode : '
#            '%%"},"parameters":{"options":{"name":"Options","args":{"advanced_mode":{"name":"Advanced '
#            'Mode","type":"boolean","value":false,"default":false}}},"position_transforms":{"name":"Random '
#            'Position Augmentations","args":{"center_crop":{"name":"Center '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height Of The Crop '
#            '(1%-100%)"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width Of The Crop '
#            '(1%-100%)"}}}},"random_horizontal_flip":{"name":"Flip '
#            'Horizontal","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"random_vertical_flip":{"name":"Flip '
#            'Vertical","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"}}}},"random_crop":{"name":"Random '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height Of The '
#            'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width Of The Crop"}}}},"random_rotate":{"name":"Random '
#            'Rotate","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_rotation":{"name":"Minimum '
#            'Rotation","value":-90,"default":-90,"min":-180,"max":180,"tooltip":"Minimum '
#            'Rotation Angle"},"max_rotation":{"name":"Maximum '
#            'Rotation","value":90,"default":90,"min":-180,"max":180,"tooltip":"Maximum '
#            'Rotation Angle"}}}},"random_resized_crop":{"name":"Random Resized '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height Of The '
#            'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width Of The Crop"},"min_scale":{"name":"Minimum '
#            'Scale","value":0.08,"default":0.08,"min":0,"max":1,"tooltip":"Minimum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"max_scale":{"name":"Maximum '
#            'Scale","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"min_aspect_ratio":{"name":"Minimum Aspect '
#            'Ratio","value":0.75,"default":0.75,"min":0.1,"max":10,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"max_aspect_ratio":{"name":"Maximum Aspect '
#            'Ratio","value":1.33,"default":1.33,"min":0.1,"max":10,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"}}}},"random_sized_crop":{"name":"Random Sized '
#            'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_height":{"name":"Minimum Crop '
#            'Size '
#            'Height","value":50,"default":50,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Minimum Crop Size Limit"},"max_height":{"name":"Maximum '
#            'Crop Size '
#            'Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Maximum Crop Size '
#            'Height"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Height After The Crop And '
#            'Resize"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#            '(1%-99%) Width After The Crop And '
#            'Resize"},"w2h_ratio":{"name":"Width to Height '
#            'Ratio","value":1,"default":1,"min":0.1,"max":1,"tooltip":"Aspect '
#            'Ratio of Crop"}}}},"shift_scale_rotate":{"name":"Shift Scale '
#            'Rotate","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_shift":{"name":"Minimum '
#            'Shift","value":-0.0625,"default":-0.0625,"min":-1,"max":1,"tooltip":"Minimum '
#            'Range Of Shift Factor For Height And '
#            'Width"},"max_shift":{"name":"Maximum '
#            'Shift","value":0.0625,"default":0.0625,"min":-1,"max":1,"tooltip":"Maximum '
#            'Range Of Shift Factor For Height And '
#            'Width"},"min_scale":{"name":"Minimum '
#            'Scale","value":-0.1,"default":-0.1,"min":-2,"max":2,"tooltip":"Minimum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"max_scale":{"name":"Maximum '
#            'Scale","value":0.1,"default":0.1,"min":-2,"max":2,"tooltip":"Maximum '
#            'Range Of Size Of The Origin Size '
#            'Cropped"},"min_rotation":{"name":"Minimum '
#            'Rotation","value":-45,"default":-45,"min":-360,"max":360,"tooltip":"Minimum '
#            'Rotation Angle"},"max_rotation":{"name":"Maximum '
#            'Rotation","value":45,"default":45,"min":-360,"max":360,"tooltip":"Maximum '
#            'Rotation Angle"}}}}}},"color_transforms":{"name":"Color Space '
#            'Augmentations","args":{"channel_dropout":{"name":"Channel '
#            'Dropout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"min_channel_dropout_range":{"name":"Min Channel '
#            'Dropout '
#            'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Minimum '
#            'Channel Dropout Limit That Should Be Used For This '
#            'Augmentation"},"max_channel_dropout_range":{"name":"Max Channel '
#            'Dropout '
#            'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Maximum '
#            'Channel Dropout Limit That Should Be Used For This '
#            'Augmentation"},"fill_value":{"name":"Fill '
#            'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#            'Value For The Dropped '
#            'Channel"}}}},"channel_shuffle":{"name":"Channel '
#            'Shuffle","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"CLAHE":{"name":"CLAHE","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_clip_limit":{"name":"Min Clip '
#            'Limit","value":1,"default":1,"min":1,"max":100,"tooltip":"Lower '
#            'Threshold Value For Contrast '
#            'Limiting"},"max_clip_limit":{"name":"Max Clip '
#            'Limit","value":4,"default":4,"min":1,"max":100,"tooltip":"Upper '
#            'Threshold Value For Contrast '
#            'Limiting"},"min_tile_grid_size":{"name":"Min Grid '
#            'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Lower '
#            'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#            'Equalization"},"max_tile_grid_size":{"name":"Max Grid '
#            'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Upper '
#            'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#            'Equalization"}}}},"color_jitter":{"name":"Color '
#            'Jitter","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_brightness":{"name":"Min '
#            'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter '
#            'Brightness"},"max_brightness":{"name":"Max '
#            'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter '
#            'Brightness"},"min_contrast":{"name":"Min '
#            'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter Contrast"},"max_contrast":{"name":"Max '
#            'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter '
#            'Contrast"},"min_saturation":{"name":"Min '
#            'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter '
#            'Saturation"},"max_saturation":{"name":"Max '
#            'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter Saturation"},"min_hue":{"name":"Min '
#            'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Minimum '
#            'Limit Of How Much To Jitter Hue"},"max_hue":{"name":"Max '
#            'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Maximum '
#            'Limit Of How Much To Jitter '
#            'Hue"}}}},"cutout":{"name":"Cutout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"num_holes":{"name":"Number Of '
#            'Holes","value":8,"default":8,"min":0,"max":100,"tooltip":"Number '
#            'Of Regions To Zero Out"},"max_h_size":{"name":"Max Hole '
# ...
#            'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#            'Blur","value":7,"default":7,"min":7,"max":100,"tooltip":"Maximum '
#            'Kernel Size For Blurring Input '
#            'Image"}}}},"multiplicative_noise":{"name":"Multiplicative '
#            'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_multi":{"name":"Min '
#            'Multiplication '
#            'Limit","value":0.9,"default":0.9,"min":0.1,"max":5,"tooltip":"Minimum '
#            'Random Number To Multiple With Input '
#            'Image"},"max_multi":{"name":"Max Multiplication '
#            'Limit","value":1.1,"default":1.1,"min":0.1,"max":5,"tooltip":"Maximum '
#            'Random Number To Multiple With Input '
#            'Image"}}}},"posterize":{"name":"Posterize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"r_bits":{"name":"R Channel Number '
#            'Of Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number '
#            'Of Bits For Red Channel"},"g_bits":{"name":"G Channel Number Of '
#            'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#            'Bits For Green Channel"},"b_bits":{"name":"B Channel Number Of '
#            'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#            'Bits For Blue Channel"}}}},"random_blur":{"name":"Random '
#            'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_blur_limit":{"name":"Min Blur '
#            'Limit","value":3,"default":3,"min":3,"max":100,"tooltip":"Minimum '
#            'Blur Limit That Should Be Used For This '
#            'Augmentation"},"max_blur_limit":{"name":"Max Blur '
#            'Limit","value":7,"default":7,"min":3,"max":100,"tooltip":"Maximum '
#            'Blur Limit That Should Be Used For This '
#            'Augmentation"}}}},"random_brightness":{"name":"Random '
#            'Brightness","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_limit":{"name":"Min '
#            'Brightness '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing Brightness"},"max_limit":{"name":"Max '
#            'Brightness '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Brightness"}}}},"random_brightness_contrast":{"name":"Random '
#            'Brightness '
#            'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_bright_limit":{"name":"Min '
#            'Brightness '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing '
#            'Brightness"},"max_bright_limit":{"name":"Max Brightness '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Brightness"},"min_contrast_limit":{"name":"Min Contrast '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing '
#            'Contrast"},"max_contrast_limit":{"name":"Max Contrast '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Contrast"}}}},"random_contrast":{"name":"Random '
#            'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_limit":{"name":"Min Contrast '
#            'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#            'Factor Range For Changing Contrast"},"max_limit":{"name":"Max '
#            'Contrast '
#            'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#            'Factor Range For Changing '
#            'Contrast"}}}},"random_fog":{"name":"Random '
#            'Fog","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"fog_coef_lower":{"name":"Lower '
#            'Coefficient '
#            'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#            'Limit For Fog Intensity '
#            'Coefficient"},"fog_coef_upper":{"name":"Upper Coefficient '
#            'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#            'Limit For Fog Intensity Coefficient"},"alpha_coef":{"name":"Alpha '
#            'Coefficient '
#            'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Transparency '
#            'Of Fog Circles"}}}},"random_gamma":{"name":"Random '
#            'Gamma","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"min_gamma_limit":{"name":"Min '
#            'Gamma '
#            'Limit","value":80,"default":80,"min":0,"max":200,"tooltip":"Minimum '
#            'Limit For Gamma Range"},"max_gamma_limit":{"name":"Max Gamma '
#            'Limit","value":120,"default":120,"min":0,"max":200,"tooltip":"Maximum '
#            'Limit For Gamma Range"}}}},"random_rain":{"name":"Random '
#            'Rain","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"slant_lower":{"name":"Lower '
#            'Slant","value":-10,"default":-10,"min":-20,"max":20,"tooltip":"Lower '
#            'Slant Of Rain Droplet"},"slant_upper":{"name":"Upper '
#            'Slant","value":10,"default":10,"min":-20,"max":20,"tooltip":"Upper '
#            'Slant Of Rain Droplet"},"drop_length":{"name":"Drop '
#            'Length","value":20,"default":20,"min":0,"max":100,"tooltip":"Length '
#            'Of Rain Droplet"},"drop_width":{"name":"Drop '
#            'Width","value":1,"default":1,"min":1,"max":5,"tooltip":"Width Of '
#            'Rain Droplet"},"drop_color_red":{"name":"Drop Color '
#            'Red","value":0,"default":0,"min":0,"max":255,"tooltip":"Red '
#            'Channel Rain Droplet"},"drop_color_green":{"name":"Drop Color '
#            'Green","value":0,"default":0,"min":0,"max":255,"tooltip":"Green '
#            'Channel Rain Droplet"},"drop_color_blue":{"name":"Drop Color '
#            'Blue","value":0,"default":0,"min":0,"max":255,"tooltip":"Blue '
#            'Channel Rain Droplet"},"blur_value":{"name":"Blur '
#            'Value","value":7,"default":7,"min":1,"max":15,"tooltip":"Blue '
#            'Channel Rain '
#            'Droplet"},"brightness_coefficient":{"name":"Brightness '
#            'Coefficient","value":0.7,"default":0.7,"min":0,"max":1,"tooltip":"Brightness '
#            'Coefficient Factor For Rain '
#            'Droplet"}}}},"random_shadow":{"name":"Random '
#            'Shadow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"x_min":{"name":"X '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#            'Axis Of Image Where Shadows Will Appear"},"y_min":{"name":"Y '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#            'Axis Of Image Where Shadows Will Appear"},"x_max":{"name":"X '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#            'Axis Of Image Where Shadows Will Appear"},"y_max":{"name":"Y '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#            'Axis Of Image Where Shadows Will '
#            'Appear"},"num_shadows_lower":{"name":"Number Of Shadows Lower '
#            'Limit","value":1,"default":1,"min":0,"max":20,"tooltip":"Lower '
#            'Limit For Possible Number Of '
#            'Shadows"},"num_shadows_upper":{"name":"Number Of Shadows Upper '
#            'Limit","value":5,"default":5,"min":0,"max":20,"tooltip":"Upper '
#            'Limit For Possible Number Of '
#            'Shadows"},"shadow_dimension":{"name":"Number Of '
#            'Edges","value":5,"default":5,"min":3,"max":20,"tooltip":"Number Of '
#            'Edges In Shadow Polygons"}}}},"random_snow":{"name":"Random '
#            'Snow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"snow_point_lower":{"name":"Lower '
#            'Snow '
#            'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#            'Limit Of The Amount Of Snow"},"snow_point_upper":{"name":"Upper '
#            'Snow '
#            'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#            'Limit Of The Amount Of '
#            'Snow"},"brightness_coefficient":{"name":"Brightness '
#            'Coefficient","value":2.5,"default":2.5,"min":0,"max":5,"tooltip":"Brightness '
#            'Coefficient Factor For Snow"}}}},"random_sunflare":{"name":"Random '
#            'Sun '
#            'Flare","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"x_min":{"name":"X '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#            'Axis Of Image Where Flares Will Appear"},"y_min":{"name":"Y '
#            'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#            'Axis Of Image Where Flares Will Appear"},"x_max":{"name":"X '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#            'Axis Of Image Where Flares Will Appear"},"y_max":{"name":"Y '
#            'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#            'Axis Of Image Where Flares Will '
#            'Appear"},"angle_lower":{"name":"Angle Lower '
#            'Limit","value":0,"default":0,"min":0,"max":1,"tooltip":"Lower '
#            'Limit For Flares Angle"},"angle_upper":{"name":"Angle Upper '
#            'Limit","value":1,"default":1,"min":0,"max":1,"tooltip":"Upper '
#            'Limit For Flares Angle"},"num_flare_circles_lower":{"name":"Number '
#            'Of Flares Lower '
#            'Limit","value":6,"default":6,"min":0,"max":20,"tooltip":"Lower '
#            'Limit For Possible Number Of '
#            'Flares"},"num_flare_circles_upper":{"name":"Number Of Flares Upper '
#            'Limit","value":10,"default":10,"min":0,"max":20,"tooltip":"Upper '
#            'Limit For Possible Number Of Flares"}}}},"rgb_shift":{"name":"RGB '
#            'Shift","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This Augmentation"},"lower_r_shift_limit":{"name":"R '
#            'Channel Shift Lower '
#            'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#            'Limit For Changing Values For Red '
#            'Channel"},"upper_r_shift_limit":{"name":"R Channel Shift Upper '
#            'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#            'Limit For Changing Values For Red '
#            'Channel"},"lower_g_shift_limit":{"name":"G Channel Shift Lower '
#            'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#            'Limit For Changing Values For Green '
#            'Channel"},"upper_g_shift_limit":{"name":"G Channel Shift Upper '
#            'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#            'Limit For Changing Values For Green '
#            'Channel"},"lower_b_shift_limit":{"name":"B Channel Shift Lower '
#            'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#            'Limit For Changing Values For Blue '
#            'Channel"},"upper_b_shift_limit":{"name":"B Channel Shift Upper '
#            'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#            'Limit For Changing Values For Blue '
#            'Channel"}}}},"sepia":{"name":"Sepia","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"}}}},"solarize":{"name":"Solarize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#            'of Applying This '
#            'Augmentation"},"threshold":{"name":"Threshold","value":128,"default":128,"min":0,"max":255,"tooltip":"Invert '
#            'All Pixel Values Above A '
#            'Threshold"}}}}}}}}},"position":{"x":450,"y":345},"__rf":{"position":{"x":450,"y":345},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"id":"1676354211794","type":"fasterrcnn-inceptionv2-1024x1024","basetype":"model","data":{"schema":{"title":"FasterRCNN '
#            'InceptionV2 '
#            '1024x1024","tag":"fasterrcnn-inceptionv2-1024x1024","hasSource":true,"hasDestination":false,"subtitle":{"targetparam":"training","targetarg":"batchsize","template":"%% '
#            'Images per Batch"},"parameters":{"training":{"name":"Training '
#            'Parameters","args":{"batchsize":{"name":"Batch '
#            'Size","type":"number","value":2,"default":2},"epochs":{"name":"Training '
#            'Epochs","type":"number","value":"500","default":1000}}},"pipeline":{"name":"Model '
#            'Configurations","args":{"max_detection_per_class":{"name":"Max '
#            'Detections Per '
#            'Class","type":"number","value":30,"default":30}}}}}},"position":{"x":450,"y":555},"__rf":{"position":{"x":450,"y":555},"width":260,"height":88,"handleBounds":{"source":null,"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false}},{"source":"1676354211779","target":"1676354211789","animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-1676354211779undefined-1676354211789undefined","sourceHandle":null,"targetHandle":null,"type":"default"},{"source":"1676354211789","target":"1676354211794","animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-1676354211789undefined-1676354211794undefined","sourceHandle":null,"targetHandle":null,"type":"default"}]',
#   'title': 'Example Old Workflow'}]

# %% [markdown]
# ## 9.2. Retrieve A Workflow

# %% [markdown]
# Retrieve a workflow based on the workflow's id. This will include the metadata for the specified workflow itself.

# %%
# Retrieve a workflow by the specified workflow id
workflow_retrieve_response = datature.Workflow.retrieve(
    "flow_63eb50320915a2159bf5442b"
)
# Display response for the retrieval of workflow operation
pprint.pprint(workflow_retrieve_response)
# Out:
# {'id': 'flow_63eb50320915a2159bf5442b',
#  'last_updated': 1676365892830,
#  'object': 'workflow',
#  'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#  'state': '[{"id":"1676365876014","type":"dataset","basetype":"dataset","data":{"schema":{"title":"Dataset","hasSource":false,"hasDestination":true,"subtitle":{"targetparam":"dataset_setup","targetarg":"train_test_split","template":"Train-Test '
#           'Split %% Ratio"},"parameters":{"dataset_setup":{"name":"Dataset '
#           'Setup","args":{"train_test_split":{"name":"Train-Test '
#           'Split","type":"float","value":0.3,"default":0.3},"shuffle":{"name":"Shuffle '
#           'Dataset","type":"boolean","value":true,"default":true},"random_seed":{"name":"Random '
#           'Seed","type":"number","value":0,"default":0}}}}}},"position":{"x":450,"y":150},"__rf":{"position":{"x":450,"y":150},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":null},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"id":"1676365876027","type":"augmentation","basetype":"augmentation","data":{"schema":{"title":"Augmentations","hasSource":true,"hasDestination":true,"subtitle":{"targetparam":"options","targetarg":"advanced_mode","template":"Advanced '
#           'Mode : '
#           '%%"},"parameters":{"options":{"name":"Options","args":{"advanced_mode":{"name":"Advanced '
#           'Mode","type":"boolean","value":false,"default":false}}},"position_transforms":{"name":"Random '
#           'Position Augmentations","args":{"center_crop":{"name":"Center '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height Of The Crop '
#           '(1%-100%)"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width Of The Crop '
#           '(1%-100%)"}}}},"random_horizontal_flip":{"name":"Flip '
#           'Horizontal","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"random_vertical_flip":{"name":"Flip '
#           'Vertical","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"}}}},"random_crop":{"name":"Random '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height Of The '
#           'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width Of The Crop"}}}},"random_rotate":{"name":"Random '
#           'Rotate","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_rotation":{"name":"Minimum '
#           'Rotation","value":-90,"default":-90,"min":-180,"max":180,"tooltip":"Minimum '
#           'Rotation Angle"},"max_rotation":{"name":"Maximum '
#           'Rotation","value":90,"default":90,"min":-180,"max":180,"tooltip":"Maximum '
#           'Rotation Angle"}}}},"random_resized_crop":{"name":"Random Resized '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height Of The '
#           'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width Of The Crop"},"min_scale":{"name":"Minimum '
#           'Scale","value":0.08,"default":0.08,"min":0,"max":1,"tooltip":"Minimum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"max_scale":{"name":"Maximum '
#           'Scale","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"min_aspect_ratio":{"name":"Minimum Aspect '
#           'Ratio","value":0.75,"default":0.75,"min":0.1,"max":10,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"max_aspect_ratio":{"name":"Maximum Aspect '
#           'Ratio","value":1.33,"default":1.33,"min":0.1,"max":10,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"}}}},"random_sized_crop":{"name":"Random Sized '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_height":{"name":"Minimum Crop '
#           'Size '
#           'Height","value":50,"default":50,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Minimum Crop Size Limit"},"max_height":{"name":"Maximum '
#           'Crop Size '
#           'Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Maximum Crop Size '
#           'Height"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height After The Crop And '
#           'Resize"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width After The Crop And '
#           'Resize"},"w2h_ratio":{"name":"Width to Height '
#           'Ratio","value":1,"default":1,"min":0.1,"max":1,"tooltip":"Aspect '
#           'Ratio of Crop"}}}},"shift_scale_rotate":{"name":"Shift Scale '
#           'Rotate","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_shift":{"name":"Minimum '
#           'Shift","value":-0.0625,"default":-0.0625,"min":-1,"max":1,"tooltip":"Minimum '
#           'Range Of Shift Factor For Height And '
#           'Width"},"max_shift":{"name":"Maximum '
#           'Shift","value":0.0625,"default":0.0625,"min":-1,"max":1,"tooltip":"Maximum '
#           'Range Of Shift Factor For Height And '
#           'Width"},"min_scale":{"name":"Minimum '
#           'Scale","value":-0.1,"default":-0.1,"min":-2,"max":2,"tooltip":"Minimum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"max_scale":{"name":"Maximum '
#           'Scale","value":0.1,"default":0.1,"min":-2,"max":2,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"min_rotation":{"name":"Minimum '
#           'Rotation","value":-45,"default":-45,"min":-360,"max":360,"tooltip":"Minimum '
#           'Rotation Angle"},"max_rotation":{"name":"Maximum '
#           'Rotation","value":45,"default":45,"min":-360,"max":360,"tooltip":"Maximum '
#           'Rotation Angle"}}}}}},"color_transforms":{"name":"Color Space '
#           'Augmentations","args":{"channel_dropout":{"name":"Channel '
#           'Dropout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"min_channel_dropout_range":{"name":"Min Channel '
#           'Dropout '
#           'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Minimum '
#           'Channel Dropout Limit That Should Be Used For This '
#           'Augmentation"},"max_channel_dropout_range":{"name":"Max Channel '
#           'Dropout '
#           'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Maximum '
#           'Channel Dropout Limit That Should Be Used For This '
#           'Augmentation"},"fill_value":{"name":"Fill '
#           'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#           'Value For The Dropped '
#           'Channel"}}}},"channel_shuffle":{"name":"Channel '
#           'Shuffle","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"CLAHE":{"name":"CLAHE","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_clip_limit":{"name":"Min Clip '
#           'Limit","value":1,"default":1,"min":1,"max":100,"tooltip":"Lower '
#           'Threshold Value For Contrast '
#           'Limiting"},"max_clip_limit":{"name":"Max Clip '
#           'Limit","value":4,"default":4,"min":1,"max":100,"tooltip":"Upper '
#           'Threshold Value For Contrast '
#           'Limiting"},"min_tile_grid_size":{"name":"Min Grid '
#           'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Lower '
#           'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#           'Equalization"},"max_tile_grid_size":{"name":"Max Grid '
#           'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Upper '
#           'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#           'Equalization"}}}},"color_jitter":{"name":"Color '
#           'Jitter","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_brightness":{"name":"Min '
#           'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter '
#           'Brightness"},"max_brightness":{"name":"Max '
#           'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter '
#           'Brightness"},"min_contrast":{"name":"Min '
#           'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter Contrast"},"max_contrast":{"name":"Max '
#           'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter '
#           'Contrast"},"min_saturation":{"name":"Min '
#           'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter '
#           'Saturation"},"max_saturation":{"name":"Max '
#           'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter Saturation"},"min_hue":{"name":"Min '
#           'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter Hue"},"max_hue":{"name":"Max '
#           'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter '
#           'Hue"}}}},"cutout":{"name":"Cutout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"num_holes":{"name":"Number Of '
#           'Holes","value":8,"default":8,"min":0,"max":100,"tooltip":"Number Of '
#           'Regions To Zero Out"},"max_h_size":{"name":"Max Hole '
#           'Height","value":8,"default":8,"min":0,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Maximum Height Of The Hole."},"max_w_size":{"name":"Max '
#           'Hole '
#           'Width","value":8,"default":8,"min":0,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Maximum Width Of The Hole"},"fill_value":{"name":"Fill '
#           'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#           'Value For The Dropped '
#           'Channel"}}}},"equalize":{"name":"Equalize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"fancy_pca":{"name":"FancyPCA","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"alpha":{"name":"Alpha","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"How '
#           'Much To Pertub/Scale The Eigen Vectors And '
#           'Values"}}}},"gaussian_blur":{"name":"Gaussian '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_sigma":{"name":"Min Sigma '
#           'Minimum","value":0,"default":0,"min":0,"max":3,"tooltip":"Minimum '
#           'Gaussian Kernel Standard Deviation"},"max_sigma":{"name":"Max Sigma '
#           'Minimum","value":3,"default":3,"min":0,"max":3,"tooltip":"Maximum '
#           'Gaussian Kernel Standard '
#           'Deviation"}}}},"gauss_noise":{"name":"Gaussian '
#           'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_var":{"name":"Min Variance '
#           'Range","value":10,"default":10,"min":0,"max":500,"tooltip":"Minimum '
#           'Variance Range For Noise"},"max_var":{"name":"Max Variance '
#           'Range","value":50,"default":50,"min":0,"max":500,"tooltip":"Maximum '
#           'Variance Range For '
#           'Noise"},"mean":{"name":"Mean","value":0,"default":0,"min":-100,"max":100,"tooltip":"Mean '
#           'Of The Noise"}}}},"glass_blur":{"name":"Glass '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"sigma":{"name":"Sigma","value":0.7,"default":0.7,"min":0,"max":3,"tooltip":"Standard '
#           'Deviation For Gaussian Kernel"},"max_delta":{"name":"Max '
#           'Delta","value":4,"default":4,"min":1,"max":10,"tooltip":"Max '
#           'Distance Between Pixels Which Are '
#           'Swapped"},"iterations":{"name":"Iterations","value":2,"default":2,"min":1,"max":10,"tooltip":"Number '
#           'Of '
#           'Repeats"}}}},"random_rgb_to_gray":{"name":"Grayscale","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"}}}},"hue_sat_val":{"name":"Hue '
#           'Saturation '
#           'Value","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_hue_shift":{"name":"Min Hue '
#           'Shift","value":-20,"default":-20,"min":-100,"max":100,"tooltip":"Minimum '
#           'Hue Shift Range Limit"},"max_hue_shift":{"name":"Max Hue '
#           'Shift","value":20,"default":20,"min":-100,"max":100,"tooltip":"Maximum '
#           'Hue Shift Range Limit"},"min_sat_shift":{"name":"Min Saturation '
#           'Shift","value":-30,"default":-30,"min":-100,"max":100,"tooltip":"Minimum '
#           'Saturation Shift Range Limit"},"max_sat_shift":{"name":"Max '
#           'Saturation '
#           'Shift","value":30,"default":30,"min":-100,"max":100,"tooltip":"Maximum '
#           'Saturation Shift Range Limit"},"min_val_shift":{"name":"Min Value '
#           'Shift","value":-20,"default":-20,"min":-100,"max":100,"tooltip":"Minimum '
#           'Value Shift Range Limit"},"max_val_shift":{"name":"Max Value '
#           'Shift","value":20,"default":20,"min":-100,"max":100,"tooltip":"Maximum '
#           'Value Shift Range Limit"}}}},"image_compression":{"name":"Image '
#           'Compression","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"quality_lower":{"name":"Lower '
#           'Quality '
#           'Limit","value":80,"default":80,"min":1,"max":100,"tooltip":"Lower '
#           'Bound On The Image Quality"},"quality_upper":{"name":"Upper Quality '
#           'Limit","value":100,"default":100,"min":1,"max":100,"tooltip":"Upper '
#           'Bound On The Image Quality"}}}},"iso_noise":{"name":"ISO '
#           'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_color_shift":{"name":"Min '
#           'Color '
#           'Shift","value":0.01,"default":0.01,"min":0,"max":1,"tooltip":"Minimum '
#           'Variance Range For Color Hue '
#           'Change"},"max_color_shift":{"name":"Max Color '
#           'Shift","value":0.05,"default":0.05,"min":0,"max":1,"tooltip":"Maximum '
#           'Variance Range For Color Hue Change"},"min_intensity":{"name":"Min '
#           'Intensity","value":0.1,"default":0.1,"min":0,"max":2,"tooltip":"Minimum '
#           'Strength Of Color And Luminace Noise"},"max_intensity":{"name":"Max '
#           'Intensity","value":0.5,"default":0.5,"min":0,"max":2,"tooltip":"Maximum '
#           'Strength Of Color And Luminace '
#           'Noise"}}}},"median_blur":{"name":"Median '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#           'Blur","value":7,"default":7,"min":7,"max":99,"tooltip":"Maximum '
#           'Aperture Linear Size For Blurring Input '
#           'Image"}}}},"motion_blur":{"name":"Motion '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#           'Blur","value":7,"default":7,"min":7,"max":100,"tooltip":"Maximum '
#           'Kernel Size For Blurring Input '
#           'Image"}}}},"multiplicative_noise":{"name":"Multiplicative '
#           'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_multi":{"name":"Min '
#           'Multiplication '
#           'Limit","value":0.9,"default":0.9,"min":0.1,"max":5,"tooltip":"Minimum '
#           'Random Number To Multiple With Input '
#           'Image"},"max_multi":{"name":"Max Multiplication '
#           'Limit","value":1.1,"default":1.1,"min":0.1,"max":5,"tooltip":"Maximum '
#           'Random Number To Multiple With Input '
#           'Image"}}}},"posterize":{"name":"Posterize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"r_bits":{"name":"R Channel Number '
#           'Of Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#           'Bits For Red Channel"},"g_bits":{"name":"G Channel Number Of '
#           'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#           'Bits For Green Channel"},"b_bits":{"name":"B Channel Number Of '
#           'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#           'Bits For Blue Channel"}}}},"random_blur":{"name":"Random '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_blur_limit":{"name":"Min Blur '
#           'Limit","value":3,"default":3,"min":3,"max":100,"tooltip":"Minimum '
#           'Blur Limit That Should Be Used For This '
#           'Augmentation"},"max_blur_limit":{"name":"Max Blur '
#           'Limit","value":7,"default":7,"min":3,"max":100,"tooltip":"Maximum '
#           'Blur Limit That Should Be Used For This '
#           'Augmentation"}}}},"random_brightness":{"name":"Random '
#           'Brightness","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_limit":{"name":"Min Brightness '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing Brightness"},"max_limit":{"name":"Max '
#           'Brightness '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Brightness"}}}},"random_brightness_contrast":{"name":"Random '
#           'Brightness '
#           'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_bright_limit":{"name":"Min '
#           'Brightness '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing '
#           'Brightness"},"max_bright_limit":{"name":"Max Brightness '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Brightness"},"min_contrast_limit":{"name":"Min Contrast '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing '
#           'Contrast"},"max_contrast_limit":{"name":"Max Contrast '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Contrast"}}}},"random_contrast":{"name":"Random '
#           'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_limit":{"name":"Min Contrast '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing Contrast"},"max_limit":{"name":"Max '
#           'Contrast '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Contrast"}}}},"random_fog":{"name":"Random '
#           'Fog","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"fog_coef_lower":{"name":"Lower '
#           'Coefficient '
#           'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#           'Limit For Fog Intensity '
#           'Coefficient"},"fog_coef_upper":{"name":"Upper Coefficient '
#           'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#           'Limit For Fog Intensity Coefficient"},"alpha_coef":{"name":"Alpha '
#           'Coefficient '
#           'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Transparency '
#           'Of Fog Circles"}}}},"random_gamma":{"name":"Random '
#           'Gamma","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_gamma_limit":{"name":"Min '
#           'Gamma '
#           'Limit","value":80,"default":80,"min":0,"max":200,"tooltip":"Minimum '
#           'Limit For Gamma Range"},"max_gamma_limit":{"name":"Max Gamma '
#           'Limit","value":120,"default":120,"min":0,"max":200,"tooltip":"Maximum '
#           'Limit For Gamma Range"}}}},"random_rain":{"name":"Random '
#           'Rain","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"slant_lower":{"name":"Lower '
#           'Slant","value":-10,"default":-10,"min":-20,"max":20,"tooltip":"Lower '
#           'Slant Of Rain Droplet"},"slant_upper":{"name":"Upper '
#           'Slant","value":10,"default":10,"min":-20,"max":20,"tooltip":"Upper '
#           'Slant Of Rain Droplet"},"drop_length":{"name":"Drop '
#           'Length","value":20,"default":20,"min":0,"max":100,"tooltip":"Length '
#           'Of Rain Droplet"},"drop_width":{"name":"Drop '
#           'Width","value":1,"default":1,"min":1,"max":5,"tooltip":"Width Of '
#           'Rain Droplet"},"drop_color_red":{"name":"Drop Color '
#           'Red","value":0,"default":0,"min":0,"max":255,"tooltip":"Red Channel '
#           'Rain Droplet"},"drop_color_green":{"name":"Drop Color '
#           'Green","value":0,"default":0,"min":0,"max":255,"tooltip":"Green '
#           'Channel Rain Droplet"},"drop_color_blue":{"name":"Drop Color '
#           'Blue","value":0,"default":0,"min":0,"max":255,"tooltip":"Blue '
#           'Channel Rain Droplet"},"blur_value":{"name":"Blur '
#           'Value","value":7,"default":7,"min":1,"max":15,"tooltip":"Blue '
#           'Channel Rain Droplet"},"brightness_coefficient":{"name":"Brightness '
#           'Coefficient","value":0.7,"default":0.7,"min":0,"max":1,"tooltip":"Brightness '
#           'Coefficient Factor For Rain '
#           'Droplet"}}}},"random_shadow":{"name":"Random '
#           'Shadow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"x_min":{"name":"X '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#           'Axis Of Image Where Shadows Will Appear"},"y_min":{"name":"Y '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#           'Axis Of Image Where Shadows Will Appear"},"x_max":{"name":"X '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#           'Axis Of Image Where Shadows Will Appear"},"y_max":{"name":"Y '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#           'Axis Of Image Where Shadows Will '
#           'Appear"},"num_shadows_lower":{"name":"Number Of Shadows Lower '
#           'Limit","value":1,"default":1,"min":0,"max":20,"tooltip":"Lower '
#           'Limit For Possible Number Of '
#           'Shadows"},"num_shadows_upper":{"name":"Number Of Shadows Upper '
#           'Limit","value":5,"default":5,"min":0,"max":20,"tooltip":"Upper '
#           'Limit For Possible Number Of '
#           'Shadows"},"shadow_dimension":{"name":"Number Of '
#           'Edges","value":5,"default":5,"min":3,"max":20,"tooltip":"Number Of '
#           'Edges In Shadow Polygons"}}}},"random_snow":{"name":"Random '
#           'Snow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"snow_point_lower":{"name":"Lower '
#           'Snow '
#           'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#           'Limit Of The Amount Of Snow"},"snow_point_upper":{"name":"Upper '
#           'Snow '
#           'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#           'Limit Of The Amount Of '
#           'Snow"},"brightness_coefficient":{"name":"Brightness '
#           'Coefficient","value":2.5,"default":2.5,"min":0,"max":5,"tooltip":"Brightness '
#           'Coefficient Factor For Snow"}}}},"random_sunflare":{"name":"Random '
#           'Sun '
#           'Flare","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"x_min":{"name":"X '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#           'Axis Of Image Where Flares Will Appear"},"y_min":{"name":"Y '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#           'Axis Of Image Where Flares Will Appear"},"x_max":{"name":"X '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#           'Axis Of Image Where Flares Will Appear"},"y_max":{"name":"Y '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#           'Axis Of Image Where Flares Will '
#           'Appear"},"angle_lower":{"name":"Angle Lower '
#           'Limit","value":0,"default":0,"min":0,"max":1,"tooltip":"Lower Limit '
#           'For Flares Angle"},"angle_upper":{"name":"Angle Upper '
#           'Limit","value":1,"default":1,"min":0,"max":1,"tooltip":"Upper Limit '
#           'For Flares Angle"},"num_flare_circles_lower":{"name":"Number Of '
#           'Flares Lower '
#           'Limit","value":6,"default":6,"min":0,"max":20,"tooltip":"Lower '
#           'Limit For Possible Number Of '
#           'Flares"},"num_flare_circles_upper":{"name":"Number Of Flares Upper '
#           'Limit","value":10,"default":10,"min":0,"max":20,"tooltip":"Upper '
#           'Limit For Possible Number Of Flares"}}}},"rgb_shift":{"name":"RGB '
#           'Shift","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"lower_r_shift_limit":{"name":"R '
#           'Channel Shift Lower '
#           'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#           'Limit For Changing Values For Red '
#           'Channel"},"upper_r_shift_limit":{"name":"R Channel Shift Upper '
#           'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#           'Limit For Changing Values For Red '
#           'Channel"},"lower_g_shift_limit":{"name":"G Channel Shift Lower '
#           'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#           'Limit For Changing Values For Green '
#           'Channel"},"upper_g_shift_limit":{"name":"G Channel Shift Upper '
#           'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#           'Limit For Changing Values For Green '
#           'Channel"},"lower_b_shift_limit":{"name":"B Channel Shift Lower '
#           'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#           'Limit For Changing Values For Blue '
#           'Channel"},"upper_b_shift_limit":{"name":"B Channel Shift Upper '
#           'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#           'Limit For Changing Values For Blue '
#           'Channel"}}}},"sepia":{"name":"Sepia","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"solarize":{"name":"Solarize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"threshold":{"name":"Threshold","value":128,"default":128,"min":0,"max":255,"tooltip":"Invert '
#           'All Pixel Values Above A '
#           'Threshold"}}}}}}}}},"position":{"x":450,"y":345},"__rf":{"position":{"x":450,"y":345},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"id":"1676365876032","type":"fasterrcnn-inceptionv2-1024x1024","basetype":"model","data":{"schema":{"title":"FasterRCNN '
#           'InceptionV2 '
#           '1024x1024","tag":"fasterrcnn-inceptionv2-1024x1024","hasSource":true,"hasDestination":false,"subtitle":{"targetparam":"training","targetarg":"batchsize","template":"%% '
#           'Images per Batch"},"parameters":{"training":{"name":"Training '
#           'Parameters","args":{"batchsize":{"name":"Batch '
#           'Size","type":"number","value":2,"default":2},"epochs":{"name":"Training '
#           'Epochs","type":"number","value":1000,"default":1000}}},"pipeline":{"name":"Model '
#           'Configurations","args":{"max_detection_per_class":{"name":"Max '
#           'Detections Per '
#           'Class","type":"number","value":30,"default":30}}}}}},"position":{"x":450,"y":555},"__rf":{"position":{"x":450,"y":555},"width":260,"height":88,"handleBounds":{"source":null,"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false}},{"source":"1676365876014","target":"1676365876027","animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-1676365876014undefined-1676365876027undefined","sourceHandle":null,"targetHandle":null,"type":"default"},{"source":"1676365876027","target":"1676365876032","animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-1676365876027undefined-1676365876032undefined","sourceHandle":null,"targetHandle":null,"type":"default"}]',
#  'title': 'Example Workflow To Be Deleted'}

# %% [markdown]
# ## 9.3. Update A Workflow

# %% [markdown]
# Updates the properties of a workflow based on the specified workflow id. Currently the only metadata that can be modified is the `title` of the workflow.

# %%
# Modify the properties of the workflow
workflow_modify_response = datature.Workflow.modify(
    "flow_63eb50320915a2159bf5442b",
    {"title": "My awesome workflow"}
)
# Display response for the modification of workflow operation
pprint.pprint(workflow_modify_response)
# Out:
# {'id': 'flow_63eb50320915a2159bf5442b',
#  'last_updated': 1676365892830,
#  'object': 'workflow',
#  'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#  'state': '[{"id":"1676365876014","type":"dataset","basetype":"dataset","data":{"schema":{"title":"Dataset","hasSource":false,"hasDestination":true,"subtitle":{"targetparam":"dataset_setup","targetarg":"train_test_split","template":"Train-Test '
#           'Split %% Ratio"},"parameters":{"dataset_setup":{"name":"Dataset '
#           'Setup","args":{"train_test_split":{"name":"Train-Test '
#           'Split","type":"float","value":0.3,"default":0.3},"shuffle":{"name":"Shuffle '
#           'Dataset","type":"boolean","value":true,"default":true},"random_seed":{"name":"Random '
#           'Seed","type":"number","value":0,"default":0}}}}}},"position":{"x":450,"y":150},"__rf":{"position":{"x":450,"y":150},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":null},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"id":"1676365876027","type":"augmentation","basetype":"augmentation","data":{"schema":{"title":"Augmentations","hasSource":true,"hasDestination":true,"subtitle":{"targetparam":"options","targetarg":"advanced_mode","template":"Advanced '
#           'Mode : '
#           '%%"},"parameters":{"options":{"name":"Options","args":{"advanced_mode":{"name":"Advanced '
#           'Mode","type":"boolean","value":false,"default":false}}},"position_transforms":{"name":"Random '
#           'Position Augmentations","args":{"center_crop":{"name":"Center '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height Of The Crop '
#           '(1%-100%)"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width Of The Crop '
#           '(1%-100%)"}}}},"random_horizontal_flip":{"name":"Flip '
#           'Horizontal","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"random_vertical_flip":{"name":"Flip '
#           'Vertical","type":"augmentation","value":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}},"default":{"enabled":true,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"}}}},"random_crop":{"name":"Random '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height Of The '
#           'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width Of The Crop"}}}},"random_rotate":{"name":"Random '
#           'Rotate","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_rotation":{"name":"Minimum '
#           'Rotation","value":-90,"default":-90,"min":-180,"max":180,"tooltip":"Minimum '
#           'Rotation Angle"},"max_rotation":{"name":"Maximum '
#           'Rotation","value":90,"default":90,"min":-180,"max":180,"tooltip":"Maximum '
#           'Rotation Angle"}}}},"random_resized_crop":{"name":"Random Resized '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height Of The '
#           'Crop"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width Of The Crop"},"min_scale":{"name":"Minimum '
#           'Scale","value":0.08,"default":0.08,"min":0,"max":1,"tooltip":"Minimum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"max_scale":{"name":"Maximum '
#           'Scale","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"min_aspect_ratio":{"name":"Minimum Aspect '
#           'Ratio","value":0.75,"default":0.75,"min":0.1,"max":10,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"max_aspect_ratio":{"name":"Maximum Aspect '
#           'Ratio","value":1.33,"default":1.33,"min":0.1,"max":10,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"}}}},"random_sized_crop":{"name":"Random Sized '
#           'Crop","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_height":{"name":"Minimum Crop '
#           'Size '
#           'Height","value":50,"default":50,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Minimum Crop Size Limit"},"max_height":{"name":"Maximum '
#           'Crop Size '
#           'Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Maximum Crop Size '
#           'Height"},"height":{"name":"Height","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Height After The Crop And '
#           'Resize"},"width":{"name":"Width","value":70,"default":70,"min":1,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Width After The Crop And '
#           'Resize"},"w2h_ratio":{"name":"Width to Height '
#           'Ratio","value":1,"default":1,"min":0.1,"max":1,"tooltip":"Aspect '
#           'Ratio of Crop"}}}},"shift_scale_rotate":{"name":"Shift Scale '
#           'Rotate","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_shift":{"name":"Minimum '
#           'Shift","value":-0.0625,"default":-0.0625,"min":-1,"max":1,"tooltip":"Minimum '
#           'Range Of Shift Factor For Height And '
#           'Width"},"max_shift":{"name":"Maximum '
#           'Shift","value":0.0625,"default":0.0625,"min":-1,"max":1,"tooltip":"Maximum '
#           'Range Of Shift Factor For Height And '
#           'Width"},"min_scale":{"name":"Minimum '
#           'Scale","value":-0.1,"default":-0.1,"min":-2,"max":2,"tooltip":"Minimum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"max_scale":{"name":"Maximum '
#           'Scale","value":0.1,"default":0.1,"min":-2,"max":2,"tooltip":"Maximum '
#           'Range Of Size Of The Origin Size '
#           'Cropped"},"min_rotation":{"name":"Minimum '
#           'Rotation","value":-45,"default":-45,"min":-360,"max":360,"tooltip":"Minimum '
#           'Rotation Angle"},"max_rotation":{"name":"Maximum '
#           'Rotation","value":45,"default":45,"min":-360,"max":360,"tooltip":"Maximum '
#           'Rotation Angle"}}}}}},"color_transforms":{"name":"Color Space '
#           'Augmentations","args":{"channel_dropout":{"name":"Channel '
#           'Dropout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"min_channel_dropout_range":{"name":"Min Channel '
#           'Dropout '
#           'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Minimum '
#           'Channel Dropout Limit That Should Be Used For This '
#           'Augmentation"},"max_channel_dropout_range":{"name":"Max Channel '
#           'Dropout '
#           'Limit","value":1,"default":1,"min":1,"max":2,"tooltip":"Maximum '
#           'Channel Dropout Limit That Should Be Used For This '
#           'Augmentation"},"fill_value":{"name":"Fill '
#           'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#           'Value For The Dropped '
#           'Channel"}}}},"channel_shuffle":{"name":"Channel '
#           'Shuffle","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"CLAHE":{"name":"CLAHE","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_clip_limit":{"name":"Min Clip '
#           'Limit","value":1,"default":1,"min":1,"max":100,"tooltip":"Lower '
#           'Threshold Value For Contrast '
#           'Limiting"},"max_clip_limit":{"name":"Max Clip '
#           'Limit","value":4,"default":4,"min":1,"max":100,"tooltip":"Upper '
#           'Threshold Value For Contrast '
#           'Limiting"},"min_tile_grid_size":{"name":"Min Grid '
#           'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Lower '
#           'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#           'Equalization"},"max_tile_grid_size":{"name":"Max Grid '
#           'Limit","value":8,"default":8,"min":1,"max":99,"tooltip":"Upper '
#           'Threshold Value For Percentage (1%-99%) Size Of Grid For Histogram '
#           'Equalization"}}}},"color_jitter":{"name":"Color '
#           'Jitter","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_brightness":{"name":"Min '
#           'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter '
#           'Brightness"},"max_brightness":{"name":"Max '
#           'Brightness","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter '
#           'Brightness"},"min_contrast":{"name":"Min '
#           'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter Contrast"},"max_contrast":{"name":"Max '
#           'Contrast","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter '
#           'Contrast"},"min_saturation":{"name":"Min '
#           'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter '
#           'Saturation"},"max_saturation":{"name":"Max '
#           'Saturation","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter Saturation"},"min_hue":{"name":"Min '
#           'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Minimum '
#           'Limit Of How Much To Jitter Hue"},"max_hue":{"name":"Max '
#           'Hue","value":0.2,"default":0.2,"min":-0.5,"max":0.5,"tooltip":"Maximum '
#           'Limit Of How Much To Jitter '
#           'Hue"}}}},"cutout":{"name":"Cutout","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"num_holes":{"name":"Number Of '
#           'Holes","value":8,"default":8,"min":0,"max":100,"tooltip":"Number Of '
#           'Regions To Zero Out"},"max_h_size":{"name":"Max Hole '
#           'Height","value":8,"default":8,"min":0,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Maximum Height Of The Hole."},"max_w_size":{"name":"Max '
#           'Hole '
#           'Width","value":8,"default":8,"min":0,"max":99,"tooltip":"Percentage '
#           '(1%-99%) Maximum Width Of The Hole"},"fill_value":{"name":"Fill '
#           'Value","value":0,"default":0,"min":0,"max":255,"tooltip":"Pixel '
#           'Value For The Dropped '
#           'Channel"}}}},"equalize":{"name":"Equalize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"fancy_pca":{"name":"FancyPCA","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"alpha":{"name":"Alpha","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"How '
#           'Much To Pertub/Scale The Eigen Vectors And '
#           'Values"}}}},"gaussian_blur":{"name":"Gaussian '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_sigma":{"name":"Min Sigma '
#           'Minimum","value":0,"default":0,"min":0,"max":3,"tooltip":"Minimum '
#           'Gaussian Kernel Standard Deviation"},"max_sigma":{"name":"Max Sigma '
#           'Minimum","value":3,"default":3,"min":0,"max":3,"tooltip":"Maximum '
#           'Gaussian Kernel Standard '
#           'Deviation"}}}},"gauss_noise":{"name":"Gaussian '
#           'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_var":{"name":"Min Variance '
#           'Range","value":10,"default":10,"min":0,"max":500,"tooltip":"Minimum '
#           'Variance Range For Noise"},"max_var":{"name":"Max Variance '
#           'Range","value":50,"default":50,"min":0,"max":500,"tooltip":"Maximum '
#           'Variance Range For '
#           'Noise"},"mean":{"name":"Mean","value":0,"default":0,"min":-100,"max":100,"tooltip":"Mean '
#           'Of The Noise"}}}},"glass_blur":{"name":"Glass '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"sigma":{"name":"Sigma","value":0.7,"default":0.7,"min":0,"max":3,"tooltip":"Standard '
#           'Deviation For Gaussian Kernel"},"max_delta":{"name":"Max '
#           'Delta","value":4,"default":4,"min":1,"max":10,"tooltip":"Max '
#           'Distance Between Pixels Which Are '
#           'Swapped"},"iterations":{"name":"Iterations","value":2,"default":2,"min":1,"max":10,"tooltip":"Number '
#           'Of '
#           'Repeats"}}}},"random_rgb_to_gray":{"name":"Grayscale","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"}}}},"hue_sat_val":{"name":"Hue '
#           'Saturation '
#           'Value","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_hue_shift":{"name":"Min Hue '
#           'Shift","value":-20,"default":-20,"min":-100,"max":100,"tooltip":"Minimum '
#           'Hue Shift Range Limit"},"max_hue_shift":{"name":"Max Hue '
#           'Shift","value":20,"default":20,"min":-100,"max":100,"tooltip":"Maximum '
#           'Hue Shift Range Limit"},"min_sat_shift":{"name":"Min Saturation '
#           'Shift","value":-30,"default":-30,"min":-100,"max":100,"tooltip":"Minimum '
#           'Saturation Shift Range Limit"},"max_sat_shift":{"name":"Max '
#           'Saturation '
#           'Shift","value":30,"default":30,"min":-100,"max":100,"tooltip":"Maximum '
#           'Saturation Shift Range Limit"},"min_val_shift":{"name":"Min Value '
#           'Shift","value":-20,"default":-20,"min":-100,"max":100,"tooltip":"Minimum '
#           'Value Shift Range Limit"},"max_val_shift":{"name":"Max Value '
#           'Shift","value":20,"default":20,"min":-100,"max":100,"tooltip":"Maximum '
#           'Value Shift Range Limit"}}}},"image_compression":{"name":"Image '
#           'Compression","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"quality_lower":{"name":"Lower '
#           'Quality '
#           'Limit","value":80,"default":80,"min":1,"max":100,"tooltip":"Lower '
#           'Bound On The Image Quality"},"quality_upper":{"name":"Upper Quality '
#           'Limit","value":100,"default":100,"min":1,"max":100,"tooltip":"Upper '
#           'Bound On The Image Quality"}}}},"iso_noise":{"name":"ISO '
#           'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_color_shift":{"name":"Min '
#           'Color '
#           'Shift","value":0.01,"default":0.01,"min":0,"max":1,"tooltip":"Minimum '
#           'Variance Range For Color Hue '
#           'Change"},"max_color_shift":{"name":"Max Color '
#           'Shift","value":0.05,"default":0.05,"min":0,"max":1,"tooltip":"Maximum '
#           'Variance Range For Color Hue Change"},"min_intensity":{"name":"Min '
#           'Intensity","value":0.1,"default":0.1,"min":0,"max":2,"tooltip":"Minimum '
#           'Strength Of Color And Luminace Noise"},"max_intensity":{"name":"Max '
#           'Intensity","value":0.5,"default":0.5,"min":0,"max":2,"tooltip":"Maximum '
#           'Strength Of Color And Luminace '
#           'Noise"}}}},"median_blur":{"name":"Median '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#           'Blur","value":7,"default":7,"min":7,"max":99,"tooltip":"Maximum '
#           'Aperture Linear Size For Blurring Input '
#           'Image"}}}},"motion_blur":{"name":"Motion '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"max_blur_limit":{"name":"Max '
#           'Blur","value":7,"default":7,"min":7,"max":100,"tooltip":"Maximum '
#           'Kernel Size For Blurring Input '
#           'Image"}}}},"multiplicative_noise":{"name":"Multiplicative '
#           'Noise","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_multi":{"name":"Min '
#           'Multiplication '
#           'Limit","value":0.9,"default":0.9,"min":0.1,"max":5,"tooltip":"Minimum '
#           'Random Number To Multiple With Input '
#           'Image"},"max_multi":{"name":"Max Multiplication '
#           'Limit","value":1.1,"default":1.1,"min":0.1,"max":5,"tooltip":"Maximum '
#           'Random Number To Multiple With Input '
#           'Image"}}}},"posterize":{"name":"Posterize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"r_bits":{"name":"R Channel Number '
#           'Of Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#           'Bits For Red Channel"},"g_bits":{"name":"G Channel Number Of '
#           'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#           'Bits For Green Channel"},"b_bits":{"name":"B Channel Number Of '
#           'Bits","value":4,"default":4,"min":0,"max":8,"tooltip":"Number Of '
#           'Bits For Blue Channel"}}}},"random_blur":{"name":"Random '
#           'Blur","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_blur_limit":{"name":"Min Blur '
#           'Limit","value":3,"default":3,"min":3,"max":100,"tooltip":"Minimum '
#           'Blur Limit That Should Be Used For This '
#           'Augmentation"},"max_blur_limit":{"name":"Max Blur '
#           'Limit","value":7,"default":7,"min":3,"max":100,"tooltip":"Maximum '
#           'Blur Limit That Should Be Used For This '
#           'Augmentation"}}}},"random_brightness":{"name":"Random '
#           'Brightness","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_limit":{"name":"Min Brightness '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing Brightness"},"max_limit":{"name":"Max '
#           'Brightness '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Brightness"}}}},"random_brightness_contrast":{"name":"Random '
#           'Brightness '
#           'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_bright_limit":{"name":"Min '
#           'Brightness '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing '
#           'Brightness"},"max_bright_limit":{"name":"Max Brightness '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Brightness"},"min_contrast_limit":{"name":"Min Contrast '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing '
#           'Contrast"},"max_contrast_limit":{"name":"Max Contrast '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Contrast"}}}},"random_contrast":{"name":"Random '
#           'Contrast","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_limit":{"name":"Min Contrast '
#           'Limit","value":-0.2,"default":-0.2,"min":-1,"max":1,"tooltip":"Minimum '
#           'Factor Range For Changing Contrast"},"max_limit":{"name":"Max '
#           'Contrast '
#           'Limit","value":0.2,"default":0.2,"min":-1,"max":1,"tooltip":"Maximum '
#           'Factor Range For Changing '
#           'Contrast"}}}},"random_fog":{"name":"Random '
#           'Fog","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"fog_coef_lower":{"name":"Lower '
#           'Coefficient '
#           'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#           'Limit For Fog Intensity '
#           'Coefficient"},"fog_coef_upper":{"name":"Upper Coefficient '
#           'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#           'Limit For Fog Intensity Coefficient"},"alpha_coef":{"name":"Alpha '
#           'Coefficient '
#           'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Transparency '
#           'Of Fog Circles"}}}},"random_gamma":{"name":"Random '
#           'Gamma","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"min_gamma_limit":{"name":"Min '
#           'Gamma '
#           'Limit","value":80,"default":80,"min":0,"max":200,"tooltip":"Minimum '
#           'Limit For Gamma Range"},"max_gamma_limit":{"name":"Max Gamma '
#           'Limit","value":120,"default":120,"min":0,"max":200,"tooltip":"Maximum '
#           'Limit For Gamma Range"}}}},"random_rain":{"name":"Random '
#           'Rain","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"slant_lower":{"name":"Lower '
#           'Slant","value":-10,"default":-10,"min":-20,"max":20,"tooltip":"Lower '
#           'Slant Of Rain Droplet"},"slant_upper":{"name":"Upper '
#           'Slant","value":10,"default":10,"min":-20,"max":20,"tooltip":"Upper '
#           'Slant Of Rain Droplet"},"drop_length":{"name":"Drop '
#           'Length","value":20,"default":20,"min":0,"max":100,"tooltip":"Length '
#           'Of Rain Droplet"},"drop_width":{"name":"Drop '
#           'Width","value":1,"default":1,"min":1,"max":5,"tooltip":"Width Of '
#           'Rain Droplet"},"drop_color_red":{"name":"Drop Color '
#           'Red","value":0,"default":0,"min":0,"max":255,"tooltip":"Red Channel '
#           'Rain Droplet"},"drop_color_green":{"name":"Drop Color '
#           'Green","value":0,"default":0,"min":0,"max":255,"tooltip":"Green '
#           'Channel Rain Droplet"},"drop_color_blue":{"name":"Drop Color '
#           'Blue","value":0,"default":0,"min":0,"max":255,"tooltip":"Blue '
#           'Channel Rain Droplet"},"blur_value":{"name":"Blur '
#           'Value","value":7,"default":7,"min":1,"max":15,"tooltip":"Blue '
#           'Channel Rain Droplet"},"brightness_coefficient":{"name":"Brightness '
#           'Coefficient","value":0.7,"default":0.7,"min":0,"max":1,"tooltip":"Brightness '
#           'Coefficient Factor For Rain '
#           'Droplet"}}}},"random_shadow":{"name":"Random '
#           'Shadow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"x_min":{"name":"X '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#           'Axis Of Image Where Shadows Will Appear"},"y_min":{"name":"Y '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#           'Axis Of Image Where Shadows Will Appear"},"x_max":{"name":"X '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#           'Axis Of Image Where Shadows Will Appear"},"y_max":{"name":"Y '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#           'Axis Of Image Where Shadows Will '
#           'Appear"},"num_shadows_lower":{"name":"Number Of Shadows Lower '
#           'Limit","value":1,"default":1,"min":0,"max":20,"tooltip":"Lower '
#           'Limit For Possible Number Of '
#           'Shadows"},"num_shadows_upper":{"name":"Number Of Shadows Upper '
#           'Limit","value":5,"default":5,"min":0,"max":20,"tooltip":"Upper '
#           'Limit For Possible Number Of '
#           'Shadows"},"shadow_dimension":{"name":"Number Of '
#           'Edges","value":5,"default":5,"min":3,"max":20,"tooltip":"Number Of '
#           'Edges In Shadow Polygons"}}}},"random_snow":{"name":"Random '
#           'Snow","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"snow_point_lower":{"name":"Lower '
#           'Snow '
#           'Limit","value":0.1,"default":0.1,"min":0,"max":1,"tooltip":"Lower '
#           'Limit Of The Amount Of Snow"},"snow_point_upper":{"name":"Upper '
#           'Snow '
#           'Limit","value":0.2,"default":0.2,"min":0,"max":1,"tooltip":"Upper '
#           'Limit Of The Amount Of '
#           'Snow"},"brightness_coefficient":{"name":"Brightness '
#           'Coefficient","value":2.5,"default":2.5,"min":0,"max":5,"tooltip":"Brightness '
#           'Coefficient Factor For Snow"}}}},"random_sunflare":{"name":"Random '
#           'Sun '
#           'Flare","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"x_min":{"name":"X '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum X '
#           'Axis Of Image Where Flares Will Appear"},"y_min":{"name":"Y '
#           'Min","value":0,"default":0,"min":0,"max":1,"tooltip":"Minimum Y '
#           'Axis Of Image Where Flares Will Appear"},"x_max":{"name":"X '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum X '
#           'Axis Of Image Where Flares Will Appear"},"y_max":{"name":"Y '
#           'Max","value":1,"default":1,"min":0,"max":1,"tooltip":"Maximum Y '
#           'Axis Of Image Where Flares Will '
#           'Appear"},"angle_lower":{"name":"Angle Lower '
#           'Limit","value":0,"default":0,"min":0,"max":1,"tooltip":"Lower Limit '
#           'For Flares Angle"},"angle_upper":{"name":"Angle Upper '
#           'Limit","value":1,"default":1,"min":0,"max":1,"tooltip":"Upper Limit '
#           'For Flares Angle"},"num_flare_circles_lower":{"name":"Number Of '
#           'Flares Lower '
#           'Limit","value":6,"default":6,"min":0,"max":20,"tooltip":"Lower '
#           'Limit For Possible Number Of '
#           'Flares"},"num_flare_circles_upper":{"name":"Number Of Flares Upper '
#           'Limit","value":10,"default":10,"min":0,"max":20,"tooltip":"Upper '
#           'Limit For Possible Number Of Flares"}}}},"rgb_shift":{"name":"RGB '
#           'Shift","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This Augmentation"},"lower_r_shift_limit":{"name":"R '
#           'Channel Shift Lower '
#           'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#           'Limit For Changing Values For Red '
#           'Channel"},"upper_r_shift_limit":{"name":"R Channel Shift Upper '
#           'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#           'Limit For Changing Values For Red '
#           'Channel"},"lower_g_shift_limit":{"name":"G Channel Shift Lower '
#           'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#           'Limit For Changing Values For Green '
#           'Channel"},"upper_g_shift_limit":{"name":"G Channel Shift Upper '
#           'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#           'Limit For Changing Values For Green '
#           'Channel"},"lower_b_shift_limit":{"name":"B Channel Shift Lower '
#           'Limit","value":-20,"default":-20,"min":-255,"max":255,"tooltip":"Lower '
#           'Limit For Changing Values For Blue '
#           'Channel"},"upper_b_shift_limit":{"name":"B Channel Shift Upper '
#           'Limit","value":20,"default":20,"min":-255,"max":255,"tooltip":"Upper '
#           'Limit For Changing Values For Blue '
#           'Channel"}}}},"sepia":{"name":"Sepia","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"}}}},"solarize":{"name":"Solarize","type":"augmentation","value":{},"default":{"enabled":false,"args":{"probability":{"name":"Probability","value":0.5,"default":0.5,"min":0,"max":1,"tooltip":"Probability '
#           'of Applying This '
#           'Augmentation"},"threshold":{"name":"Threshold","value":128,"default":128,"min":0,"max":255,"tooltip":"Invert '
#           'All Pixel Values Above A '
#           'Threshold"}}}}}}}}},"position":{"x":450,"y":345},"__rf":{"position":{"x":450,"y":345},"width":260,"height":88,"handleBounds":{"source":[{"id":null,"position":"bottom","x":125,"y":83,"width":10,"height":10}],"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false},"style":{"boxShadow":"none","WebkitBoxShadow":"none","MozBoxShadow":"none"}},{"id":"1676365876032","type":"fasterrcnn-inceptionv2-1024x1024","basetype":"model","data":{"schema":{"title":"FasterRCNN '
#           'InceptionV2 '
#           '1024x1024","tag":"fasterrcnn-inceptionv2-1024x1024","hasSource":true,"hasDestination":false,"subtitle":{"targetparam":"training","targetarg":"batchsize","template":"%% '
#           'Images per Batch"},"parameters":{"training":{"name":"Training '
#           'Parameters","args":{"batchsize":{"name":"Batch '
#           'Size","type":"number","value":2,"default":2},"epochs":{"name":"Training '
#           'Epochs","type":"number","value":1000,"default":1000}}},"pipeline":{"name":"Model '
#           'Configurations","args":{"max_detection_per_class":{"name":"Max '
#           'Detections Per '
#           'Class","type":"number","value":30,"default":30}}}}}},"position":{"x":450,"y":555},"__rf":{"position":{"x":450,"y":555},"width":260,"height":88,"handleBounds":{"source":null,"target":[{"id":null,"position":"top","x":125,"y":-5,"width":10,"height":10}]},"isDragging":false}},{"source":"1676365876014","target":"1676365876027","animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-1676365876014undefined-1676365876027undefined","sourceHandle":null,"targetHandle":null,"type":"default"},{"source":"1676365876027","target":"1676365876032","animated":true,"arrowHeadType":"arrow","id":"reactflow__edge-1676365876027undefined-1676365876032undefined","sourceHandle":null,"targetHandle":null,"type":"default"}]',
#  'title': 'My awesome workflow'}

# %% [markdown]
# ## 9.4. Delete A Workflow

# %% [markdown]
# Delete a workflow based on the specified workflow id.

# %%
# Delete workflow based on specified workflow id
workflow_delete_response = datature.Workflow.delete(
    "flow_63eb50320915a2159bf5442b"
)
# Display response for the deletion of the workflow operation
pprint.pprint(workflow_delete_response)
# Out:
# {'deleted': True, 'id': 'flow_63eb50320915a2159bf5442b'}

# %% [markdown]
# # 10. Training API

# %% [markdown]
# This section describes all the operations with regards to the training run. The training run executes the training based on the selected workflow specified.

# %% [markdown]
# ## 10.1. Create A Training Run

# %% [markdown]
# Create a training run based on the specified configuration. For more information about how to configure the training run, please refer to the developer's documentation itself.

# %%
# Start a training run based on the specified workflow id and configurations
run_start_response = datature.Run.start(
    "flow_63eb229abec73541a7b37280",
    {
        "accelerator": {
            "name": "GPU_T4",
            "count": 1
        },
        "checkpoint": {
            "strategy": "STRAT_LOWEST_VALIDATION_LOSS",
                        "evaluation_interval": 250,
                        "metric": "Loss/total_loss"
        },
        "limit": {
            "metric": "LIM_MINUTE",
            "value": 260
        },
        "debug": True,
        "preview": True
    }
)
# Display response of the creation of training run operation
pprint.pprint(run_start_response)
# Out:
# {'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                'checkpoint': {'evaluation_interval': 250,
#                               'metric': 'Loss/total_loss',
#                               'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'}},
#  'features': {'preview': True},
#  'flow_id': 'flow_63eb229abec73541a7b37280',
#  'id': 'run_63eb5410e3cc5b966339344f',
#  'logs': ['log_63eb5410e3cc5b966339344f'],
#  'object': 'run',
#  'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#  'status': {'conditions': [{'condition': 'TrainingStarted',
#                             'status': 'running'}]}}

# %% [markdown]
# ## 10.2. List All Training Runs

# %% [markdown]
# List all trainings runs in the project. This will include the metadata related to the training run. Do note that the information of the workflow that is used in the training run will not be dispayed and will require the use of the `workflow` API itself to retrieve the information related to it.

# %%
# List all training runs in the project
run_list_response = datature.Run.list()
# Display response for listing all the training runs operation
pprint.pprint(run_list_response)
# Out:
# [{'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'Loss/total_loss',
#                                'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'}},
#   'features': {'preview': True},
#   'flow_id': 'flow_63eb229abec73541a7b37280',
#   'id': 'run_63eb5410e3cc5b966339344f',
#   'logs': ['log_63eb5410e3cc5b966339344f'],
#   'object': 'run',
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'status': {'conditions': [{'condition': 'TrainingStarted',
#                              'status': 'running'}]}},
#  {'create_date': 1676361363944,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'STRAT_ALWAYS_SAVE_LATEST',
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'}},
#   'features': {'preview': True},
#   'flow_id': 'flow_63eb229abec73541a7b37280',
#   'id': 'run_63eb3dfdf45218f93dbb34a4',
#   'last_modified_date': 1676361994586,
#   'logs': ['log_63eb3dfdf45218f93dbb34a4'],
#   'object': 'run',
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'status': {'conditions': [{'condition': 'TrainingStarted',
#                              'last_updated': 1676361363944,
#                              'status': 'finished'},
#                             {'condition': 'TrainingFinished',
#                              'last_updated': 1676361994586,
#                              'reason': 'Killed',
#                              'status': 'errored'}],
#              'last_updated': 1676361994586}},
#  {'create_date': 1676360993059,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 250,
#                                'metric': 'Loss/total_loss',
#                                'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'}},
#   'features': {'preview': True},
#   'flow_id': 'flow_63eb229abec73541a7b37280',
#   'id': 'run_63eb3c7a16691c3269fac8ec',
#   'last_modified_date': 1676361186145,
#   'logs': ['log_63eb3c7a16691c3269fac8ec'],
#   'object': 'run',
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'status': {'conditions': [{'condition': 'TrainingStarted',
#                              'last_updated': 1676360993059,
#                              'status': 'finished'},
#                             {'condition': 'TrainingFinished',
#                              'last_updated': 1676361186145,
#                              'reason': 'Killed',
#                              'status': 'errored'}],
#              'last_updated': 1676361186145}},
#  {'create_date': 1676354398180,
#   'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                 'checkpoint': {'evaluation_interval': 100,
#                                'metric': 'STRAT_ALWAYS_SAVE_LATEST',
#                                'strategy': 'STRAT_ALWAYS_SAVE_LATEST'}},
#   'features': {'preview': True},
#   'flow_id': 'flow_63eb229abec73541a7b37280',
#   'id': 'run_63eb22b7bec73541a7b3728f',
#   'last_modified_date': 1676355807836,
#   'logs': ['log_63eb22b7bec73541a7b3728f'],
#   'object': 'run',
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'status': {'conditions': [{'condition': 'TrainingStarted',
#                              'last_updated': 1676354398180,
#                              'status': 'finished'},
#                             {'condition': 'TrainingFinished',
#                              'last_updated': 1676355807836,
#                              'status': 'finished'}],
#              'last_updated': 1676355807836}}]

# %% [markdown]
# ## 10.3. Retrieve A Training Log

# %% [markdown]
# Retrieves a training log based on the specified training log id. The log id related to the training run can be retrieved from retrieving the information about the training run itself. Retrieval of training run information can be found [here](#10.4.-Retrieve-A-Training-Run). The log details information like the loss and metrics of training run itself.

# %%
# Retrieve the log information based on the specified log id
run_log_response = datature.Run.log(
    "log_63eb22b7bec73541a7b3728f"
)
# Display response for the retrieval of log operation
pprint.pprint(run_log_response)
# Out:
# {'events': [{'ev': 'trainingStarted', 't': 1676354490},
#             {'ev': 'evaluationCheckpoint',
#              'pl': {'average_precision': 8.8e-05,
#                     'average_precision.50_iou': 0.000439,
#                     'average_precision.75_iou': 0,
#                     'average_recall1': 0.00098,
#                     'average_recall10': 0.003137,
#                     'average_recall100': 0.005294,
#                     'classification_loss': 0.784523,
#                     'large_average_precision': 0.000188,
#                     'large_average_recall100': 0.016993,
#                     'localization_loss': 0.00926,
#                     'log': 'Loading and preparing annotation results...\n'
#                            'INFO:tensorflow:Eval metrics at step 0\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Precision/mAP: '
#                            '0.000088\n'
#                            'INFO:tensorflow:\t+ '
#                            'DetectionBoxes_Precision/mAP@.50IOU: 0.000439\n'
#                            'INFO:tensorflow:\t+ '
#                            'DetectionBoxes_Precision/mAP@.75IOU: 0.000000\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Precision/mAP '
#                            '(small): 0.000000\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Precision/mAP '
#                            '(medium): 0.000017\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Precision/mAP '
#                            '(large): 0.000188\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Recall/AR@1: '
#                            '0.000980\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Recall/AR@10: '
#                            '0.003137\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Recall/AR@100: '
#                            '0.005294\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Recall/AR@100 '
#                            '(small): 0.000000\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Recall/AR@100 '
#                            '(medium): 0.001299\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Recall/AR@100 '
#                            '(large): 0.016993\n'
#                            'INFO:tensorflow:\t+ Loss/rpnLocalization_loss: '
#                            '0.252264\n'
#                            'INFO:tensorflow:\t+ Loss/rpnObjectness_loss: '
#                            '0.698408\n'
#                            'INFO:tensorflow:\t+ Loss/localization_loss: '
#                            '0.009260\n'
#                            'INFO:tensorflow:\t+ Loss/classification_loss: '
#                            '0.784523\n'
#                            'INFO:tensorflow:\t+ Loss/regularization_loss: '
#                            '0.000000\n'
#                            'INFO:tensorflow:\t+ Loss/total_loss: 1.744455\n'
#                            'INFO:tensorflow:Waiting for new checkpoint at '
#                            '***\n',
#                     'medium_average_precision': 1.7e-05,
#                     'medium_average_recall100': 0.001299,
#                     'regularization_loss': 0,
#                     'rpn_localization_loss': 0.252264,
#                     'rpn_objectness_loss': 0.698408,
#                     'small_average_precision': 0,
#                     'small_average_recall100': 0,
#                     'step': 0,
#                     'total_loss': 1.744455},
#              't': 1676354888},
#             {'ev': 'artifactAuthorized',
#              'pl': {'artifact_id': '63eb2548b03587e371e77bea',
#                     'name': 'ckpt-1'},
#              't': 1676354888},
#             {'ev': 'artifactUploaded',
#              'pl': {'artifact_id': '63eb2548b03587e371e77bea',
#                     'files': [{'md5': '832cc3488eee29f21794a17a503eed09',
#                                'name': 'ckpt-1.index'},
#                               {'md5': 'acce8cdac80ea96af1b1a81247333578',
#                                'name': 'ckpt-1.data-00000-of-00001'}]},
#              't': 1676354894},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.723,
#                     'localization_loss': 0.091,
#                     'log': 'INFO:tensorflow:Step 1 per-step time 187.710s '
#                            'total_loss=1.555, classification_loss=0.723, '
#                            'localization_loss=0.091, rpnObjectness_loss=0.699, '
#                            'rpnLocalization_loss=0.043, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.043,
#                     'rpn_objectness_loss': 0.699,
#                     'step': 1,
#                     'total_loss': 1.555},
#              't': 1676354939},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.634,
#                     'localization_loss': 0,
#                     'log': 'INFO:tensorflow:Step 2 per-step time 1.604s '
#                            'total_loss=1.384, classification_loss=0.634, '
#                            'localization_loss=0.000, rpnObjectness_loss=0.700, '
#                            'rpnLocalization_loss=0.051, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.051,
#                     'rpn_objectness_loss': 0.7,
#                     'step': 2,
#                     'total_loss': 1.384},
#              't': 1676354940},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.569,
#                     'localization_loss': 0,
#                     'log': 'INFO:tensorflow:Step 3 per-step time 1.613s '
#                            'total_loss=1.347, classification_loss=0.569, '
#                            'localization_loss=0.000, rpnObjectness_loss=0.699, '
#                            'rpnLocalization_loss=0.079, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.079,
#                     'rpn_objectness_loss': 0.699,
#                     'step': 3,
#                     'total_loss': 1.347},
#              't': 1676354942},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.484,
#                     'localization_loss': 0.081,
#                     'log': 'INFO:tensorflow:Step 4 per-step time 1.623s '
#                            'total_loss=1.418, classification_loss=0.484, '
#                            'localization_loss=0.081, rpnObjectness_loss=0.698, '
#                            'rpnLocalization_loss=0.155, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.155,
#                     'rpn_objectness_loss': 0.698,
#                     'step': 4,
#                     'total_loss': 1.418},
#              't': 1676354944},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.24,
#                     'localization_loss': 0,
#                     'log': 'INFO:tensorflow:Step 5 per-step time 1.622s '
#                            'total_loss=1.021, classification_loss=0.240, '
#                            'localization_loss=0.000, rpnObjectness_loss=0.699, '
#                            'rpnLocalization_loss=0.082, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.082,
#                     'rpn_objectness_loss': 0.699,
#                     'step': 5,
#                     'total_loss': 1.021},
#              't': 1676354945},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.11,
#                     'localization_loss': 0.028,
#                     'log': 'INFO:tensorflow:Step 6 per-step time 1.628s '
#                            'total_loss=0.852, classification_loss=0.110, '
#                            'localization_loss=0.028, rpnObjectness_loss=0.694, '
#                            'rpnLocalization_loss=0.019, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.019,
#                     'rpn_objectness_loss': 0.694,
#                     'step': 6,
#                     'total_loss': 0.852},
#              't': 1676354947},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.048,
#                     'localization_loss': 0,
#                     'log': 'INFO:tensorflow:Step 7 per-step time 1.627s '
#                            'total_loss=0.793, classification_loss=0.048, '
#                            'localization_loss=0.000, rpnObjectness_loss=0.693, '
#                            'rpnLocalization_loss=0.052, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.052,
#                     'rpn_objectness_loss': 0.693,
#                     'step': 7,
#                     'total_loss': 0.793},
#              't': 1676354948},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.122,
#                     'localization_loss': 0.27,
#                     'log': 'INFO:tensorflow:Step 8 per-step time 1.634s '
#                            'total_loss=1.899, classification_loss=0.122, '
#                            'localization_loss=0.270, rpnObjectness_loss=0.689, '
#                            'rpnLocalization_loss=0.817, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.817,
#                     'rpn_objectness_loss': 0.689,
#                     'step': 8,
#                     'total_loss': 1.899},
#              't': 1676354950},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.024,
#                     'localization_loss': 0.079,
#                     'log': 'INFO:tensorflow:Step 9 per-step time 1.641s '
#                            'total_loss=1.942, classification_loss=0.024, '
#                            'localization_loss=0.079, rpnObjectness_loss=0.685, '
#                            'rpnLocalization_loss=1.155, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 1.155,
#                     'rpn_objectness_loss': 0.685,
#                     'step': 9,
#                     'total_loss': 1.942},
#              't': 1676354952},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.001,
#                     'localization_loss': 0,
#                     'log': 'INFO:tensorflow:Step 10 per-step time 1.648s '
#                            'total_loss=1.163, classification_loss=0.001, '
#                            'localization_loss=0.000, rpnObjectness_loss=0.679, '
#                            'rpnLocalization_loss=0.484, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.484,
#                     'rpn_objectness_loss': 0.679,
#                     'step': 10,
#                     'total_loss': 1.163},
#              't': 1676354953},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.004,
#                     'localization_loss': 0,
#                     'log': 'INFO:tensorflow:Step 11 per-step time 1.647s '
#                            'total_loss=0.708, classification_loss=0.004, '
#                            'localization_loss=0.000, rpnObjectness_loss=0.671, '
#                            'rpnLocalization_loss=0.033, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.033,
#                     'rpn_objectness_loss': 0.671,
#                     'step': 11,
#                     'total_loss': 0.708},
#              't': 1676354955},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.194,
#                     'localization_loss': 0.273,
#                     'log': 'INFO:tensorflow:Step 12 per-step time 1.641s '
#                            'total_loss=1.147, classification_loss=0.194, '
#                            'localization_loss=0.273, rpnObjectness_loss=0.659, '
#                            'rpnLocalization_loss=0.021, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.021,
#                     'rpn_objectness_loss': 0.659,
#                     'step': 12,
#                     'total_loss': 1.147},
#              't': 1676354957},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.142,
#                     'localization_loss': 0.115,
#                     'log': 'INFO:tensorflow:Step 13 per-step time 1.640s '
#                            'total_loss=0.942, classification_loss=0.142, '
#                            'localization_loss=0.115, rpnObjectness_loss=0.653, '
#                            'rpnLocalization_loss=0.032, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.032,
#                     'rpn_objectness_loss': 0.653,
#                     'step': 13,
#                     'total_loss': 0.942},
#              't': 1676354958},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.16,
#                     'localization_loss': 0.139,
#                     'log': 'INFO:tensorflow:Step 14 per-step time 1.641s '
#                            'total_loss=0.986, classification_loss=0.160, '
#                            'localization_loss=0.139, rpnObjectness_loss=0.637, '
#                            'rpnLocalization_loss=0.049, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.049,
#                     'rpn_objectness_loss': 0.637,
#                     'step': 14,
#                     'total_loss': 0.986},
#              't': 1676354960},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.089,
#                     'localization_loss': 0.076,
#                     'log': 'INFO:tensorflow:Step 15 per-step time 1.642s '
#                            'total_loss=0.839, classification_loss=0.089, '
#                            'localization_loss=0.076, rpnObjectness_loss=0.625, '
#                            'rpnLocalization_loss=0.048, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.048,
#                     'rpn_objectness_loss': 0.625,
#                     'step': 15,
#                     'total_loss': 0.839},
#              't': 1676354962},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.155,
#                     'localization_loss': 0.376,
#                     'log': 'INFO:tensorflow:Step 16 per-step time 1.636s '
#                            'total_loss=1.240, classification_loss=0.155, '
#                            'localization_loss=0.376, rpnObjectness_loss=0.607, '
#                            'rpnLocalization_loss=0.102, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.102,
#                     'rpn_objectness_loss': 0.607,
#                     'step': 16,
#                     'total_loss': 1.24},
#              't': 1676354963},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.12,
#                     'localization_loss': 0.351,
#                     'log': 'INFO:tensorflow:Step 17 per-step time 1.625s '
#                            'total_loss=1.081, classification_loss=0.120, '
#                            'localization_loss=0.351, rpnObjectness_loss=0.589, '
#                            'rpnLocalization_loss=0.021, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.021,
#                     'rpn_objectness_loss': 0.589,
#                     'step': 17,
#                     'total_loss': 1.081},
#              't': 1676354965},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.092,
#                     'localization_loss': 0.41,
#                     'log': 'INFO:tensorflow:Step 18 per-step time 1.623s '
#                            'total_loss=1.196, classification_loss=0.092, '
#                            'localization_loss=0.410, rpnObjectness_loss=0.574, '
#                            'rpnLocalization_loss=0.119, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.119,
#                     'rpn_objectness_loss': 0.574,
#                     'step': 18,
#                     'total_loss': 1.196},
#              't': 1676354967},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.044,
#                     'localization_loss': 0.117,
#                     'log': 'INFO:tensorflow:Step 19 per-step time 1.628s '
#                            'total_loss=0.948, classification_loss=0.044, '
#                            'localization_loss=0.117, rpnObjectness_loss=0.546, '
#                            'rpnLocalization_loss=0.241, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.241,
#                     'rpn_objectness_loss': 0.546,
#                     'step': 19,
#                     'total_loss': 0.948},
#              't': 1676354968},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.229,
#                     'localization_loss': 1.773,
#                     'log': 'INFO:tensorflow:Step 20 per-step time 1.614s '
#                            'total_loss=2.538, classification_loss=0.229, '
#                            'localization_loss=1.773, rpnObjectness_loss=0.513, '
#                            'rpnLocalization_loss=0.023, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.023,
#                     'rpn_objectness_loss': 0.513,
#                     'step': 20,
#                     'total_loss': 2.538},
#              't': 1676354970},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.186,
#                     'localization_loss': 0.706,
#                     'log': 'INFO:tensorflow:Step 21 per-step time 1.614s '
#                            'total_loss=1.403, classification_loss=0.186, '
#                            'localization_loss=0.706, rpnObjectness_loss=0.450, '
#                            'rpnLocalization_loss=0.060, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.06,
#                     'rpn_objectness_loss': 0.45,
#                     'step': 21,
#                     'total_loss': 1.403},
#              't': 1676354971},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.18,
#                     'localization_loss': 0.544,
#                     'log': 'INFO:tensorflow:Step 22 per-step time 1.615s '
#                            'total_loss=1.263, classification_loss=0.180, '
#                            'localization_loss=0.544, rpnObjectness_loss=0.404, '
#                            'rpnLocalization_loss=0.135, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.135,
#                     'rpn_objectness_loss': 0.404,
#                     'step': 22,
#                     'total_loss': 1.263},
#              't': 1676354973},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.059,
#                     'localization_loss': 0.095,
#                     'log': 'INFO:tensorflow:Step 23 per-step time 1.612s '
#                            'total_loss=0.630, classification_loss=0.059, '
#                            'localization_loss=0.095, rpnObjectness_loss=0.328, '
#                            'rpnLocalization_loss=0.149, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.149,
#                     'rpn_objectness_loss': 0.328,
#                     'step': 23,
#                     'total_loss': 0.63},
#              't': 1676354975},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.087,
#                     'localization_loss': 0.242,
#                     'log': 'INFO:tensorflow:Step 24 per-step time 1.609s '
#                            'total_loss=0.549, classification_loss=0.087, '
#                            'localization_loss=0.242, rpnObjectness_loss=0.206, '
#                            'rpnLocalization_loss=0.014, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.014,
#                     'rpn_objectness_loss': 0.206,
#                     'step': 24,
#                     'total_loss': 0.549},
#              't': 1676354976},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.161,
#                     'localization_loss': 0.593,
#                     'log': 'INFO:tensorflow:Step 25 per-step time 1.596s '
#                            'total_loss=0.998, classification_loss=0.161, '
#                            'localization_loss=0.593, rpnObjectness_loss=0.156, '
#                            'rpnLocalization_loss=0.089, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.089,
#                     'rpn_objectness_loss': 0.156,
#                     'step': 25,
#                     'total_loss': 0.998},
#              't': 1676354978},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.505,
#                     'localization_loss': 0.23,
#                     'log': 'INFO:tensorflow:Step 26 per-step time 1.602s '
#                            'total_loss=0.797, classification_loss=0.505, '
#                            'localization_loss=0.230, rpnObjectness_loss=0.045, '
#                            'rpnLocalization_loss=0.017, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.017,
#                     'rpn_objectness_loss': 0.045,
#                     'step': 26,
#                     'total_loss': 0.797},
#              't': 1676354979},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.111,
#                     'localization_loss': 0.438,
#                     'log': 'INFO:tensorflow:Step 27 per-step time 1.599s '
#                            'total_loss=0.685, classification_loss=0.111, '
#                            'localization_loss=0.438, rpnObjectness_loss=0.059, '
#                            'rpnLocalization_loss=0.076, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.076,
#                     'rpn_objectness_loss': 0.059,
#                     'step': 27,
#                     'total_loss': 0.685},
#              't': 1676354981},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.255,
#                     'localization_loss': 0.836,
#                     'log': 'INFO:tensorflow:Step 28 per-step time 1.594s '
#                            'total_loss=1.169, classification_loss=0.255, '
#                            'localization_loss=0.836, rpnObjectness_loss=0.050, '
#                            'rpnLocalization_loss=0.027, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.027,
#                     'rpn_objectness_loss': 0.05,
#                     'step': 28,
#                     'total_loss': 1.169},
#              't': 1676354983},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.291,
#                     'localization_loss': 0.62,
#                     'log': 'INFO:tensorflow:Step 29 per-step time 1.587s '
#                            'total_loss=0.964, classification_loss=0.291, '
#                            'localization_loss=0.620, rpnObjectness_loss=0.028, '
#                            'rpnLocalization_loss=0.025, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.025,
#                     'rpn_objectness_loss': 0.028,
#                     'step': 29,
#                     'total_loss': 0.964},
#              't': 1676354984},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.326,
#                     'localization_loss': 0.782,
#                     'log': 'INFO:tensorflow:Step 30 per-step time 1.600s '
#                            'total_loss=1.403, classification_loss=0.326, '
#                            'localization_loss=0.782, rpnObjectness_loss=0.060, '
#                            'rpnLocalization_loss=0.235, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.235,
#                     'rpn_objectness_loss': 0.06,
#                     'step': 30,
#                     'total_loss': 1.403},
#              't': 1676354986},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.152,
#                     'localization_loss': 0.219,
#                     'log': 'INFO:tensorflow:Step 31 per-step time 1.584s '
#                            'total_loss=0.404, classification_loss=0.152, '
#                            'localization_loss=0.219, rpnObjectness_loss=0.022, '
#                            'rpnLocalization_loss=0.012, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.012,
#                     'rpn_objectness_loss': 0.022,
#                     'step': 31,
#                     'total_loss': 0.404},
#              't': 1676354987},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.228,
#                     'localization_loss': 0.328,
#                     'log': 'INFO:tensorflow:Step 32 per-step time 1.586s '
#                            'total_loss=0.709, classification_loss=0.228, '
#                            'localization_loss=0.328, rpnObjectness_loss=0.069, '
#                            'rpnLocalization_loss=0.084, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.084,
#                     'rpn_objectness_loss': 0.069,
#                     'step': 32,
#                     'total_loss': 0.709},
#              't': 1676354989},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.151,
#                     'localization_loss': 0.221,
#                     'log': 'INFO:tensorflow:Step 33 per-step time 1.589s '
#                            'total_loss=0.466, classification_loss=0.151, '
#                            'localization_loss=0.221, rpnObjectness_loss=0.036, '
#                            'rpnLocalization_loss=0.058, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.058,
#                     'rpn_objectness_loss': 0.036,
#                     'step': 33,
#                     'total_loss': 0.466},
#              't': 1676354991},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.063,
#                     'localization_loss': 0.112,
#                     'log': 'INFO:tensorflow:Step 34 per-step time 1.584s '
#                            'total_loss=0.227, classification_loss=0.063, '
#                            'localization_loss=0.112, rpnObjectness_loss=0.018, '
#                            'rpnLocalization_loss=0.035, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.035,
#                     'rpn_objectness_loss': 0.018,
#                     'step': 34,
#                     'total_loss': 0.227},
#              't': 1676354992},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.417,
#                     'localization_loss': 0.596,
#                     'log': 'INFO:tensorflow:Step 35 per-step time 1.581s '
#                            'total_loss=1.083, classification_loss=0.417, '
#                            'localization_loss=0.596, rpnObjectness_loss=0.032, '
#                            'rpnLocalization_loss=0.039, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.039,
#                     'rpn_objectness_loss': 0.032,
#                     'step': 35,
#                     'total_loss': 1.083},
#              't': 1676354994},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.358,
#                     'localization_loss': 0.888,
#                     'log': 'INFO:tensorflow:Step 36 per-step time 1.591s '
#                            'total_loss=1.370, classification_loss=0.358, '
#                            'localization_loss=0.888, rpnObjectness_loss=0.055, '
#                            'rpnLocalization_loss=0.069, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.069,
#                     'rpn_objectness_loss': 0.055,
#                     'step': 36,
#                     'total_loss': 1.37},
#              't': 1676354995},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.205,
#                     'localization_loss': 0.187,
#                     'log': 'INFO:tensorflow:Step 37 per-step time 1.588s '
#                            'total_loss=0.504, classification_loss=0.205, '
#                            'localization_loss=0.187, rpnObjectness_loss=0.068, '
#                            'rpnLocalization_loss=0.045, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.045,
#                     'rpn_objectness_loss': 0.068,
#                     'step': 37,
#                     'total_loss': 0.504},
#              't': 1676354997},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.264,
#                     'localization_loss': 0.362,
#                     'log': 'INFO:tensorflow:Step 38 per-step time 1.581s '
#                            'total_loss=0.757, classification_loss=0.264, '
#                            'localization_loss=0.362, rpnObjectness_loss=0.078, '
#                            'rpnLocalization_loss=0.052, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.052,
#                     'rpn_objectness_loss': 0.078,
#                     'step': 38,
#                     'total_loss': 0.757},
#              't': 1676354998},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.228,
#                     'localization_loss': 0.761,
#                     'log': 'INFO:tensorflow:Step 39 per-step time 1.579s '
#                            'total_loss=1.387, classification_loss=0.228, '
#                            'localization_loss=0.761, rpnObjectness_loss=0.164, '
#                            'rpnLocalization_loss=0.234, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.234,
#                     'rpn_objectness_loss': 0.164,
#                     'step': 39,
#                     'total_loss': 1.387},
#              't': 1676355000},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.145,
#                     'localization_loss': 0.126,
#                     'log': 'INFO:tensorflow:Step 40 per-step time 1.582s '
#                            'total_loss=0.529, classification_loss=0.145, '
#                            'localization_loss=0.126, rpnObjectness_loss=0.072, '
#                            'rpnLocalization_loss=0.186, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.186,
#                     'rpn_objectness_loss': 0.072,
#                     'step': 40,
#                     'total_loss': 0.529},
#              't': 1676355002},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.141,
#                     'localization_loss': 0.168,
#                     'log': 'INFO:tensorflow:Step 41 per-step time 1.584s '
#                            'total_loss=0.596, classification_loss=0.141, '
#                            'localization_loss=0.168, rpnObjectness_loss=0.074, '
#                            'rpnLocalization_loss=0.213, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.213,
#                     'rpn_objectness_loss': 0.074,
#                     'step': 41,
#                     'total_loss': 0.596},
#              't': 1676355003},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.239,
#                     'localization_loss': 0.514,
#                     'log': 'INFO:tensorflow:Step 42 per-step time 1.578s '
#                            'total_loss=0.863, classification_loss=0.239, '
#                            'localization_loss=0.514, rpnObjectness_loss=0.050, '
#                            'rpnLocalization_loss=0.060, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.06,
#                     'rpn_objectness_loss': 0.05,
#                     'step': 42,
#                     'total_loss': 0.863},
#              't': 1676355005},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.182,
#                     'localization_loss': 0.327,
#                     'log': 'INFO:tensorflow:Step 43 per-step time 1.582s '
#                            'total_loss=0.620, classification_loss=0.182, '
#                            'localization_loss=0.327, rpnObjectness_loss=0.056, '
#                            'rpnLocalization_loss=0.055, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.055,
#                     'rpn_objectness_loss': 0.056,
#                     'step': 43,
#                     'total_loss': 0.62},
#              't': 1676355006},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.455,
#                     'localization_loss': 1.157,
#                     'log': 'INFO:tensorflow:Step 44 per-step time 1.578s '
#                            'total_loss=1.749, classification_loss=0.455, '
#                            'localization_loss=1.157, rpnObjectness_loss=0.076, '
#                            'rpnLocalization_loss=0.061, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.061,
#                     'rpn_objectness_loss': 0.076,
#                     'step': 44,
#                     'total_loss': 1.749},
#              't': 1676355008},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.104,
#                     'localization_loss': 0.529,
#                     'log': 'INFO:tensorflow:Step 45 per-step time 1.582s '
#                            'total_loss=0.679, classification_loss=0.104, '
#                            'localization_loss=0.529, rpnObjectness_loss=0.028, '
#                            'rpnLocalization_loss=0.019, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.019,
#                     'rpn_objectness_loss': 0.028,
#                     'step': 45,
#                     'total_loss': 0.679},
#              't': 1676355010},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.325,
#                     'localization_loss': 0.368,
#                     'log': 'INFO:tensorflow:Step 46 per-step time 1.582s '
#                            'total_loss=0.763, classification_loss=0.325, '
#                            'localization_loss=0.368, rpnObjectness_loss=0.049, '
#                            'rpnLocalization_loss=0.021, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.021,
#                     'rpn_objectness_loss': 0.049,
#                     'step': 46,
#                     'total_loss': 0.763},
#              't': 1676355011},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.12,
#                     'localization_loss': 0,
#                     'log': 'INFO:tensorflow:Step 47 per-step time 1.584s '
#                            'total_loss=0.612, classification_loss=0.120, '
#                            'localization_loss=0.000, rpnObjectness_loss=0.117, '
#                            'rpnLocalization_loss=0.375, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.375,
#                     'rpn_objectness_loss': 0.117,
#                     'step': 47,
#                     'total_loss': 0.612},
#              't': 1676355013},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.385,
#                     'localization_loss': 0.794,
#                     'log': 'INFO:tensorflow:Step 48 per-step time 1.581s '
#                            'total_loss=1.370, classification_loss=0.385, '
#                            'localization_loss=0.794, rpnObjectness_loss=0.086, '
#                            'rpnLocalization_loss=0.105, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.105,
#                     'rpn_objectness_loss': 0.086,
#                     'step': 48,
#                     'total_loss': 1.37},
#              't': 1676355014},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.226,
#                     'localization_loss': 0.508,
#                     'log': 'INFO:tensorflow:Step 49 per-step time 1.585s '
#                            'total_loss=0.938, classification_loss=0.226, '
#                            'localization_loss=0.508, rpnObjectness_loss=0.072, '
#                            'rpnLocalization_loss=0.134, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.134,
#                     'rpn_objectness_loss': 0.072,
#                     'step': 49,
#                     'total_loss': 0.938},
#              't': 1676355016},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.102,
#                     'localization_loss': 0.285,
#                     'log': 'INFO:tensorflow:Step 50 per-step time 1.584s '
#                            'total_loss=0.421, classification_loss=0.102, '
#                            'localization_loss=0.285, rpnObjectness_loss=0.018, '
#                            'rpnLocalization_loss=0.015, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.015,
#                     'rpn_objectness_loss': 0.018,
#                     'step': 50,
#                     'total_loss': 0.421},
#              't': 1676355017},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.753,
#                     'localization_loss': 0.496,
#                     'log': 'INFO:tensorflow:Step 51 per-step time 1.588s '
#                            'total_loss=1.389, classification_loss=0.753, '
#                            'localization_loss=0.496, rpnObjectness_loss=0.095, '
#                            'rpnLocalization_loss=0.045, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.045,
#                     'rpn_objectness_loss': 0.095,
#                     'step': 51,
#                     'total_loss': 1.389},
#              't': 1676355019},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.142,
#                     'localization_loss': 0,
#                     'log': 'INFO:tensorflow:Step 52 per-step time 1.581s '
#                            'total_loss=0.193, classification_loss=0.142, '
#                            'localization_loss=0.000, rpnObjectness_loss=0.028, '
#                            'rpnLocalization_loss=0.024, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.024,
#                     'rpn_objectness_loss': 0.028,
#                     'step': 52,
#                     'total_loss': 0.193},
#              't': 1676355021},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.126,
#                     'localization_loss': 0.223,
#                     'log': 'INFO:tensorflow:Step 53 per-step time 1.579s '
#                            'total_loss=0.441, classification_loss=0.126, '
#                            'localization_loss=0.223, rpnObjectness_loss=0.053, '
#                            'rpnLocalization_loss=0.040, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.04,
#                     'rpn_objectness_loss': 0.053,
#                     'step': 53,
#                     'total_loss': 0.441},
#              't': 1676355022},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.234,
#                     'localization_loss': 0.715,
#                     'log': 'INFO:tensorflow:Step 54 per-step time 1.586s '
#                            'total_loss=1.045, classification_loss=0.234, '
#                            'localization_loss=0.715, rpnObjectness_loss=0.044, '
#                            'rpnLocalization_loss=0.052, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.052,
#                     'rpn_objectness_loss': 0.044,
#                     'step': 54,
#                     'total_loss': 1.045},
#              't': 1676355024},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.279,
#                     'localization_loss': 0.623,
#                     'log': 'INFO:tensorflow:Step 55 per-step time 1.587s '
#                            'total_loss=1.137, classification_loss=0.279, '
#                            'localization_loss=0.623, rpnObjectness_loss=0.111, '
#                            'rpnLocalization_loss=0.124, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.124,
#                     'rpn_objectness_loss': 0.111,
#                     'step': 55,
#                     'total_loss': 1.137},
#              't': 1676355025},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.132,
#                     'localization_loss': 0.214,
#                     'log': 'INFO:tensorflow:Step 56 per-step time 1.585s '
#                            'total_loss=0.771, classification_loss=0.132, '
#                            'localization_loss=0.214, rpnObjectness_loss=0.212, '
#                            'rpnLocalization_loss=0.214, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.214,
#                     'rpn_objectness_loss': 0.212,
#                     'step': 56,
#                     'total_loss': 0.771},
#              't': 1676355027},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.238,
#                     'localization_loss': 0.497,
#                     'log': 'INFO:tensorflow:Step 57 per-step time 1.596s '
#                            'total_loss=1.009, classification_loss=0.238, '
#                            'localization_loss=0.497, rpnObjectness_loss=0.114, '
#                            'rpnLocalization_loss=0.160, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.16,
#                     'rpn_objectness_loss': 0.114,
#                     'step': 57,
#                     'total_loss': 1.009},
#              't': 1676355029},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.419,
#                     'localization_loss': 1.436,
#                     'log': 'INFO:tensorflow:Step 58 per-step time 1.599s '
#                            'total_loss=1.897, classification_loss=0.419, '
#                            'localization_loss=1.436, rpnObjectness_loss=0.019, '
#                            'rpnLocalization_loss=0.023, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.023,
#                     'rpn_objectness_loss': 0.019,
#                     'step': 58,
#                     'total_loss': 1.897},
#              't': 1676355030},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.425,
#                     'localization_loss': 1.469,
#                     'log': 'INFO:tensorflow:Step 59 per-step time 1.584s '
#                            'total_loss=1.983, classification_loss=0.425, '
#                            'localization_loss=1.469, rpnObjectness_loss=0.048, '
#                            'rpnLocalization_loss=0.041, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.041,
#                     'rpn_objectness_loss': 0.048,
#                     'step': 59,
#                     'total_loss': 1.983},
#              't': 1676355032},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.401,
#                     'localization_loss': 0.432,
#                     'log': 'INFO:tensorflow:Step 60 per-step time 1.602s '
#                            'total_loss=0.906, classification_loss=0.401, '
#                            'localization_loss=0.432, rpnObjectness_loss=0.040, '
#                            'rpnLocalization_loss=0.033, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.033,
#                     'rpn_objectness_loss': 0.04,
#                     'step': 60,
#                     'total_loss': 0.906},
#              't': 1676355033},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.394,
#                     'localization_loss': 0.368,
#                     'log': 'INFO:tensorflow:Step 61 per-step time 1.603s '
#                            'total_loss=0.790, classification_loss=0.394, '
#                            'localization_loss=0.368, rpnObjectness_loss=0.014, '
#                            'rpnLocalization_loss=0.015, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.015,
#                     'rpn_objectness_loss': 0.014,
#                     'step': 61,
#                     'total_loss': 0.79},
#              't': 1676355035},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.302,
#                     'localization_loss': 0.524,
#                     'log': 'INFO:tensorflow:Step 62 per-step time 1.603s '
#                            'total_loss=1.005, classification_loss=0.302, '
#                            'localization_loss=0.524, rpnObjectness_loss=0.083, '
#                            'rpnLocalization_loss=0.096, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.096,
#                     'rpn_objectness_loss': 0.083,
#                     'step': 62,
#                     'total_loss': 1.005},
#              't': 1676355037},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.332,
#                     'localization_loss': 0.801,
#                     'log': 'INFO:tensorflow:Step 63 per-step time 1.603s '
#                            'total_loss=3.341, classification_loss=0.332, '
#                            'localization_loss=0.801, rpnObjectness_loss=0.342, '
#                            'rpnLocalization_loss=1.866, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 1.866,
#                     'rpn_objectness_loss': 0.342,
#                     'step': 63,
#                     'total_loss': 3.341},
#              't': 1676355038},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.125,
#                     'localization_loss': 0.068,
#                     'log': 'INFO:tensorflow:Step 64 per-step time 1.594s '
#                            'total_loss=0.432, classification_loss=0.125, '
#                            'localization_loss=0.068, rpnObjectness_loss=0.071, '
#                            'rpnLocalization_loss=0.168, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.168,
# ...
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.026,
#                     'rpn_objectness_loss': 0.02,
#                     'step': 284,
#                     'total_loss': 0.826},
#              't': 1676355645},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.163,
#                     'localization_loss': 0.145,
#                     'log': 'INFO:tensorflow:Step 285 per-step time 1.579s '
#                            'total_loss=0.358, classification_loss=0.163, '
#                            'localization_loss=0.145, rpnObjectness_loss=0.026, '
#                            'rpnLocalization_loss=0.023, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.023,
#                     'rpn_objectness_loss': 0.026,
#                     'step': 285,
#                     'total_loss': 0.358},
#              't': 1676355646},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.101,
#                     'localization_loss': 0.208,
#                     'log': 'INFO:tensorflow:Step 286 per-step time 1.583s '
#                            'total_loss=0.554, classification_loss=0.101, '
#                            'localization_loss=0.208, rpnObjectness_loss=0.128, '
#                            'rpnLocalization_loss=0.117, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.117,
#                     'rpn_objectness_loss': 0.128,
#                     'step': 286,
#                     'total_loss': 0.554},
#              't': 1676355648},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.413,
#                     'localization_loss': 0.528,
#                     'log': 'INFO:tensorflow:Step 287 per-step time 1.579s '
#                            'total_loss=1.018, classification_loss=0.413, '
#                            'localization_loss=0.528, rpnObjectness_loss=0.035, '
#                            'rpnLocalization_loss=0.042, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.042,
#                     'rpn_objectness_loss': 0.035,
#                     'step': 287,
#                     'total_loss': 1.018},
#              't': 1676355650},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.152,
#                     'localization_loss': 0.281,
#                     'log': 'INFO:tensorflow:Step 288 per-step time 1.579s '
#                            'total_loss=0.471, classification_loss=0.152, '
#                            'localization_loss=0.281, rpnObjectness_loss=0.014, '
#                            'rpnLocalization_loss=0.024, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.024,
#                     'rpn_objectness_loss': 0.014,
#                     'step': 288,
#                     'total_loss': 0.471},
#              't': 1676355651},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.088,
#                     'localization_loss': 0.222,
#                     'log': 'INFO:tensorflow:Step 289 per-step time 1.579s '
#                            'total_loss=0.359, classification_loss=0.088, '
#                            'localization_loss=0.222, rpnObjectness_loss=0.013, '
#                            'rpnLocalization_loss=0.035, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.035,
#                     'rpn_objectness_loss': 0.013,
#                     'step': 289,
#                     'total_loss': 0.359},
#              't': 1676355653},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.194,
#                     'localization_loss': 0.113,
#                     'log': 'INFO:tensorflow:Step 290 per-step time 1.586s '
#                            'total_loss=0.352, classification_loss=0.194, '
#                            'localization_loss=0.113, rpnObjectness_loss=0.021, '
#                            'rpnLocalization_loss=0.025, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.025,
#                     'rpn_objectness_loss': 0.021,
#                     'step': 290,
#                     'total_loss': 0.352},
#              't': 1676355654},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.351,
#                     'localization_loss': 0.697,
#                     'log': 'INFO:tensorflow:Step 291 per-step time 1.586s '
#                            'total_loss=1.119, classification_loss=0.351, '
#                            'localization_loss=0.697, rpnObjectness_loss=0.042, '
#                            'rpnLocalization_loss=0.029, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.029,
#                     'rpn_objectness_loss': 0.042,
#                     'step': 291,
#                     'total_loss': 1.119},
#              't': 1676355656},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.057,
#                     'localization_loss': 0.068,
#                     'log': 'INFO:tensorflow:Step 292 per-step time 1.578s '
#                            'total_loss=0.233, classification_loss=0.057, '
#                            'localization_loss=0.068, rpnObjectness_loss=0.036, '
#                            'rpnLocalization_loss=0.072, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.072,
#                     'rpn_objectness_loss': 0.036,
#                     'step': 292,
#                     'total_loss': 0.233},
#              't': 1676355657},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.094,
#                     'localization_loss': 0.099,
#                     'log': 'INFO:tensorflow:Step 293 per-step time 1.578s '
#                            'total_loss=0.214, classification_loss=0.094, '
#                            'localization_loss=0.099, rpnObjectness_loss=0.008, '
#                            'rpnLocalization_loss=0.013, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.013,
#                     'rpn_objectness_loss': 0.008,
#                     'step': 293,
#                     'total_loss': 0.214},
#              't': 1676355659},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.119,
#                     'localization_loss': 0.184,
#                     'log': 'INFO:tensorflow:Step 294 per-step time 1.578s '
#                            'total_loss=0.339, classification_loss=0.119, '
#                            'localization_loss=0.184, rpnObjectness_loss=0.009, '
#                            'rpnLocalization_loss=0.027, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.027,
#                     'rpn_objectness_loss': 0.009,
#                     'step': 294,
#                     'total_loss': 0.339},
#              't': 1676355661},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.194,
#                     'localization_loss': 0.188,
#                     'log': 'INFO:tensorflow:Step 295 per-step time 1.587s '
#                            'total_loss=0.421, classification_loss=0.194, '
#                            'localization_loss=0.188, rpnObjectness_loss=0.018, '
#                            'rpnLocalization_loss=0.021, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.021,
#                     'rpn_objectness_loss': 0.018,
#                     'step': 295,
#                     'total_loss': 0.421},
#              't': 1676355662},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.149,
#                     'localization_loss': 0.129,
#                     'log': 'INFO:tensorflow:Step 296 per-step time 1.584s '
#                            'total_loss=0.359, classification_loss=0.149, '
#                            'localization_loss=0.129, rpnObjectness_loss=0.025, '
#                            'rpnLocalization_loss=0.056, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.056,
#                     'rpn_objectness_loss': 0.025,
#                     'step': 296,
#                     'total_loss': 0.359},
#              't': 1676355664},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.197,
#                     'localization_loss': 0.205,
#                     'log': 'INFO:tensorflow:Step 297 per-step time 1.577s '
#                            'total_loss=0.657, classification_loss=0.197, '
#                            'localization_loss=0.205, rpnObjectness_loss=0.102, '
#                            'rpnLocalization_loss=0.154, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.154,
#                     'rpn_objectness_loss': 0.102,
#                     'step': 297,
#                     'total_loss': 0.657},
#              't': 1676355665},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.246,
#                     'localization_loss': 0.565,
#                     'log': 'INFO:tensorflow:Step 298 per-step time 1.582s '
#                            'total_loss=0.901, classification_loss=0.246, '
#                            'localization_loss=0.565, rpnObjectness_loss=0.040, '
#                            'rpnLocalization_loss=0.051, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.051,
#                     'rpn_objectness_loss': 0.04,
#                     'step': 298,
#                     'total_loss': 0.901},
#              't': 1676355667},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.057,
#                     'localization_loss': 0.122,
#                     'log': 'INFO:tensorflow:Step 299 per-step time 1.584s '
#                            'total_loss=0.212, classification_loss=0.057, '
#                            'localization_loss=0.122, rpnObjectness_loss=0.009, '
#                            'rpnLocalization_loss=0.023, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.023,
#                     'rpn_objectness_loss': 0.009,
#                     'step': 299,
#                     'total_loss': 0.212},
#              't': 1676355668},
#             {'ev': 'trainingCheckpoint',
#              'pl': {'classification_loss': 0.141,
#                     'localization_loss': 0.182,
#                     'log': 'INFO:tensorflow:Step 300 per-step time 1.580s '
#                            'total_loss=0.463, classification_loss=0.141, '
#                            'localization_loss=0.182, rpnObjectness_loss=0.053, '
#                            'rpnLocalization_loss=0.087, mask_loss=0.000, ',
#                     'mask_loss': 0,
#                     'rpn_localization_loss': 0.087,
#                     'rpn_objectness_loss': 0.053,
#                     'step': 300,
#                     'total_loss': 0.463},
#              't': 1676355670},
#             {'ev': 'evaluationCheckpoint',
#              'pl': {'average_precision': 0.178539,
#                     'average_precision.50_iou': 0.316443,
#                     'average_precision.75_iou': 0.184913,
#                     'average_recall1': 0.162157,
#                     'average_recall10': 0.222549,
#                     'average_recall100': 0.233333,
#                     'classification_loss': 0.086784,
#                     'large_average_precision': 0.528648,
#                     'large_average_recall100': 0.657516,
#                     'localization_loss': 0.043357,
#                     'log': 'Loading and preparing annotation results...\n'
#                            'INFO:tensorflow:Eval metrics at step 300\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Precision/mAP: '
#                            '0.178539\n'
#                            'INFO:tensorflow:\t+ '
#                            'DetectionBoxes_Precision/mAP@.50IOU: 0.316443\n'
#                            'INFO:tensorflow:\t+ '
#                            'DetectionBoxes_Precision/mAP@.75IOU: 0.184913\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Precision/mAP '
#                            '(small): 0.013373\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Precision/mAP '
#                            '(medium): 0.100620\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Precision/mAP '
#                            '(large): 0.528648\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Recall/AR@1: '
#                            '0.162157\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Recall/AR@10: '
#                            '0.222549\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Recall/AR@100: '
#                            '0.233333\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Recall/AR@100 '
#                            '(small): 0.011071\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Recall/AR@100 '
#                            '(medium): 0.198701\n'
#                            'INFO:tensorflow:\t+ DetectionBoxes_Recall/AR@100 '
#                            '(large): 0.657516\n'
#                            'INFO:tensorflow:\t+ Loss/rpnLocalization_loss: '
#                            '0.151804\n'
#                            'INFO:tensorflow:\t+ Loss/rpnObjectness_loss: '
#                            '0.061480\n'
#                            'INFO:tensorflow:\t+ Loss/localization_loss: '
#                            '0.043357\n'
#                            'INFO:tensorflow:\t+ Loss/classification_loss: '
#                            '0.086784\n'
#                            'INFO:tensorflow:\t+ Loss/regularization_loss: '
#                            '0.000000\n'
#                            'INFO:tensorflow:\t+ Loss/total_loss: 0.343426\n'
#                            'INFO:tensorflow:Waiting for new checkpoint at '
#                            '***\n',
#                     'medium_average_precision': 0.10062,
#                     'medium_average_recall100': 0.198701,
#                     'regularization_loss': 0,
#                     'rpn_localization_loss': 0.151804,
#                     'rpn_objectness_loss': 0.06148,
#                     'small_average_precision': 0.013373,
#                     'small_average_recall100': 0.011071,
#                     'step': 300,
#                     'total_loss': 0.343426},
#              't': 1676355798},
#             {'ev': 'artifactAuthorized',
#              'pl': {'artifact_id': '63eb28d6b03587e371e787cc',
#                     'name': 'ckpt-4'},
#              't': 1676355798},
#             {'ev': 'trainingFinished',
#              'pl': {'message': 'Training finished with code 0 on signal null'},
#              't': 1676355805},
#             {'ev': 'evaluationFinished',
#              'pl': {'message': 'Evaluation finished with code 0 on signal '
#                                'null'},
#              't': 1676355805},
#             {'ev': 'artifactUploaded',
#              'pl': {'artifact_id': '63eb28d6b03587e371e787cc',
#                     'files': [{'md5': '0ef8c7070af7cf9892fec8089e0180fe',
#                                'name': 'ckpt-4.index'},
#                               {'md5': 'c253ca78d4a3a15e6890c801e2f663a9',
#                                'name': 'ckpt-4.data-00000-of-00001'}]},
#              't': 1676355807},
#             {'ev': 'artifactRemoved',
#              'pl': {'artifact_id': '63eb27b8b03587e371e78401',
#                     'by': '63eb28d6b03587e371e787cc',
#                     'reason': 'replaced'},
#              't': 1676355809}],
#  'id': 'log_63eb22b7bec73541a7b3728f',
#  'object': 'archivedLog'}

# %% [markdown]
# ## 10.4. Retrieve A Training Run

# %% [markdown]
# Retrieves a training run based on the specified training run id.

# %%
run_retrieve_response = datature.Run.retrieve(
    "run_63eb5410e3cc5b966339344f"
)
pprint.pprint(run_retrieve_response)
# Out:
# {'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                'checkpoint': {'evaluation_interval': 250,
#                               'metric': 'Loss/total_loss',
#                               'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'}},
#  'features': {'preview': True},
#  'flow_id': 'flow_63eb229abec73541a7b37280',
#  'id': 'run_63eb5410e3cc5b966339344f',
#  'logs': ['log_63eb5410e3cc5b966339344f'],
#  'object': 'run',
#  'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#  'status': {'conditions': [{'condition': 'TrainingStarted',
#                             'status': 'running'}]}}

# %% [markdown]
# ## 10.5. Kill A Training Run

# %% [markdown]
# Kill an ongoing training run based on the specified training run id. Note that the this will ony work if the training has already initialized and is currently ongoing.

# %%
# Kill an ongoing training run
run_modify_response = datature.Run.kill(
    "run_63eb5410e3cc5b966339344f",
)
# Display response for the killing of training run operation
pprint.pprint(run_modify_response)
# Out:
# {'create_date': 1676367040778,
#  'execution': {'accelerator': {'count': 1, 'name': 'GPU_T4'},
#                'checkpoint': {'evaluation_interval': 250,
#                               'metric': 'Loss/total_loss',
#                               'strategy': 'STRAT_LOWEST_VALIDATION_LOSS'}},
#  'features': {'preview': True},
#  'flow_id': 'flow_63eb229abec73541a7b37280',
#  'id': 'run_63eb5410e3cc5b966339344f',
#  'logs': ['log_63eb5410e3cc5b966339344f'],
#  'object': 'run',
#  'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#  'status': {'conditions': [{'condition': 'TrainingStarted',
#                             'last_updated': 1676367040778,
#                             'status': 'finished'},
#                            {'condition': 'TrainingFinished',
#                             'last_updated': 1676367040778,
#                             'status': 'running'}]}}

# %% [markdown]
# ## 10.6. Delete A Training Run

# %% [markdown]
# Delete a training run based on the specified training run id.

# %%
# Delete a training run based on the specified training run id
run_delete_response = datature.Run.delete(
    "run_63eb5410e3cc5b966339344f"
)
# Display response of the deletion of training run operation
pprint.pprint(run_delete_response)
# Out:
# {'deleted': True, 'id': 'run_63eb5410e3cc5b966339344f'}

# %% [markdown]
# # 11. Artifact API

# %% [markdown]
# This section contains all the operations with regards to the artifacts. Artifacts are the model files that are generated from the training runs where it can be exported to a variety of formats like `tensorflow`, `tflite` or `onnx`.

# %% [markdown]
# ## 11.1. List All Artifacts

# %% [markdown]
# List all artifacts in the project. The listed artifacts will include the metadata related to the artifacts like the `metric` and the `exports` that has been made to export the artifact to the specified model format as well as other metadata.

# %%
# List all artifacts in the project
artifact_list_response = datature.Artifact.list()
# Display response for the listing of all artifacts operations
pprint.pprint(artifact_list_response)
# Out:
# [{'artifact': 'ckpt-1',
#   'create_date': 1676361841029,
#   'exports': [],
#   'files': [{'md5': '832cc3488eee29f21794a17a503eed09', 'name': 'ckpt-1.index'},
#             {'md5': 'acce8cdac80ea96af1b1a81247333578',
#              'name': 'ckpt-1.data-00000-of-00001'}],
#   'flow_title': 'Example Old Workflow',
#   'id': 'artifact_63eb4071b03587e371e79bd6',
#   'is_deployed': False,
#   'is_training': False,
#   'metric': {'classification_loss': 1.484,
#              'localization_loss': 0.173,
#              'regularization_loss': 0,
#              'total_loss': 1.658},
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'run_id': 'run_63eb3dfdf45218f93dbb34a4',
#   'step': 0},
#  {'artifact': 'ckpt-4',
#   'create_date': 1676355798502,
#   'exports': ['tensorflow', 'onnx'],
#   'files': [{'md5': '0ef8c7070af7cf9892fec8089e0180fe', 'name': 'ckpt-4.index'},
#             {'md5': 'c253ca78d4a3a15e6890c801e2f663a9',
#              'name': 'ckpt-4.data-00000-of-00001'}],
#   'flow_title': 'Example Old Workflow',
#   'id': 'artifact_63eb28d6b03587e371e787cc',
#   'is_deployed': True,
#   'is_training': False,
#   'metric': {'classification_loss': 0.148,
#              'localization_loss': 0.195,
#              'regularization_loss': 0,
#              'total_loss': 0.343},
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'run_id': 'run_63eb22b7bec73541a7b3728f',
#   'step': 300}]

# %% [markdown]
# ## 11.2. Retrieve An Artifact

# %% [markdown]
# Retrieves an artifact information based on the specified artifact id. The return response will include the metadata related to the specified artifact like the `metric` and the `exports` that has been made to export the artifact to the specified model format as well as other metadata.

# %%
# Retrieve an artifact's information based on the specified artifact id
artifact_retrieve_response = datature.Artifact.retrieve(
    "artifact_63eb28d6b03587e371e787cc"
)
# Display response of artifact retrieval operation
pprint.pprint(artifact_retrieve_response)
# Out:
# {'artifact': 'ckpt-4',
#  'create_date': 1676355798502,
#  'exports': ['tensorflow', 'onnx'],
#  'files': [{'md5': '0ef8c7070af7cf9892fec8089e0180fe', 'name': 'ckpt-4.index'},
#            {'md5': 'c253ca78d4a3a15e6890c801e2f663a9',
#             'name': 'ckpt-4.data-00000-of-00001'}],
#  'flow_title': 'Example Old Workflow',
#  'id': 'artifact_63eb28d6b03587e371e787cc',
#  'is_deployed': True,
#  'is_training': False,
#  'metric': {'classification_loss': 0.148,
#             'localization_loss': 0.195,
#             'regularization_loss': 0,
#             'total_loss': 0.343},
#  'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#  'run_id': 'run_63eb22b7bec73541a7b3728f',
#  'step': 300}

# %% [markdown]
# ## 11.3. Export An Artifact Model

# %% [markdown]
# Triggers an artifact export operation based on the specified artifact id as well as specified model format. Allowed formats to be exported are as follows:
#
# `tensorflow`, `tflite`, `onnx`

# %%
# Export a model to the specified model format for specified artifact id
artifact_export_model_response = datature.Artifact.export_model(
    "artifact_63eb28d6b03587e371e787cc",
    "onnx"
)
# Display response for triggering the export model artifact operation
pprint.pprint(artifact_export_model_response)
# Out:
# {'create_date': 1676367354183,
#  'format': 'onnx',
#  'id': 'model_5535e70ae448f9be6df5969104d5fb49',
#  'object': 'model',
#  'status': 'Running'}

# %% [markdown]
# ## 11.4. Retrieve Artifact Models

# %% [markdown]
# Retrieves all the models for an artifact based on the specified artifact id. The models here refers to the different possible model format that the artifact has been exported to like `tensorflow`, `tflite` or `onnx`.

# %%
# List all exported models for the specified artifact id
artifact_list_exported_response = datature.Artifact.list_exported(
    "artifact_63eb28d6b03587e371e787cc"
)
# Display response for the list exported artifact response
pprint.pprint(artifact_list_exported_response)
# Out:
# [{'create_date': 1676363861901,
#   'download': {'expiry': 1676450631949,
#                'method': 'GET',
#                'url': 'https://storage.googleapis.com/exports.datature.io/c4df32bdb04a34877c1693540a710b05/models/63eb22b7bec73541a7b3728f-ckpt-4-onnx.zip?Expires=1676450631&GoogleAccessId=464284302797-compute%40developer.gserviceaccount.com&Signature=LdsrGotPVN4uzXLtG0GreQAcxth44%2BocVSz3NLvLQ3B26SF%2BWh%2BRsooh1iQ1t%2FR6Aan0ZYcZu6ig3AT%2Bm03ypKG2sLStj1xr%2FV63jdFSjm3EoTTODEdepivIBgNO7f%2FGgBmg2EersTe1c0W90313a1No8uygp7%2BEiYIS3GZa5cYSsihi4mvEmHCDlwV%2B4BJ4%2BJOCeiazLE17FPpZMTiGCwevtSgZCQ0gbHelvlfXt5kxklgOBWJf63Nm%2F0mXjyx%2FNO2uej7R8JJOSofFEtuOnVI5KaDE8OMlujOoqxpdRdkgrns0iyTaiEFasruFWWYFZoozmLO4MV4KYJVAxJONBg%3D%3D'},
#   'format': 'onnx',
#   'id': 'model_4530c25934201603b4e15461c64395ac',
#   'object': 'model',
#   'status': 'Finished'},
#  {'create_date': 1676363078987,
#   'download': {'expiry': 1676450071466,
#                'method': 'GET',
#                'url': 'https://storage.googleapis.com/exports.datature.io/c4df32bdb04a34877c1693540a710b05/models/63eb22b7bec73541a7b3728f-ckpt-4.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=464284302797-compute%40developer.gserviceaccount.com%2F20230214%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230214T083431Z&X-Goog-Expires=86401&X-Goog-SignedHeaders=host&X-Goog-Signature=...'},
#   'format': 'tensorflow',
#   'id': 'model_6eaf8a9bdce682ce0e6be8c2929a8a09',
#   'object': 'model',
#   'status': 'Finished'}]

# %% [markdown]
# # 12. Deploy API

# %% [markdown]
# This section describes all the operations related to deployment. Deployment helps to serve the model into an API endpoint to be consumed.

# %% [markdown]
# ## 12.1. Create A Deployment

# %% [markdown]
# Create a model deployment based on the specified model id. Configurable parameters are the `name` of the deployment as well as the `num_of_instances` which represents the number of instances of the model deployment to serve. Do note that it will take some time (5-7 minutes) for the deployment to be created.
#
# **NOTE: An ONNX model is required to be exported first in order to trigger the creation of a deployment API**

# %%
# Create a deployment based on the specified model id
deploy_create_response = datature.Deploy.create(
    {
         "name": "My First API",
         "model_id": "model_4530c25934201603b4e15461c64395ac",
         "num_of_instances": 1,
    }
)
# Display response of the create deployment operation
pprint.pprint(deploy_create_response)
# Out:
# {'id': 'op_02c63009-b5a0-4c8c-a6a1-0db3f4f3d5b3',
#  'object': 'operation',
#  'op_link': 'users/api|9ba9baf9-178a-47ed-9d2b-60155eda2359/projects/c4df32bdb04a34877c1693540a710b05/operations/octopod.managedDeployments.setup/02c63009-b5a0-4c8c-a6a1-0db3f4f3d5b3',
#  'status': {'message': 'Operation queued',
#             'overview': 'Queued',
#             'progress': {'unit': 'whole operation',
#                          'with_status': {'cancelled': 0,
#                                          'errored': 0,
#                                          'finished': 0,
#                                          'queued': 1,
#                                          'running': 0}},
#             'time_scheduled': 1676365015109,
#             'time_updated': 1676365015109}}

# %% [markdown]
# ## 12.2. List All Deployments

# %% [markdown]
# List all deployments in a project. The listed deployments will include the metadata of related to the deployments like the `status` as well as the `scaling` method of the deployment along with other metadata.

# %%
# List all deployments in the project
deploy_list_response = datature.Deploy.list()
# Display response for listing of deployments operations
pprint.pprint(deploy_list_response)
# Out:
# [{'create_date': 1676364310924,
#   'id': 'deploy_57078a22-fe8d-41dc-a83a-0479bec6032e',
#   'last_modified_date': 1676364771563,
#   'locked': False,
#   'model_id': 'model_4530c25934201603b4e15461c64395ac',
#   'name': 'My First API',
#   'object': 'deploy',
#   'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#   'scaling': {'mode': 'fixed', 'num_instances': 1},
#   'status': {'message': 'Created service successfully',
#              'overview': 'AVAILABLE',
#              'status_date': 1676364771563},
#   'url': 'https://inference.datature.io/neural/57078a22-fe8d-41dc-a83a-0479bec6032e/predict'}]

# %% [markdown]
# ## 12.3. Retrieve A Deployment

# %% [markdown]
# Retrieves a deployment based on the specified deployment id. The results will include the metadata of related to the deployments like the `status` as well as the `scaling` method of the deployment along with other metadata.

# %%
# Retrieve a deployment by the specified deployment id
deploy_retrieve_response = datature.Deploy.retrieve(
    "deploy_57078a22-fe8d-41dc-a83a-0479bec6032e"
)
# Display response for the retrieval of deployment operation
pprint.pprint(deploy_retrieve_response)
# Out:
# {'create_date': 1676364310924,
#  'id': 'deploy_57078a22-fe8d-41dc-a83a-0479bec6032e',
#  'last_modified_date': 1676364771563,
#  'locked': False,
#  'model_id': 'model_4530c25934201603b4e15461c64395ac',
#  'name': 'My First API',
#  'object': 'deploy',
#  'project_id': 'proj_c4df32bdb04a34877c1693540a710b05',
#  'scaling': {'mode': 'fixed', 'num_instances': 1},
#  'status': {'message': 'Created service successfully',
#             'overview': 'AVAILABLE',
#             'status_date': 1676364771563},
#  'url': 'https://inference.datature.io/neural/57078a22-fe8d-41dc-a83a-0479bec6032e/predict'}

# %% [markdown]
# ## 12.4. Delete A Deployment

# %% [markdown]
# Delete a deployment based on the specified deployment id. Do note that it will take some time (5-7 minutes) for the deployment to be removed on the platform.

# %%
# Delete a deployment based on the specified deployment id
deploy_delete_response = datature.Deploy.delete(
    "deploy_57078a22-fe8d-41dc-a83a-0479bec6032e"
)
# Display response for the deletion of the deployment operation
pprint.pprint(deploy_delete_response)
# Out:
# {'deleted': True, 'id': 'deploy_57078a22-fe8d-41dc-a83a-0479bec6032e'}
